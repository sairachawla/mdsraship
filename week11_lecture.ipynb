# %% [markdown]
# # Week 11 - Databases and SQL

# %% [markdown]
# ## Roadmap
#
# - Python and Relational Databases
#     * Connecting to local and remote databases
#     * Send SQL queries from Python
#     * Return Python objects from SQL
# - Introduction to SQL
#     * Building SQL queries

# %% [markdown]
# # Administrative
#
# ## Assignments
#
# - HW 9 on SQL will be the last weekly assignment.
# - Focus should be on final project afterwards.

# %% [markdown]
# ## Final Project
#
# ![](images/final_project_no_worry.jpg)

# %% [markdown]
# # Python and Relational Databases
#
# ![](images/python_sql_banner.png)

# %% [markdown]
# ## What is a relational database?
#
# ![](images/relational_company_1.png)

# %% [markdown]
# ## What is a relational database?
#
# ![](images/relational_company_2.png)

# %% [markdown]
# ## What is a relational database?
#
# ![](images/relational_company_3.png)

# %% [markdown]
# ## What is a relational database?
#
# ![](images/relational_company_4.png)

# %% [markdown]
# ## What is a relational database?
#
# ![](images/relational_company_5.png)

# %% [markdown]
# ## Why use relational databases in Python?
#
# - A: the data is currently stored in a **relational databases**. We want to work with it directly.
#
# - B: The data is **not currently in a relational database**. But maybe it should be, to **address some short-comings in Python**.

# %% [markdown]
# ## Python's short comings
#
# **Python has difficulty with:**
#
# - **Memory:** Manipulating large datasets because data needs to reside in memory for most tasks.
# - **Several Users:** Providing concurrent access to data for multiple users.
# - **Persistence:** Data cannot easily be updated (or changed in a few observations) without loading the data into Python and then recreating the data file on disk.

# %% [markdown]
# ## SQL Databases

# %% [markdown]
# ![](images/main_databases.jpg)

# %% [markdown]
# - [RDBMS](https://en.wikipedia.org/wiki/Relational_database_management_system) - **R**elational **D**ata**base** **M**anagement **S**ystem
# - _Open source_: MySQL, PostgreSQL, SQLite
# - _Proprietary_: Oracle Database, Microsoft SQL Server, Redshift, BigQuery, Snowflake

# %% [markdown]
# ## SQL - **S**trucured **Q**uery **L**anguage
#
# SQL, or **S**trucured **Q**uery **L**anguage, is a standard language for storing, manipulating and retrieving data in databases.
#
# **Good News**:
#
# All of these relational databases systems can be queried with [SQL](https://en.wikipedia.org/wiki/SQL).
#
# **Bad News**:
#
# Each has an proprietary API / SQL Dialect.

# %% [markdown]
# ## DBMS Popularity
#
# ![](images/DBMS_popularity.png)
#
# <span class="source">https://db-engines.com/en/ranking_trend/relational+dbms </span>

# %% [markdown]
# ## Required Packages
#
# - None - for sqlite the driver is part of the Python distribution
# - `psycopg2` — for PostgreSQL (*recommended* for this course)
# - `pymysql` — for MySQL
# - `pyodbc` — for SQL Server
#
# and ...
#
# - `sqlalchemy` — to work with data as Python objects

# %% [markdown]
# ## Connecting to a database with SQLAlchemy
#
# Let's connect to a database for our lecture today.

# %%
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://guest:guest@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo')

# %% [markdown]
# ## Running SQL from Jupyter Notebook
#
# ![](images/jupyter_sql_banner.jpeg)

# %% [markdown]
# ## SQL cell
#
# For convenience, we can add some functionality to Jupyter Notebooks to directly run SQL cells. This likely won't be a production implementation but is useful for exploration code.
#
# Assuming you have installed `ipython-sql`, you can load the sql extension:

# %%
# %load_ext sql

# %% [markdown]
# And connect to the database:

# %%
# %sql mysql+pymysql://guest:guest@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo

# %% [markdown]
# You can refer to a specific database connection (if you have multiple) by `<username>@<DBname`

# %%
# %sql guest@shinydemo

# %% [markdown]
# ## Running SQL commands
#
# Once the database connection is established, you can simply run SQL cells starting with `%%sql`:

# %%
# %%sql
# SHOW TABLES
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 3 rows affected.
# [('City',), ('Country',), ('CountryLanguage',)]

# %% [markdown]
# # Intro to SQL
#
# ![](images/sql_for_data_science_banner.png)

# %% [markdown]
# ## SHOW TABLES
#
# **TASK**: `SHOW TABLES` lists all tables the database includes.

# %%
# %sql SHOW TABLES
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 3 rows affected.
# [('City',), ('Country',), ('CountryLanguage',)]

# %% [markdown]
# ## DESCRIBE
#
# We can describe each table with `DESCRIBE <table name>`.

# %%
# %sql DESCRIBE Country
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'float(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint(6)', 'YES', '', None, ''),
#  ('Population', 'int(11)', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'float(3,1)', 'YES', '', None, ''),
#  ('GNP', 'float(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'float(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int(11)', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %% [markdown]
# ## DESCRIBE
#
# **TASK**: Describe the `City` and `CountryLanguage` table.

# %%
# %sql DESCRIBE City
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 5 rows affected.
# [('ID', 'double', 'YES', '', None, ''),
#  ('Name', 'text', 'YES', '', None, ''),
#  ('CountryCode', 'text', 'YES', '', None, ''),
#  ('District', 'text', 'YES', '', None, ''),
#  ('Population', 'double', 'YES', '', None, '')]

# %%
# %sql DESCRIBE CountryLanguage
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 4 rows affected.
# [('CountryCode', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Language', 'char(30)', 'NO', 'PRI', '', ''),
#  ('IsOfficial', "enum('T','F')", 'NO', '', 'F', ''),
#  ('Percentage', 'float(4,1)', 'NO', '', '0.0', '')]

# %% [markdown]
# ## SELECT

# %% [markdown]
# `SELECT <column names>` is called the **SELECT clause**.
#
# `SELECT` is used to **specify what columns to retrieve** from various tables.
#
# `<column names>` specifies **column names separated by a comma** (aka comma-delimited column names).
#
# Note that there should be **no comma after the last column**.
#
# `*` is a **wild card** including all columns.

# %% [markdown]
# ## SELECT

# %% [markdown]
# **TASK**: Select a single column, `Language`, from the `CountryLanguage` table.

# %%
# %sql SELECT Language FROM CountryLanguage
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 984 rows affected.
# [('Dutch',),
#  ('English',),
#  ('Papiamento',),
#  ('Spanish',),
#  ('Balochi',),
#  ('Dari',),
#  ('Pashto',),
#  ('Turkmenian',),
#  ('Uzbek',),
#  ('Ambo',),
#  ('Chokwe',),
#  ('Kongo',),
#  ('Luchazi',),
#  ('Luimbe-nganguela',),
#  ('Luvale',),
#  ('Mbundu',),
#  ('Nyaneka-nkhumbi',),
#  ('Ovimbundu',),
#  ('English',),
#  ('Albaniana',),
#  ('Greek',),
#  ('Macedonian',),
#  ('Catalan',),
#  ('French',),
#  ('Portuguese',),
#  ('Spanish',),
#  ('Dutch',),
#  ('English',),
#  ('Papiamento',),
#  ('Arabic',),
#  ('Hindi',),
#  ('Indian Languages',),
#  ('Italian',),
#  ('Spanish',),
#  ('Armenian',),
#  ('Azerbaijani',),
#  ('English',),
#  ('Samoan',),
#  ('Tongan',),
#  ('Creole English',),
#  ('English',),
#  ('Arabic',),
#  ('Canton Chinese',),
#  ('English',),
#  ('German',),
#  ('Greek',),
#  ('Italian',),
#  ('Serbo-Croatian',),
#  ('Vietnamese',),
#  ('Czech',),
#  ('German',),
#  ('Hungarian',),
#  ('Polish',),
#  ('Romanian',),
#  ('Serbo-Croatian',),
#  ('Slovene',),
#  ('Turkish',),
#  ('Armenian',),
#  ('Azerbaijani',),
#  ('Lezgian',),
#  ('Russian',),
#  ('French',),
#  ('Kirundi',),
#  ('Swahili',),
#  ('Arabic',),
#  ('Dutch',),
#  ('French',),
#  ('German',),
#  ('Italian',),
#  ('Turkish',),
#  ('Adja',),
#  ('Aizo',),
#  ('Bariba',),
#  ('Fon',),
#  ('Ful',),
#  ('Joruba',),
#  ('Somba',),
#  ('Busansi',),
#  ('Dagara',),
#  ('Dyula',),
#  ('Ful',),
#  ('Gurma',),
#  ('Mossi',),
#  ('Bengali',),
#  ('Chakma',),
#  ('Garo',),
#  ('Khasi',),
#  ('Marma',),
#  ('Santhali',),
#  ('Tripuri',),
#  ('Bulgariana',),
#  ('Macedonian',),
#  ('Romani',),
#  ('Turkish',),
#  ('Arabic',),
#  ('English',),
#  ('Creole English',),
#  ('Creole French',),
#  ('Serbo-Croatian',),
#  ('Belorussian',),
#  ('Polish',),
#  ('Russian',),
#  ('Ukrainian',),
#  ('English',),
#  ('Garifuna',),
#  ('Maya Languages',),
#  ('Spanish',),
#  ('English',),
#  ('Aimará',),
#  ('Guaraní',),
#  ('Ketšua',),
#  ('Spanish',),
#  ('German',),
#  ('Indian Languages',),
#  ('Italian',),
#  ('Japanese',),
#  ('Portuguese',),
#  ('Bajan',),
#  ('English',),
#  ('Chinese',),
#  ('English',),
#  ('Malay',),
#  ('Malay-English',),
#  ('Asami',),
#  ('Dzongkha',),
#  ('Nepali',),
#  ('Khoekhoe',),
#  ('Ndebele',),
#  ('San',),
#  ('Shona',),
#  ('Tswana',),
#  ('Banda',),
#  ('Gbaya',),
#  ('Mandjia',),
#  ('Mbum',),
#  ('Ngbaka',),
#  ('Sara',),
#  ('Chinese',),
#  ('Dutch',),
#  ('English',),
#  ('Eskimo Languages',),
#  ('French',),
#  ('German',),
#  ('Italian',),
#  ('Polish',),
#  ('Portuguese',),
#  ('Punjabi',),
#  ('Spanish',),
#  ('Ukrainian',),
#  ('English',),
#  ('Malay',),
#  ('French',),
#  ('German',),
#  ('Italian',),
#  ('Romansh',),
#  ('Aimará',),
#  ('Araucan',),
#  ('Rapa nui',),
#  ('Spanish',),
#  ('Chinese',),
#  ('Dong',),
#  ('Hui',),
#  ('Mantšu',),
#  ('Miao',),
#  ('Mongolian',),
#  ('Puyi',),
#  ('Tibetan',),
#  ('Tujia',),
#  ('Uighur',),
#  ('Yi',),
#  ('Zhuang',),
#  ('Akan',),
#  ('Gur',),
#  ('Kru',),
#  ('Malinke',),
#  ('[South]Mande',),
#  ('Bamileke-bamum',),
#  ('Duala',),
#  ('Fang',),
#  ('Ful',),
#  ('Maka',),
#  ('Mandara',),
#  ('Masana',),
#  ('Tikar',),
#  ('Boa',),
#  ('Chokwe',),
#  ('Kongo',),
#  ('Luba',),
#  ('Mongo',),
#  ('Ngala and Bangi',),
#  ('Rundi',),
#  ('Rwanda',),
#  ('Teke',),
#  ('Zande',),
#  ('Kongo',),
#  ('Mbete',),
#  ('Mboshi',),
#  ('Punu',),
#  ('Sango',),
#  ('Teke',),
#  ('English',),
#  ('Maori',),
#  ('Arawakan',),
#  ('Caribbean',),
#  ('Chibcha',),
#  ('Creole English',),
#  ('Spanish',),
#  ('Comorian',),
#  ('Comorian-Arabic',),
#  ('Comorian-French',),
#  ('Comorian-madagassi',),
#  ('Comorian-Swahili',),
#  ('Crioulo',),
#  ('Portuguese',),
#  ('Chibcha',),
#  ('Chinese',),
#  ('Creole English',),
#  ('Spanish',),
#  ('Spanish',),
#  ('Chinese',),
#  ('English',),
#  ('English',),
#  ('Greek',),
#  ('Turkish',),
#  ('Czech',),
#  ('German',),
#  ('Hungarian',),
#  ('Moravian',),
#  ('Polish',),
#  ('Romani',),
#  ('Silesiana',),
#  ('Slovak',),
#  ('German',),
#  ('Greek',),
#  ('Italian',),
#  ('Polish',),
#  ('Southern Slavic Languages',),
#  ('Turkish',),
#  ('Afar',),
#  ('Arabic',),
#  ('Somali',),
#  ('Creole English',),
#  ('Creole French',),
#  ('Arabic',),
#  ('Danish',),
#  ('English',),
#  ('German',),
#  ('Norwegian',),
#  ('Swedish',),
#  ('Turkish',),
#  ('Creole French',),
#  ('Spanish',),
#  ('Arabic',),
#  ('Berberi',),
#  ('Ketšua',),
#  ('Spanish',),
#  ('Arabic',),
#  ('Sinaberberi',),
#  ('Afar',),
#  ('Bilin',),
#  ('Hadareb',),
#  ('Saho',),
#  ('Tigre',),
#  ('Tigrinja',),
#  ('Arabic',),
#  ('Basque',),
#  ('Catalan',),
#  ('Galecian',),
#  ('Spanish',),
#  ('Belorussian',),
#  ('Estonian',),
#  ('Finnish',),
#  ('Russian',),
#  ('Ukrainian',),
#  ('Amhara',),
#  ('Gurage',),
#  ('Oromo',),
#  ('Sidamo',),
#  ('Somali',),
#  ('Tigrinja',),
#  ('Walaita',),
#  ('Estonian',),
#  ('Finnish',),
#  ('Russian',),
#  ('Saame',),
#  ('Swedish',),
#  ('Fijian',),
#  ('Hindi',),
#  ('English',),
#  ('Arabic',),
#  ('French',),
#  ('Italian',),
#  ('Portuguese',),
#  ('Spanish',),
#  ('Turkish',),
#  ('Danish',),
#  ('Faroese',),
#  ('Kosrean',),
#  ('Mortlock',),
#  ('Pohnpei',),
#  ('Trukese',),
#  ('Wolea',),
#  ('Yap',),
#  ('Fang',),
#  ('Mbete',),
#  ('Mpongwe',),
#  ('Punu-sira-nzebi',),
#  ('English',),
#  ('Gaeli',),
#  ('Kymri',),
#  ('Abhyasi',),
#  ('Armenian',),
#  ('Azerbaijani',),
#  ('Georgiana',),
#  ('Osseetti',),
#  ('Russian',),
#  ('Akan',),
#  ('Ewe',),
#  ('Ga-adangme',),
#  ('Gurma',),
#  ('Joruba',),
#  ('Mossi',),
#  ('Arabic',),
#  ('English',),
#  ('Ful',),
#  ('Kissi',),
#  ('Kpelle',),
#  ('Loma',),
#  ('Malinke',),
#  ('Susu',),
#  ('Yalunka',),
#  ('Creole French',),
#  ('French',),
#  ('Diola',),
#  ('Ful',),
#  ('Malinke',),
#  ('Soninke',),
#  ('Wolof',),
#  ('Balante',),
#  ('Crioulo',),
#  ('Ful',),
#  ('Malinke',),
#  ('Mandyako',),
#  ('Portuguese',),
#  ('Bubi',),
#  ('Fang',),
#  ('Greek',),
#  ('Turkish',),
#  ('Creole English',),
#  ('Danish',),
#  ('Greenlandic',),
#  ('Cakchiquel',),
#  ('Kekchí',),
#  ('Mam',),
#  ('Quiché',),
#  ('Spanish',),
#  ('Creole French',),
#  ('Indian Languages',),
#  ('Chamorro',),
#  ('English',),
#  ('Japanese',),
#  ('Korean',),
#  ('Philippene Languages',),
#  ('Arawakan',),
#  ('Caribbean',),
#  ('Creole English',),
#  ('Canton Chinese',),
#  ('Chiu chau',),
#  ('English',),
#  ('Fukien',),
#  ('Hakka',),
#  ('Creole English',),
#  ('Garifuna',),
#  ('Miskito',),
#  ('Spanish',),
#  ('Serbo-Croatian',),
#  ('Slovene',),
#  ('French',),
#  ('Haiti Creole',),
#  ('German',),
#  ('Hungarian',),
#  ('Romani',),
#  ('Romanian',),
#  ('Serbo-Croatian',),
#  ('Slovak',),
#  ('Bali',),
#  ('Banja',),
#  ('Batakki',),
#  ('Bugi',),
#  ('Javanese',),
#  ('Madura',),
#  ('Malay',),
#  ('Minangkabau',),
#  ('Sunda',),
#  ('Asami',),
#  ('Bengali',),
#  ('Gujarati',),
#  ('Hindi',),
#  ('Kannada',),
#  ('Malajalam',),
#  ('Marathi',),
#  ('Orija',),
#  ('Punjabi',),
#  ('Tamil',),
#  ('Telugu',),
#  ('Urdu',),
#  ('English',),
#  ('Irish',),
#  ('Arabic',),
#  ('Azerbaijani',),
#  ('Bakhtyari',),
#  ('Balochi',),
#  ('Gilaki',),
#  ('Kurdish',),
#  ('Luri',),
#  ('Mazandarani',),
#  ('Persian',),
#  ('Turkmenian',),
#  ('Arabic',),
#  ('Assyrian',),
#  ('Azerbaijani',),
#  ('Kurdish',),
#  ('Persian',),
#  ('English',),
#  ('Icelandic',),
#  ('Arabic',),
#  ('Hebrew',),
#  ('Russian',),
#  ('Albaniana',),
#  ('French',),
#  ('Friuli',),
#  ('German',),
#  ('Italian',),
#  ('Romani',),
#  ('Sardinian',),
#  ('Slovene',),
#  ('Creole English',),
#  ('Hindi',),
#  ('Arabic',),
#  ('Armenian',),
#  ('Circassian',),
#  ('Ainu',),
#  ('Chinese',),
#  ('English',),
#  ('Japanese',),
#  ('Korean',),
#  ('Philippene Languages',),
#  ('German',),
#  ('Kazakh',),
#  ('Russian',),
#  ('Tatar',),
#  ('Ukrainian',),
#  ('Uzbek',),
#  ('Gusii',),
#  ('Kalenjin',),
#  ('Kamba',),
#  ('Kikuyu',),
#  ('Luhya',),
#  ('Luo',),
#  ('Masai',),
#  ('Meru',),
#  ('Nyika',),
#  ('Turkana',),
#  ('Kazakh',),
#  ('Kirgiz',),
#  ('Russian',),
#  ('Tadzhik',),
#  ('Tatar',),
#  ('Ukrainian',),
#  ('Uzbek',),
#  ('Chinese',),
#  ('Khmer',),
#  ('Tšam',),
#  ('Vietnamese',),
#  ('Kiribati',),
#  ('Tuvalu',),
#  ('Creole English',),
#  ('English',),
#  ('Chinese',),
#  ('Korean',),
#  ('Arabic',),
#  ('English',),
#  ('Lao',),
#  ('Lao-Soung',),
#  ('Mon-khmer',),
#  ('Thai',),
#  ('Arabic',),
#  ('Armenian',),
#  ('French',),
#  ('Bassa',),
#  ('Gio',),
#  ('Grebo',),
#  ('Kpelle',),
#  ('Kru',),
#  ('Loma',),
#  ('Malinke',),
#  ('Mano',),
#  ('Arabic',),
#  ('Berberi',),
#  ('Creole French',),
#  ('English',),
#  ('German',),
#  ('Italian',),
#  ('Turkish',),
#  ('Mixed Languages',),
#  ('Singali',),
#  ('Tamil',),
#  ('English',),
#  ('Sotho',),
#  ('Zulu',),
#  ('Belorussian',),
#  ('Lithuanian',),
#  ('Polish',),
#  ('Russian',),
#  ('Ukrainian',),
#  ('French',),
#  ('German',),
#  ('Italian',),
#  ('Luxembourgish',),
#  ('Portuguese',),
#  ('Belorussian',),
#  ('Latvian',),
#  ('Lithuanian',),
#  ('Polish',),
#  ('Russian',),
#  ('Ukrainian',),
#  ('Canton Chinese',),
#  ('English',),
#  ('Mandarin Chinese',),
#  ('Portuguese',),
#  ('Arabic',),
#  ('Berberi',),
#  ('English',),
#  ('French',),
#  ('Italian',),
#  ('Monegasque',),
#  ('Bulgariana',),
#  ('Gagauzi',),
#  ('Romanian',),
#  ('Russian',),
#  ('Ukrainian',),
#  ('French',),
#  ('Malagasy',),
#  ('Dhivehi',),
#  ('English',),
#  ('Mixtec',),
#  ('Náhuatl',),
#  ('Otomí',),
#  ('Spanish',),
#  ('Yucatec',),
#  ('Zapotec',),
#  ('English',),
#  ('Marshallese',),
#  ('Albaniana',),
#  ('Macedonian',),
#  ('Romani',),
#  ('Serbo-Croatian',),
#  ('Turkish',),
#  ('Bambara',),
#  ('Ful',),
#  ('Senufo and Minianka',),
#  ('Songhai',),
#  ('Soninke',),
#  ('Tamashek',),
#  ('English',),
#  ('Maltese',),
#  ('Burmese',),
#  ('Chin',),
#  ('Kachin',),
#  ('Karen',),
#  ('Kayah',),
#  ('Mon',),
#  ('Rakhine',),
#  ('Shan',),
#  ('Bajad',),
#  ('Buryat',),
#  ('Dariganga',),
#  ('Dorbet',),
#  ('Kazakh',),
#  ('Mongolian',),
#  ('Carolinian',),
#  ('Chamorro',),
#  ('Chinese',),
#  ('English',),
#  ('Korean',),
#  ('Philippene Languages',),
#  ('Chuabo',),
#  ('Lomwe',),
#  ('Makua',),
#  ('Marendje',),
#  ('Nyanja',),
#  ('Ronga',),
#  ('Sena',),
#  ('Shona',),
#  ('Tsonga',),
#  ('Tswa',),
#  ('Ful',),
#  ('Hassaniya',),
#  ('Soninke',),
#  ('Tukulor',),
#  ('Wolof',),
#  ('Zenaga',),
#  ('English',),
#  ('Creole French',),
#  ('French',),
#  ('Bhojpuri',),
#  ('Creole French',),
#  ('French',),
#  ('Hindi',),
#  ('Marathi',),
#  ('Tamil',),
#  ('Chichewa',),
#  ('Lomwe',),
#  ('Ngoni',),
#  ('Yao',),
#  ('Chinese',),
#  ('Dusun',),
#  ('English',),
#  ('Iban',),
#  ('Malay',),
#  ('Tamil',),
#  ('French',),
#  ('Mahoré',),
#  ('Malagasy',),
#  ('Afrikaans',),
#  ('Caprivi',),
#  ('German',),
#  ('Herero',),
#  ('Kavango',),
#  ('Nama',),
#  ('Ovambo',),
#  ('San',),
#  ('French',),
#  ('Malenasian Languages',),
#  ('Polynesian Languages',),
#  ('Ful',),
#  ('Hausa',),
#  ('Kanuri',),
#  ('Songhai-zerma',),
#  ('Tamashek',),
#  ('English',),
#  ('Bura',),
#  ('Edo',),
#  ('Ful',),
#  ('Hausa',),
#  ('Ibibio',),
#  ('Ibo',),
#  ('Ijo',),
#  ('Joruba',),
#  ('Kanuri',),
#  ('Tiv',),
#  ('Creole English',),
#  ('Miskito',),
#  ('Spanish',),
#  ('Sumo',),
#  ('English',),
#  ('Niue',),
#  ('Arabic',),
#  ('Dutch',),
#  ('Fries',),
#  ('Turkish',),
#  ('Danish',),
#  ('English',),
#  ('Norwegian',),
#  ('Saame',),
#  ('Swedish',),
#  ('Bhojpuri',),
#  ('Hindi',),
#  ('Maithili',),
#  ('Nepali',),
#  ('Newari',),
#  ('Tamang',),
#  ('Tharu',),
#  ('Chinese',),
#  ('English',),
#  ('Kiribati',),
#  ('Nauru',),
#  ('Tuvalu',),
#  ('English',),
#  ('Maori',),
#  ('Arabic',),
#  ('Balochi',),
#  ('Balochi',),
#  ('Brahui',),
#  ('Hindko',),
#  ('Pashto',),
#  ('Punjabi',),
#  ('Saraiki',),
#  ('Sindhi',),
#  ('Urdu',),
#  ('Arabic',),
#  ('Creole English',),
#  ('Cuna',),
#  ('Embera',),
#  ('Guaymí',),
#  ('Spanish',),
#  ('Pitcairnese',),
#  ('Aimará',),
#  ('Ketšua',),
#  ('Spanish',),
#  ('Bicol',),
#  ('Cebuano',),
#  ('Hiligaynon',),
#  ('Ilocano',),
#  ('Maguindanao',),
#  ('Maranao',),
#  ('Pampango',),
#  ('Pangasinan',),
#  ('Pilipino',),
#  ('Waray-waray',),
#  ('Chinese',),
#  ('English',),
#  ('Palau',),
#  ('Philippene Languages',),
#  ('Malenasian Languages',),
#  ('Papuan Languages',),
#  ('Belorussian',),
#  ('German',),
#  ('Polish',),
#  ('Ukrainian',),
#  ('English',),
#  ('Spanish',),
#  ('Chinese',),
#  ('Korean',),
#  ('Portuguese',),
#  ('German',),
#  ('Guaraní',),
#  ('Portuguese',),
#  ('Spanish',),
#  ('Arabic',),
#  ('Hebrew',),
#  ('Chinese',),
#  ('French',),
#  ('Tahitian',),
#  ('Arabic',),
#  ('Urdu',),
#  ('Chinese',),
#  ('Comorian',),
#  ('Creole French',),
#  ('Malagasy',),
#  ('Tamil',),
#  ('German',),
#  ('Hungarian',),
#  ('Romani',),
#  ('Romanian',),
#  ('Serbo-Croatian',),
#  ('Ukrainian',),
#  ('Avarian',),
#  ('Bashkir',),
#  ('Belorussian',),
#  ('Chechen',),
#  ('Chuvash',),
#  ('Kazakh',),
#  ('Mari',),
#  ('Mordva',),
#  ('Russian',),
#  ('Tatar',),
#  ('Udmur',),
#  ('Ukrainian',),
#  ('French',),
#  ('Rwanda',),
#  ('Arabic',),
#  ('Arabic',),
#  ('Bari',),
#  ('Beja',),
#  ('Chilluk',),
#  ('Dinka',),
#  ('Fur',),
#  ('Lotuko',),
#  ('Nubian Languages',),
#  ('Nuer',),
#  ('Zande',),
#  ('Diola',),
#  ('Ful',),
#  ('Malinke',),
#  ('Serer',),
#  ('Soninke',),
#  ('Wolof',),
#  ('Chinese',),
#  ('Malay',),
#  ('Tamil',),
#  ('English',),
#  ('Norwegian',),
#  ('Russian',),
#  ('Malenasian Languages',),
#  ('Papuan Languages',),
#  ('Polynesian Languages',),
#  ('Bullom-sherbro',),
#  ('Ful',),
#  ('Kono-vai',),
#  ('Kuranko',),
#  ('Limba',),
#  ('Mende',),
#  ('Temne',),
#  ('Yalunka',),
#  ('Nahua',),
#  ('Spanish',),
#  ('Italian',),
#  ('Arabic',),
#  ('Somali',),
#  ('French',),
#  ('Crioulo',),
#  ('French',),
#  ('Hindi',),
#  ('Sranantonga',),
#  ('Czech and Moravian',),
#  ('Hungarian',),
#  ('Romani',),
#  ('Slovak',),
#  ('Ukrainian and Russian',),
#  ('Hungarian',),
#  ('Serbo-Croatian',),
#  ('Slovene',),
#  ('Arabic',),
#  ('Finnish',),
#  ('Norwegian',),
#  ('Southern Slavic Languages',),
#  ('Spanish',),
#  ('Swedish',),
#  ('Swazi',),
#  ('Zulu',),
#  ('English',),
#  ('French',),
#  ('Seselwa',),
#  ('Arabic',),
#  ('Kurdish',),
#  ('English',),
#  ('Arabic',),
#  ('Gorane',),
#  ('Hadjarai',),
#  ('Kanem-bornu',),
#  ('Mayo-kebbi',),
#  ('Ouaddai',),
#  ('Sara',),
#  ('Tandjile',),
#  ('Ane',),
#  ('Ewe',),
#  ('Gurma',),
#  ('Kabyé',),
#  ('Kotokoli',),
#  ('Moba',),
#  ('Naudemba',),
#  ('Watyi',),
#  ('Chinese',),
#  ('Khmer',),
#  ('Kuy',),
#  ('Lao',),
#  ('Malay',),
#  ('Thai',),
#  ('Russian',),
#  ('Tadzhik',),
#  ('Uzbek',),
#  ('English',),
#  ('Tokelau',),
#  ('Kazakh',),
#  ('Russian',),
#  ('Turkmenian',),
#  ('Uzbek',),
#  ('Portuguese',),
#  ('Sunda',),
#  ('English',),
#  ('Tongan',),
#  ('Creole English',),
#  ('English',),
#  ('Hindi',),
#  ('Arabic',),
#  ('Arabic-French',),
#  ('Arabic-French-English',),
#  ('Arabic',),
#  ('Kurdish',),
#  ('Turkish',),
#  ('English',),
#  ('Kiribati',),
#  ('Tuvalu',),
#  ('Ami',),
#  ('Atayal',),
#  ('Hakka',),
#  ('Mandarin Chinese',),
#  ('Min',),
#  ('Paiwan',),
#  ('Chaga and Pare',),
#  ('Gogo',),
#  ('Ha',),
#  ('Haya',),
#  ('Hehet',),
#  ('Luguru',),
#  ('Makonde',),
#  ('Nyakusa',),
#  ('Nyamwesi',),
#  ('Shambala',),
#  ('Swahili',),
#  ('Acholi',),
#  ('Ganda',),
#  ('Gisu',),
#  ('Kiga',),
#  ('Lango',),
#  ('Lugbara',),
#  ('Nkole',),
#  ('Rwanda',),
#  ('Soga',),
#  ('Teso',),
#  ('Belorussian',),
#  ('Bulgariana',),
#  ('Hungarian',),
#  ('Polish',),
#  ('Romanian',),
#  ('Russian',),
#  ('Ukrainian',),
#  ('English',),
#  ('Spanish',),
#  ('Chinese',),
#  ('English',),
#  ('French',),
#  ('German',),
#  ('Italian',),
#  ('Japanese',),
#  ('Korean',),
#  ('Polish',),
#  ('Portuguese',),
#  ('Spanish',),
#  ('Tagalog',),
#  ('Vietnamese',),
#  ('Karakalpak',),
#  ('Kazakh',),
#  ('Russian',),
#  ('Tadzhik',),
#  ('Tatar',),
#  ('Uzbek',),
#  ('Italian',),
#  ('Creole English',),
#  ('English',),
#  ('Goajiro',),
#  ('Spanish',),
#  ('Warrau',),
#  ('English',),
#  ('English',),
#  ('French',),
#  ('Spanish',),
#  ('Chinese',),
#  ('Khmer',),
#  ('Man',),
#  ('Miao',),
#  ('Muong',),
#  ('Nung',),
#  ('Thai',),
#  ('Tho',),
#  ('Vietnamese',),
#  ('Bislama',),
#  ('English',),
#  ('French',),
#  ('Futuna',),
#  ('Wallis',),
#  ('English',),
#  ('Samoan',),
#  ('Samoan-English',),
#  ('Arabic',),
#  ('Soqutri',),
#  ('Albaniana',),
#  ('Hungarian',),
#  ('Macedonian',),
#  ('Romani',),
#  ('Serbo-Croatian',),
#  ('Slovak',),
#  ('Afrikaans',),
#  ('English',),
#  ('Ndebele',),
#  ('Northsotho',),
#  ('Southsotho',),
#  ('Swazi',),
#  ('Tsonga',),
#  ('Tswana',),
#  ('Venda',),
#  ('Xhosa',),
#  ('Zulu',),
#  ('Bemba',),
#  ('Chewa',),
#  ('Lozi',),
#  ('Nsenga',),
#  ('Nyanja',),
#  ('Tongan',),
#  ('English',),
#  ('Ndebele',),
#  ('Nyanja',),
#  ('Shona',)]

# %% [markdown]
# ## SELECT

# %% [markdown]
# **TASK**: Select **all** columns from the `City` table

# %%
# %sql SELECT * FROM City
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 3427 rows affected.
# [(1.0, 'Kabul', 'AFG', 'Kabol', 1780000.0),
#  (2.0, 'Qandahar', 'AFG', 'Qandahar', 237500.0),
#  (3.0, 'Herat', 'AFG', 'Herat', 186800.0),
#  (4.0, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800.0),
#  (5.0, 'Amsterdam', 'NLD', 'Noord-Holland', 731200.0),
#  (6.0, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321.0),
#  (7.0, 'Haag', 'NLD', 'Zuid-Holland', 440900.0),
#  (8.0, 'Utrecht', 'NLD', 'Utrecht', 234323.0),
#  (9.0, 'Eindhoven', 'NLD', 'Noord-Brabant', 201843.0),
#  (10.0, 'Tilburg', 'NLD', 'Noord-Brabant', 193238.0),
#  (11.0, 'Groningen', 'NLD', 'Groningen', 172701.0),
#  (12.0, 'Breda', 'NLD', 'Noord-Brabant', 160398.0),
#  (13.0, 'Apeldoorn', 'NLD', 'Gelderland', 153491.0),
#  (14.0, 'Nijmegen', 'NLD', 'Gelderland', 152463.0),
#  (15.0, 'Enschede', 'NLD', 'Overijssel', 149544.0),
#  (16.0, 'Haarlem', 'NLD', 'Noord-Holland', 148772.0),
#  (17.0, 'Almere', 'NLD', 'Flevoland', 142465.0),
#  (18.0, 'Arnhem', 'NLD', 'Gelderland', 138020.0),
#  (19.0, 'Zaanstad', 'NLD', 'Noord-Holland', 135621.0),
#  (21.0, 'Amersfoort', 'NLD', 'Utrecht', 126270.0),
#  (22.0, 'Maastricht', 'NLD', 'Limburg', 122087.0),
#  (23.0, 'Dordrecht', 'NLD', 'Zuid-Holland', 119811.0),
#  (24.0, 'Leiden', 'NLD', 'Zuid-Holland', 117196.0),
#  (25.0, 'Haarlemmermeer', 'NLD', 'Noord-Holland', 110722.0),
#  (26.0, 'Zoetermeer', 'NLD', 'Zuid-Holland', 110214.0),
#  (27.0, 'Emmen', 'NLD', 'Drenthe', 105853.0),
#  (28.0, 'Zwolle', 'NLD', 'Overijssel', 105819.0),
#  (29.0, 'Ede', 'NLD', 'Gelderland', 101574.0),
#  (30.0, 'Delft', 'NLD', 'Zuid-Holland', 95268.0),
#  (31.0, 'Heerlen', 'NLD', 'Limburg', 95052.0),
#  (32.0, 'Alkmaar', 'NLD', 'Noord-Holland', 92713.0),
#  (34.0, 'Tirana', 'ALB', 'Tirana', 270000.0),
#  (35.0, 'Alger', 'DZA', 'Alger', 2168000.0),
#  (36.0, 'Oran', 'DZA', 'Oran', 609823.0),
#  (37.0, 'Constantine', 'DZA', 'Constantine', 443727.0),
#  (38.0, 'Annaba', 'DZA', 'Annaba', 222518.0),
#  (39.0, 'Batna', 'DZA', 'Batna', 183377.0),
#  (42.0, 'Skikda', 'DZA', 'Skikda', 128747.0),
#  (43.0, 'Biskra', 'DZA', 'Biskra', 128281.0),
#  (44.0, 'Blida (el-Boulaida)', 'DZA', 'Blida', 127284.0),
#  (46.0, 'Mostaganem', 'DZA', 'Mostaganem', 115212.0),
#  (48.0, 'Tlemcen (Tilimsen)', 'DZA', 'Tlemcen', 110242.0),
#  (50.0, 'Tiaret', 'DZA', 'Tiaret', 100118.0),
#  (51.0, 'Ech-Chleff (el-Asnam)', 'DZA', 'Chlef', 96794.0),
#  (53.0, 'Tafuna', 'ASM', 'Tutuila', 5200.0),
#  (54.0, 'Fagatogo', 'ASM', 'Tutuila', 2323.0),
#  (55.0, 'Andorra la Vella', 'AND', 'Andorra la Vella', 21189.0),
#  (56.0, 'Luanda', 'AGO', 'Luanda', 2022000.0),
#  (57.0, 'Huambo', 'AGO', 'Huambo', 163100.0),
#  (58.0, 'Lobito', 'AGO', 'Benguela', 130000.0),
#  (59.0, 'Benguela', 'AGO', 'Benguela', 128300.0),
#  (60.0, 'Namibe', 'AGO', 'Namibe', 118200.0),
#  (64.0, 'Dubai', 'ARE', 'Dubai', 669181.0),
#  (65.0, 'Abu Dhabi', 'ARE', 'Abu Dhabi', 398695.0),
#  (66.0, 'Sharja', 'ARE', 'Sharja', 320095.0),
#  (67.0, 'al-Ayn', 'ARE', 'Abu Dhabi', 225970.0),
#  (68.0, 'Ajman', 'ARE', 'Ajman', 114395.0),
#  (69.0, 'Buenos Aires', 'ARG', 'Distrito Federal', 2982146.0),
#  (70.0, 'La Matanza', 'ARG', 'Buenos Aires', 1266461.0),
#  (73.0, 'Lomas de Zamora', 'ARG', 'Buenos Aires', 622013.0),
#  (74.0, 'Quilmes', 'ARG', 'Buenos Aires', 559249.0),
#  (75.0, 'Almirante Brown', 'ARG', 'Buenos Aires', 538918.0),
#  (76.0, 'La Plata', 'ARG', 'Buenos Aires', 521936.0),
#  (77.0, 'Mar del Plata', 'ARG', 'Buenos Aires', 512880.0),
#  (80.0, 'Merlo', 'ARG', 'Buenos Aires', 463846.0),
#  (82.0, 'Salta', 'ARG', 'Salta', 367550.0),
#  (83.0, 'Moreno', 'ARG', 'Buenos Aires', 356993.0),
#  (85.0, 'Avellaneda', 'ARG', 'Buenos Aires', 353046.0),
#  (86.0, 'Tres de Febrero', 'ARG', 'Buenos Aires', 352311.0),
#  (88.0, 'Florencio Varela', 'ARG', 'Buenos Aires', 315432.0),
#  (89.0, 'San Isidro', 'ARG', 'Buenos Aires', 306341.0),
#  (90.0, 'Tigre', 'ARG', 'Buenos Aires', 296226.0),
#  (91.0, 'Malvinas Argentinas', 'ARG', 'Buenos Aires', 290335.0),
#  (93.0, 'Berazategui', 'ARG', 'Buenos Aires', 276916.0),
#  (94.0, 'Corrientes', 'ARG', 'Corrientes', 258103.0),
#  (95.0, 'San Miguel', 'ARG', 'Buenos Aires', 248700.0),
#  (98.0, 'Resistencia', 'ARG', 'Chaco', 229212.0),
#  (101.0, 'Godoy Cruz', 'ARG', 'Mendoza', 206998.0),
#  (102.0, 'Posadas', 'ARG', 'Misiones', 201273.0),
#  (104.0, 'Santiago del Estero', 'ARG', 'Santiago del Estero', 189947.0),
#  (105.0, 'San Salvador de Jujuy', 'ARG', 'Jujuy', 178748.0),
#  (106.0, 'Hurlingham', 'ARG', 'Buenos Aires', 170028.0),
#  (109.0, 'San Fernando', 'ARG', 'Buenos Aires', 153036.0),
#  (110.0, 'Formosa', 'ARG', 'Formosa', 147636.0),
#  (111.0, 'Las Heras', 'ARG', 'Mendoza', 145823.0),
#  (112.0, 'La Rioja', 'ARG', 'La Rioja', 138117.0),
#  (113.0, 'San Fernando del Valle de Cata', 'ARG', 'Catamarca', 134935.0),
#  (115.0, 'Comodoro Rivadavia', 'ARG', 'Chubut', 124104.0),
#  (116.0, 'Mendoza', 'ARG', 'Mendoza', 123027.0),
#  (118.0, 'San Juan', 'ARG', 'San Juan', 119152.0),
#  (119.0, 'Escobar', 'ARG', 'Buenos Aires', 116675.0),
#  (120.0, 'Concordia', 'ARG', 'Entre Rios', 116485.0),
#  (121.0, 'Pilar', 'ARG', 'Buenos Aires', 113428.0),
#  (122.0, 'San Luis', 'ARG', 'San Luis', 110136.0),
#  (123.0, 'Ezeiza', 'ARG', 'Buenos Aires', 99578.0),
#  (124.0, 'San Rafael', 'ARG', 'Mendoza', 94651.0),
#  (125.0, 'Tandil', 'ARG', 'Buenos Aires', 91101.0),
#  (126.0, 'Yerevan', 'ARM', 'Yerevan', 1248700.0),
#  (128.0, 'Vanadzor', 'ARM', 'Lori', 172700.0),
#  (130.0, 'Sydney', 'AUS', 'New South Wales', 3276207.0),
#  (131.0, 'Melbourne', 'AUS', 'Victoria', 2865329.0),
#  (132.0, 'Brisbane', 'AUS', 'Queensland', 1291117.0),
#  (133.0, 'Perth', 'AUS', 'West Australia', 1096829.0),
#  (134.0, 'Adelaide', 'AUS', 'South Australia', 978100.0),
#  (135.0, 'Canberra', 'AUS', 'Capital Region', 322723.0),
#  (136.0, 'Gold Coast', 'AUS', 'Queensland', 311932.0),
#  (137.0, 'Newcastle', 'AUS', 'New South Wales', 270324.0),
#  (138.0, 'Central Coast', 'AUS', 'New South Wales', 227657.0),
#  (139.0, 'Wollongong', 'AUS', 'New South Wales', 219761.0),
#  (140.0, 'Hobart', 'AUS', 'Tasmania', 126118.0),
#  (141.0, 'Geelong', 'AUS', 'Victoria', 125382.0),
#  (142.0, 'Townsville', 'AUS', 'Queensland', 109914.0),
#  (143.0, 'Cairns', 'AUS', 'Queensland', 92273.0),
#  (144.0, 'Baku', 'AZE', 'Baki', 1787800.0),
#  (146.0, 'Sumqayit', 'AZE', 'Sumqayit', 283000.0),
#  (148.0, 'Nassau', 'BHS', 'New Providence', 172000.0),
#  (149.0, 'al-Manama', 'BHR', 'al-Manama', 148000.0),
#  (150.0, 'Dhaka', 'BGD', 'Dhaka', 3612850.0),
#  (151.0, 'Chittagong', 'BGD', 'Chittagong', 1392860.0),
#  (152.0, 'Khulna', 'BGD', 'Khulna', 663340.0),
#  (153.0, 'Rajshahi', 'BGD', 'Rajshahi', 294056.0),
#  (154.0, 'Narayanganj', 'BGD', 'Dhaka', 202134.0),
#  (155.0, 'Rangpur', 'BGD', 'Rajshahi', 191398.0),
#  (156.0, 'Mymensingh', 'BGD', 'Dhaka', 188713.0),
#  (157.0, 'Barisal', 'BGD', 'Barisal', 170232.0),
#  (158.0, 'Tungi', 'BGD', 'Dhaka', 168702.0),
#  (159.0, 'Jessore', 'BGD', 'Khulna', 139710.0),
#  (160.0, 'Comilla', 'BGD', 'Chittagong', 135313.0),
#  (161.0, 'Nawabganj', 'BGD', 'Rajshahi', 130577.0),
#  (162.0, 'Dinajpur', 'BGD', 'Rajshahi', 127815.0),
#  (163.0, 'Bogra', 'BGD', 'Rajshahi', 120170.0),
#  (164.0, 'Sylhet', 'BGD', 'Sylhet', 117396.0),
#  (165.0, 'Brahmanbaria', 'BGD', 'Chittagong', 109032.0),
#  (166.0, 'Tangail', 'BGD', 'Dhaka', 106004.0),
#  (167.0, 'Jamalpur', 'BGD', 'Dhaka', 103556.0),
#  (168.0, 'Pabna', 'BGD', 'Rajshahi', 103277.0),
#  (169.0, 'Naogaon', 'BGD', 'Rajshahi', 101266.0),
#  (170.0, 'Sirajganj', 'BGD', 'Rajshahi', 99669.0),
#  (171.0, 'Narsinghdi', 'BGD', 'Dhaka', 98342.0),
#  (172.0, 'Saidpur', 'BGD', 'Rajshahi', 96777.0),
#  (173.0, 'Gazipur', 'BGD', 'Dhaka', 96717.0),
#  (174.0, 'Bridgetown', 'BRB', 'St Michael', 6070.0),
#  (175.0, 'Antwerpen', 'BEL', 'Antwerpen', 446525.0),
#  (176.0, 'Gent', 'BEL', 'East Flanderi', 224180.0),
#  (177.0, 'Charleroi', 'BEL', 'Hainaut', 200827.0),
#  (179.0, 'Bruxelles [Brussel]', 'BEL', 'Bryssel', 133859.0),
#  (180.0, 'Brugge', 'BEL', 'West Flanderi', 116246.0),
#  (181.0, 'Schaerbeek', 'BEL', 'Bryssel', 105692.0),
#  (182.0, 'Namur', 'BEL', 'Namur', 105419.0),
#  (183.0, 'Mons', 'BEL', 'Hainaut', 90935.0),
#  (184.0, 'Belize City', 'BLZ', 'Belize City', 55810.0),
#  (185.0, 'Belmopan', 'BLZ', 'Cayo', 7105.0),
#  (186.0, 'Cotonou', 'BEN', 'Atlantique', 536827.0),
#  (188.0, 'Djougou', 'BEN', 'Atacora', 134099.0),
#  (189.0, 'Parakou', 'BEN', 'Borgou', 103577.0),
#  (191.0, 'Hamilton', 'BMU', 'Hamilton', 1200.0),
#  (192.0, 'Thimphu', 'BTN', 'Thimphu', 22000.0),
#  (193.0, 'Santa Cruz de la Sierra', 'BOL', 'Santa Cruz', 935361.0),
#  (194.0, 'La Paz', 'BOL', 'La Paz', 758141.0),
#  (195.0, 'El Alto', 'BOL', 'La Paz', 534466.0),
#  (196.0, 'Cochabamba', 'BOL', 'Cochabamba', 482800.0),
#  (197.0, 'Oruro', 'BOL', 'Oruro', 223553.0),
#  (198.0, 'Sucre', 'BOL', 'Chuquisaca', 178426.0),
#  (200.0, 'Tarija', 'BOL', 'Tarija', 125255.0),
#  (201.0, 'Sarajevo', 'BIH', 'Federaatio', 360000.0),
#  (202.0, 'Banja Luka', 'BIH', 'Republika Srpska', 143079.0),
#  (203.0, 'Zenica', 'BIH', 'Federaatio', 96027.0),
#  (204.0, 'Gaborone', 'BWA', 'Gaborone', 213017.0),
#  (205.0, 'Francistown', 'BWA', 'Francistown', 101805.0),
#  (207.0, 'Rio de Janeiro', 'BRA', 'Rio de Janeiro', 5598953.0),
#  (208.0, 'Salvador', 'BRA', 'Bahia', 2302832.0),
#  (209.0, 'Belo Horizonte', 'BRA', 'Minas Gerais', 2139125.0),
#  (213.0, 'Recife', 'BRA', 'Pernambuco', 1378087.0),
#  (214.0, 'Porto Alegre', 'BRA', 'Rio Grande do Sul', 1314032.0),
#  (215.0, 'Manaus', 'BRA', 'Amazonas', 1255049.0),
#  (224.0, 'Duque de Caxias', 'BRA', 'Rio de Janeiro', 746758.0),
#  (227.0, 'Natal', 'BRA', 'Rio Grande do Norte', 688955.0),
#  (229.0, 'Campo Grande', 'BRA', 'Mato Grosso do Sul', 649593.0),
#  (233.0, 'Contagem', 'BRA', 'Minas Gerais', 520801.0),
#  (236.0, 'Feira de Santana', 'BRA', 'Bahia', 479992.0),
#  (241.0, 'Juiz de Fora', 'BRA', 'Minas Gerais', 450288.0),
#  (242.0, 'Aracaju', 'BRA', 'Sergipe', 445555.0),
#  (245.0, 'Joinville', 'BRA', 'Santa Catarina', 428011.0),
#  (246.0, 'Belford Roxo', 'BRA', 'Rio de Janeiro', 425194.0),
#  (249.0, 'Campos dos Goytacazes', 'BRA', 'Rio de Janeiro', 398418.0),
#  (252.0, 'Olinda', 'BRA', 'Pernambuco', 354732.0),
#  (255.0, 'Caxias do Sul', 'BRA', 'Rio Grande do Sul', 349581.0),
#  (262.0, 'Pelotas', 'BRA', 'Rio Grande do Sul', 315415.0),
#  (266.0, 'Betim', 'BRA', 'Minas Gerais', 302108.0),
#  (268.0, 'Canoas', 'BRA', 'Rio Grande do Sul', 294125.0),
#  (272.0, 'Montes Claros', 'BRA', 'Minas Gerais', 286058.0),
#  (279.0, 'Rio Branco', 'BRA', 'Acre', 259537.0),
#  (284.0, 'Uberaba', 'BRA', 'Minas Gerais', 249225.0),
#  (285.0, 'Paulista', 'BRA', 'Pernambuco', 248473.0),
#  (287.0, 'Blumenau', 'BRA', 'Santa Catarina', 244379.0),
#  (288.0, 'Caruaru', 'BRA', 'Pernambuco', 244247.0),
#  (290.0, 'Volta Redonda', 'BRA', 'Rio de Janeiro', 240315.0),
#  (291.0, 'Novo Hamburgo', 'BRA', 'Rio Grande do Sul', 239940.0),
#  (293.0, 'Santa Maria', 'BRA', 'Rio Grande do Sul', 238473.0),
#  (297.0, 'Governador Valadares', 'BRA', 'Minas Gerais', 231724.0),
#  (304.0, 'Petrolina', 'BRA', 'Pernambuco', 210540.0),
#  (307.0, 'Ipatinga', 'BRA', 'Minas Gerais', 206338.0),
#  (308.0, 'Juazeiro', 'BRA', 'Bahia', 201073.0),
#  (320.0, 'Sete Lagoas', 'BRA', 'Minas Gerais', 182984.0),
#  (321.0, 'Rio Grande', 'BRA', 'Rio Grande do Sul', 182222.0),
#  (322.0, 'Itabuna', 'BRA', 'Bahia', 182148.0),
#  (324.0, 'Arapiraca', 'BRA', 'Alagoas', 178988.0),
#  (327.0, 'Alvorada', 'BRA', 'Rio Grande do Sul', 175574.0),
#  (331.0, 'Nova Friburgo', 'BRA', 'Rio de Janeiro', 170697.0),
#  (334.0, 'Barra Mansa', 'BRA', 'Rio de Janeiro', 168953.0),
#  (338.0, 'Boa Vista', 'BRA', 'Roraima', 167185.0),
#  (339.0, 'Passo Fundo', 'BRA', 'Rio Grande do Sul', 166343.0),
#  (340.0, 'Dourados', 'BRA', 'Mato Grosso do Sul', 164716.0),
#  (341.0, 'Santa Luzia', 'BRA', 'Minas Gerais', 164704.0),
#  (350.0, 'Cabo de Santo Agostinho', 'BRA', 'Pernambuco', 149964.0),
#  (356.0, 'Lages', 'BRA', 'Santa Catarina', 139570.0),
#  (363.0, 'Nossa Senhora do Socorro', 'BRA', 'Sergipe', 131351.0),
#  (367.0, 'Barreiras', 'BRA', 'Bahia', 127801.0),
#  (369.0, 'Alagoinhas', 'BRA', 'Bahia', 126820.0),
#  (371.0, 'Uruguaiana', 'BRA', 'Rio Grande do Sul', 126305.0),
#  (379.0, 'Palmas', 'BRA', 'Tocantins', 121919.0),
#  (383.0, 'Sapucaia do Sul', 'BRA', 'Rio Grande do Sul', 120217.0),
#  (384.0, 'Cabo Frio', 'BRA', 'Rio de Janeiro', 119503.0),
#  (386.0, 'Patos de Minas', 'BRA', 'Minas Gerais', 119262.0),
#  (387.0, 'Camaragibe', 'BRA', 'Pernambuco', 118968.0),
#  (389.0, 'Queimados', 'BRA', 'Rio de Janeiro', 115020.0),
#  (391.0, 'Garanhuns', 'BRA', 'Pernambuco', 114603.0),
#  (394.0, 'Barbacena', 'BRA', 'Minas Gerais', 113079.0),
#  (397.0, 'Lauro de Freitas', 'BRA', 'Bahia', 109236.0),
#  (399.0, 'Teixeira de Freitas', 'BRA', 'Bahia', 108441.0),
#  (400.0, 'Varginha', 'BRA', 'Minas Gerais', 108314.0),
#  (407.0, 'Santa Cruz do Sul', 'BRA', 'Rio Grande do Sul', 106734.0),
#  (412.0, 'Cachoeirinha', 'BRA', 'Rio Grande do Sul', 103240.0),
#  (416.0, 'Itabira', 'BRA', 'Minas Gerais', 102217.0),
#  (419.0, 'Resende', 'BRA', 'Rio de Janeiro', 100627.0),
#  (421.0, 'Pouso Alegre', 'BRA', 'Minas Gerais', 100028.0),
#  (424.0, 'Passos', 'BRA', 'Minas Gerais', 98570.0),
#  (425.0, 'Araguari', 'BRA', 'Minas Gerais', 98399.0),
#  (429.0, 'Conselheiro Lafaiete', 'BRA', 'Minas Gerais', 97507.0),
#  (430.0, 'Paulo Afonso', 'BRA', 'Bahia', 97291.0),
#  (431.0, 'Angra dos Reis', 'BRA', 'Rio de Janeiro', 96864.0),
#  (435.0, 'Parnamirim', 'BRA', 'Rio Grande do Norte', 96210.0),
#  (436.0, 'Jacobina', 'BRA', 'Bahia', 96131.0),
#  (437.0, 'Coronel Fabriciano', 'BRA', 'Minas Gerais', 95933.0),
#  (445.0, 'Santana do Livramento', 'BRA', 'Rio Grande do Sul', 91779.0),
#  (449.0, 'Ituiutaba', 'BRA', 'Minas Gerais', 90507.0),
#  (456.0, 'London', 'GBR', 'England', 7285000.0),
#  (457.0, 'Birmingham', 'GBR', 'England', 1013000.0),
#  (458.0, 'Glasgow', 'GBR', 'Scotland', 619680.0),
#  (459.0, 'Liverpool', 'GBR', 'England', 461000.0),
#  (460.0, 'Edinburgh', 'GBR', 'Scotland', 450180.0),
#  (461.0, 'Sheffield', 'GBR', 'England', 431607.0),
#  (462.0, 'Manchester', 'GBR', 'England', 430000.0),
#  (463.0, 'Leeds', 'GBR', 'England', 424194.0),
#  (464.0, 'Bristol', 'GBR', 'England', 402000.0),
#  (465.0, 'Cardiff', 'GBR', 'Wales', 321000.0),
#  (466.0, 'Coventry', 'GBR', 'England', 304000.0),
#  (467.0, 'Leicester', 'GBR', 'England', 294000.0),
#  (468.0, 'Bradford', 'GBR', 'England', 289376.0),
#  (469.0, 'Belfast', 'GBR', 'North Ireland', 287500.0),
#  (470.0, 'Nottingham', 'GBR', 'England', 287000.0),
#  (471.0, 'Kingston upon Hull', 'GBR', 'England', 262000.0),
#  (472.0, 'Plymouth', 'GBR', 'England', 253000.0),
#  (473.0, 'Stoke-on-Trent', 'GBR', 'England', 252000.0),
#  (474.0, 'Wolverhampton', 'GBR', 'England', 242000.0),
#  (475.0, 'Derby', 'GBR', 'England', 236000.0),
#  (476.0, 'Swansea', 'GBR', 'Wales', 230000.0),
#  (477.0, 'Southampton', 'GBR', 'England', 216000.0),
#  (478.0, 'Aberdeen', 'GBR', 'Scotland', 213070.0),
#  (479.0, 'Northampton', 'GBR', 'England', 196000.0),
#  (480.0, 'Dudley', 'GBR', 'England', 192171.0),
#  (481.0, 'Portsmouth', 'GBR', 'England', 190000.0),
#  (482.0, 'Newcastle upon Tyne', 'GBR', 'England', 189150.0),
#  (483.0, 'Sunderland', 'GBR', 'England', 183310.0),
#  (484.0, 'Luton', 'GBR', 'England', 183000.0),
#  (485.0, 'Swindon', 'GBR', 'England', 180000.0),
#  (486.0, 'Southend-on-Sea', 'GBR', 'England', 176000.0),
#  (487.0, 'Walsall', 'GBR', 'England', 174739.0),
#  (488.0, 'Bournemouth', 'GBR', 'England', 162000.0),
#  (489.0, 'Peterborough', 'GBR', 'England', 156000.0),
#  (490.0, 'Brighton', 'GBR', 'England', 156124.0),
#  (491.0, 'Blackpool', 'GBR', 'England', 151000.0),
#  (492.0, 'Dundee', 'GBR', 'Scotland', 146690.0),
#  (493.0, 'West Bromwich', 'GBR', 'England', 146386.0),
#  (494.0, 'Reading', 'GBR', 'England', 148000.0),
#  (495.0, 'Oldbury/Smethwick (Warley)', 'GBR', 'England', 145542.0),
#  (496.0, 'Middlesbrough', 'GBR', 'England', 145000.0),
#  (497.0, 'Huddersfield', 'GBR', 'England', 143726.0),
#  (498.0, 'Oxford', 'GBR', 'England', 144000.0),
#  (499.0, 'Poole', 'GBR', 'England', 141000.0),
#  (500.0, 'Bolton', 'GBR', 'England', 139020.0),
#  (501.0, 'Blackburn', 'GBR', 'England', 140000.0),
#  (502.0, 'Newport', 'GBR', 'Wales', 139000.0),
#  (503.0, 'Preston', 'GBR', 'England', 135000.0),
#  (504.0, 'Stockport', 'GBR', 'England', 132813.0),
#  (505.0, 'Norwich', 'GBR', 'England', 124000.0),
#  (506.0, 'Rotherham', 'GBR', 'England', 121380.0),
#  (507.0, 'Cambridge', 'GBR', 'England', 121000.0),
#  (508.0, 'Watford', 'GBR', 'England', 113080.0),
#  (509.0, 'Ipswich', 'GBR', 'England', 114000.0),
#  (510.0, 'Slough', 'GBR', 'England', 112000.0),
#  (511.0, 'Exeter', 'GBR', 'England', 111000.0),
#  (512.0, 'Cheltenham', 'GBR', 'England', 106000.0),
#  (513.0, 'Gloucester', 'GBR', 'England', 107000.0),
#  (514.0, 'Saint Helens', 'GBR', 'England', 106293.0),
#  (515.0, 'Sutton Coldfield', 'GBR', 'England', 106001.0),
#  (516.0, 'York', 'GBR', 'England', 104425.0),
#  (517.0, 'Oldham', 'GBR', 'England', 103931.0),
#  (518.0, 'Basildon', 'GBR', 'England', 100924.0),
#  (519.0, 'Worthing', 'GBR', 'England', 100000.0),
#  (520.0, 'Chelmsford', 'GBR', 'England', 97451.0),
#  (521.0, 'Colchester', 'GBR', 'England', 96063.0),
#  (522.0, 'Crawley', 'GBR', 'England', 97000.0),
#  (523.0, 'Gillingham', 'GBR', 'England', 92000.0),
#  (524.0, 'Solihull', 'GBR', 'England', 94531.0),
#  (525.0, 'Rochdale', 'GBR', 'England', 94313.0),
#  (526.0, 'Birkenhead', 'GBR', 'England', 93087.0),
#  (527.0, 'Worcester', 'GBR', 'England', 95000.0),
#  (528.0, 'Hartlepool', 'GBR', 'England', 92000.0),
#  (529.0, 'Halifax', 'GBR', 'England', 91069.0),
#  (530.0, 'Woking/Byfleet', 'GBR', 'England', 92000.0),
#  (531.0, 'Southport', 'GBR', 'England', 90959.0),
#  (532.0, 'Maidstone', 'GBR', 'England', 90878.0),
#  (533.0, 'Eastbourne', 'GBR', 'England', 90000.0),
#  (534.0, 'Grimsby', 'GBR', 'England', 89000.0),
#  (535.0, 'Saint Helier', 'GBR', 'Jersey', 27523.0),
#  (537.0, 'Road Town', 'VGB', 'Tortola', 8000.0),
#  (538.0, 'Bandar Seri Begawan', 'BRN', 'Brunei and Muara', 21484.0),
#  (539.0, 'Sofija', 'BGR', 'Grad Sofija', 1122302.0),
#  (540.0, 'Plovdiv', 'BGR', 'Plovdiv', 342584.0),
#  (541.0, 'Varna', 'BGR', 'Varna', 299801.0),
#  (542.0, 'Burgas', 'BGR', 'Burgas', 195255.0),
#  (543.0, 'Ruse', 'BGR', 'Ruse', 166467.0),
#  (544.0, 'Stara Zagora', 'BGR', 'Haskovo', 147939.0),
#  (545.0, 'Pleven', 'BGR', 'Lovec', 121952.0),
#  (546.0, 'Sliven', 'BGR', 'Burgas', 105530.0),
#  (547.0, 'Dobric', 'BGR', 'Varna', 100399.0),
#  (549.0, 'Ouagadougou', 'BFA', 'Kadiogo', 824000.0),
#  (550.0, 'Bobo-Dioulasso', 'BFA', 'Houet', 300000.0),
#  (552.0, 'Bujumbura', 'BDI', 'Bujumbura', 300000.0),
#  (553.0, 'George Town', 'CYM', 'Grand Cayman', 19600.0),
#  (554.0, 'Santiago de Chile', 'CHL', 'Santiago', 4703954.0),
#  (555.0, 'Puente Alto', 'CHL', 'Santiago', 386236.0),
#  (559.0, 'Antofagasta', 'CHL', 'Antofagasta', 251429.0),
#  (560.0, 'San Bernardo', 'CHL', 'Santiago', 241910.0),
#  (565.0, 'Talca', 'CHL', 'Maule', 187557.0),
#  (569.0, 'Puerto Montt', 'CHL', 'Los Lagos', 152194.0),
#  (570.0, 'Coquimbo', 'CHL', 'Coquimbo', 143353.0),
#  (571.0, 'Osorno', 'CHL', 'Los Lagos', 141468.0),
#  (572.0, 'La Serena', 'CHL', 'Coquimbo', 137409.0),
#  (573.0, 'Calama', 'CHL', 'Antofagasta', 137265.0),
#  (574.0, 'Valdivia', 'CHL', 'Los Lagos', 133106.0),
#  (575.0, 'Punta Arenas', 'CHL', 'Magallanes', 125631.0),
#  (579.0, 'Ovalle', 'CHL', 'Coquimbo', 94854.0),
#  (582.0, 'Melipilla', 'CHL', 'Santiago', 91056.0),
#  (583.0, 'Avarua', 'COK', 'Rarotonga', 11900.0),
#  (585.0, 'Djibouti', 'DJI', 'Djibouti', 383000.0),
#  (586.0, 'Roseau', 'DMA', 'St George', 16243.0),
#  (588.0, 'Santiago de los Caballeros', 'DOM', 'Santiago', 365463.0),
#  (589.0, 'La Romana', 'DOM', 'La Romana', 140204.0),
#  (592.0, 'San Felipe de Puerto Plata', 'DOM', 'Puerto Plata', 89423.0),
#  (593.0, 'Guayaquil', 'ECU', 'Guayas', 2070040.0),
#  (594.0, 'Quito', 'ECU', 'Pichincha', 1573458.0),
#  (595.0, 'Cuenca', 'ECU', 'Azuay', 270353.0),
#  (596.0, 'Machala', 'ECU', 'El Oro', 210368.0),
#  (597.0, 'Santo Domingo de los Colorados', 'ECU', 'Pichincha', 202111.0),
#  (599.0, 'Ambato', 'ECU', 'Tungurahua', 169612.0),
#  (601.0, 'Duran [Eloy Alfaro]', 'ECU', 'Guayas', 152514.0),
#  (602.0, 'Ibarra', 'ECU', 'Imbabura', 130643.0),
#  (604.0, 'Milagro', 'ECU', 'Guayas', 124177.0),
#  (605.0, 'Loja', 'ECU', 'Loja', 123875.0),
#  (607.0, 'Esmeraldas', 'ECU', 'Esmeraldas', 123045.0),
#  (608.0, 'Cairo', 'EGY', 'Kairo', 6789479.0),
#  (609.0, 'Alexandria', 'EGY', 'Aleksandria', 3328196.0),
#  (610.0, 'Giza', 'EGY', 'Giza', 2221868.0),
#  (611.0, 'Shubra al-Khayma', 'EGY', 'al-Qalyubiya', 870716.0),
#  (612.0, 'Port Said', 'EGY', 'Port Said', 469533.0),
#  (613.0, 'Suez', 'EGY', 'Suez', 417610.0),
#  (614.0, 'al-Mahallat al-Kubra', 'EGY', 'al-Gharbiya', 395402.0),
#  (615.0, 'Tanta', 'EGY', 'al-Gharbiya', 371010.0),
#  (616.0, 'al-Mansura', 'EGY', 'al-Daqahliya', 369621.0),
#  (617.0, 'Luxor', 'EGY', 'Luxor', 360503.0),
#  (618.0, 'Asyut', 'EGY', 'Asyut', 343498.0),
#  (619.0, 'Bahtim', 'EGY', 'al-Qalyubiya', 275807.0),
#  (620.0, 'Zagazig', 'EGY', 'al-Sharqiya', 267351.0),
#  (621.0, 'al-Faiyum', 'EGY', 'al-Faiyum', 260964.0),
#  (622.0, 'Ismailia', 'EGY', 'Ismailia', 254477.0),
#  (623.0, 'Kafr al-Dawwar', 'EGY', 'al-Buhayra', 231978.0),
#  (624.0, 'Assuan', 'EGY', 'Assuan', 219017.0),
#  (625.0, 'Damanhur', 'EGY', 'al-Buhayra', 212203.0),
#  (626.0, 'al-Minya', 'EGY', 'al-Minya', 201360.0),
#  (627.0, 'Bani Suwayf', 'EGY', 'Bani Suwayf', 172032.0),
#  (628.0, 'Qina', 'EGY', 'Qina', 171275.0),
#  (629.0, 'Sawhaj', 'EGY', 'Sawhaj', 170125.0),
#  (630.0, 'Shibin al-Kawm', 'EGY', 'al-Minufiya', 159909.0),
#  (631.0, 'Bulaq al-Dakrur', 'EGY', 'Giza', 148787.0),
#  (632.0, 'Banha', 'EGY', 'al-Qalyubiya', 145792.0),
#  (633.0, 'Warraq al-Arab', 'EGY', 'Giza', 127108.0),
#  (634.0, 'Kafr al-Shaykh', 'EGY', 'Kafr al-Shaykh', 124819.0),
#  (635.0, 'Mallawi', 'EGY', 'al-Minya', 119283.0),
#  (636.0, 'Bilbays', 'EGY', 'al-Sharqiya', 113608.0),
#  (637.0, 'Mit Ghamr', 'EGY', 'al-Daqahliya', 101801.0),
#  (638.0, 'al-Arish', 'EGY', 'Shamal Sina', 100447.0),
#  (639.0, 'Talkha', 'EGY', 'al-Daqahliya', 97700.0),
#  (640.0, 'Qalyub', 'EGY', 'al-Qalyubiya', 97200.0),
#  (641.0, 'Jirja', 'EGY', 'Sawhaj', 95400.0),
#  (642.0, 'Idfu', 'EGY', 'Qina', 94200.0),
#  (643.0, 'al-Hawamidiya', 'EGY', 'Giza', 91700.0),
#  (644.0, 'Disuq', 'EGY', 'Kafr al-Shaykh', 91300.0),
#  (645.0, 'San Salvador', 'SLV', 'San Salvador', 415346.0),
#  (646.0, 'Santa Ana', 'SLV', 'Santa Ana', 139389.0),
#  (647.0, 'Mejicanos', 'SLV', 'San Salvador', 138800.0),
#  (648.0, 'Soyapango', 'SLV', 'San Salvador', 129800.0),
#  (649.0, 'San Miguel', 'SLV', 'San Miguel', 127696.0),
#  (650.0, 'Nueva San Salvador', 'SLV', 'La Libertad', 98400.0),
#  (651.0, 'Apopa', 'SLV', 'San Salvador', 88800.0),
#  (652.0, 'Asmara', 'ERI', 'Maekel', 431000.0),
#  (653.0, 'Madrid', 'ESP', 'Madrid', 2879052.0),
#  (654.0, 'Barcelona', 'ESP', 'Katalonia', 1503451.0),
#  (655.0, 'Valencia', 'ESP', 'Valencia', 739412.0),
#  (656.0, 'Sevilla', 'ESP', 'Andalusia', 701927.0),
#  (657.0, 'Zaragoza', 'ESP', 'Aragonia', 603367.0),
#  (659.0, 'Bilbao', 'ESP', 'Baskimaa', 357589.0),
#  (660.0, 'Las Palmas de Gran Canaria', 'ESP', 'Canary Islands', 354757.0),
#  (661.0, 'Murcia', 'ESP', 'Murcia', 353504.0),
#  (662.0, 'Palma de Mallorca', 'ESP', 'Balears', 326993.0),
#  (665.0, 'Vigo', 'ESP', 'Galicia', 283670.0),
#  (666.0, 'Alicante [Alacant]', 'ESP', 'Valencia', 272432.0),
#  (669.0, 'Granada', 'ESP', 'Andalusia', 244767.0),
#  (671.0, 'Vitoria-Gasteiz', 'ESP', 'Baskimaa', 217154.0),
#  (672.0, 'Santa Cruz de Tenerife', 'ESP', 'Canary Islands', 213050.0),
#  (673.0, 'Badalona', 'ESP', 'Katalonia', 209635.0),
#  (674.0, 'Oviedo', 'ESP', 'Asturia', 200453.0),
#  (676.0, 'Elche [Elx]', 'ESP', 'Valencia', 193174.0),
#  (677.0, 'Sabadell', 'ESP', 'Katalonia', 184859.0),
#  (678.0, 'Santander', 'ESP', 'Cantabria', 184165.0),
#  (679.0, 'Jerez de la Frontera', 'ESP', 'Andalusia', 182660.0),
#  (682.0, 'Cartagena', 'ESP', 'Murcia', 177709.0),
#  (684.0, 'Fuenlabrada', 'ESP', 'Madrid', 171173.0),
#  (686.0, 'Terrassa', 'ESP', 'Katalonia', 168695.0),
#  (690.0, 'Albacete', 'ESP', 'Kastilia-La Mancha', 147527.0),
#  (691.0, 'Getafe', 'ESP', 'Madrid', 145371.0),
#  (694.0, 'Huelva', 'ESP', 'Andalusia', 140583.0),
#  (697.0, 'Badajoz', 'ESP', 'Extremadura', 136613.0),
#  (700.0, 'Santa Coloma de Gramenet', 'ESP', 'Katalonia', 120802.0),
#  (701.0, 'Tarragona', 'ESP', 'Katalonia', 113016.0),
#  (704.0, 'Ourense (Orense)', 'ESP', 'Galicia', 109120.0),
#  (706.0, 'Algeciras', 'ESP', 'Andalusia', 103106.0),
#  (707.0, 'Marbella', 'ESP', 'Andalusia', 101144.0),
#  (708.0, 'Barakaldo', 'ESP', 'Baskimaa', 98212.0),
#  (709.0, 'Dos Hermanas', 'ESP', 'Andalusia', 94591.0),
#  (710.0, 'Santiago de Compostela', 'ESP', 'Galicia', 93745.0),
#  (712.0, 'Cape Town', 'ZAF', 'Western Cape', 2352121.0),
#  (713.0, 'Soweto', 'ZAF', 'Gauteng', 904165.0),
#  (714.0, 'Johannesburg', 'ZAF', 'Gauteng', 756653.0),
#  (715.0, 'Port Elizabeth', 'ZAF', 'Eastern Cape', 752319.0),
#  (716.0, 'Pretoria', 'ZAF', 'Gauteng', 658630.0),
#  (717.0, 'Inanda', 'ZAF', 'KwaZulu-Natal', 634065.0),
#  (718.0, 'Durban', 'ZAF', 'KwaZulu-Natal', 566120.0),
#  (719.0, 'Vanderbijlpark', 'ZAF', 'Gauteng', 468931.0),
#  (720.0, 'Kempton Park', 'ZAF', 'Gauteng', 442633.0),
#  (721.0, 'Alberton', 'ZAF', 'Gauteng', 410102.0),
#  (722.0, 'Pinetown', 'ZAF', 'KwaZulu-Natal', 378810.0),
#  (723.0, 'Pietermaritzburg', 'ZAF', 'KwaZulu-Natal', 370190.0),
#  (724.0, 'Benoni', 'ZAF', 'Gauteng', 365467.0),
#  (725.0, 'Randburg', 'ZAF', 'Gauteng', 341288.0),
#  (726.0, 'Umlazi', 'ZAF', 'KwaZulu-Natal', 339233.0),
#  (727.0, 'Bloemfontein', 'ZAF', 'Free State', 334341.0),
#  (728.0, 'Vereeniging', 'ZAF', 'Gauteng', 328535.0),
#  (729.0, 'Wonderboom', 'ZAF', 'Gauteng', 283289.0),
#  (730.0, 'Roodepoort', 'ZAF', 'Gauteng', 279340.0),
#  (731.0, 'Boksburg', 'ZAF', 'Gauteng', 262648.0),
#  (732.0, 'Klerksdorp', 'ZAF', 'North West', 261911.0),
#  (733.0, 'Soshanguve', 'ZAF', 'Gauteng', 242727.0),
#  (734.0, 'Newcastle', 'ZAF', 'KwaZulu-Natal', 222993.0),
#  (735.0, 'East London', 'ZAF', 'Eastern Cape', 221047.0),
#  (736.0, 'Welkom', 'ZAF', 'Free State', 203296.0),
#  (737.0, 'Kimberley', 'ZAF', 'Northern Cape', 197254.0),
#  (738.0, 'Uitenhage', 'ZAF', 'Eastern Cape', 192120.0),
#  (739.0, 'Chatsworth', 'ZAF', 'KwaZulu-Natal', 189885.0),
#  (740.0, 'Mdantsane', 'ZAF', 'Eastern Cape', 182639.0),
#  (741.0, 'Krugersdorp', 'ZAF', 'Gauteng', 181503.0),
#  (742.0, 'Botshabelo', 'ZAF', 'Free State', 177971.0),
#  (743.0, 'Brakpan', 'ZAF', 'Gauteng', 171363.0),
#  (744.0, 'Witbank', 'ZAF', 'Mpumalanga', 167183.0),
#  (745.0, 'Oberholzer', 'ZAF', 'Gauteng', 164367.0),
#  (746.0, 'Germiston', 'ZAF', 'Gauteng', 164252.0),
#  (747.0, 'Springs', 'ZAF', 'Gauteng', 162072.0),
#  (748.0, 'Westonaria', 'ZAF', 'Gauteng', 159632.0),
#  (749.0, 'Randfontein', 'ZAF', 'Gauteng', 120838.0),
#  (750.0, 'Paarl', 'ZAF', 'Western Cape', 105768.0),
#  (751.0, 'Potchefstroom', 'ZAF', 'North West', 101817.0),
#  (752.0, 'Rustenburg', 'ZAF', 'North West', 97008.0),
#  (753.0, 'Nigel', 'ZAF', 'Gauteng', 96734.0),
#  (754.0, 'George', 'ZAF', 'Western Cape', 93818.0),
#  (755.0, 'Ladysmith', 'ZAF', 'KwaZulu-Natal', 89292.0),
#  (756.0, 'Addis Abeba', 'ETH', 'Addis Abeba', 2495000.0),
#  (757.0, 'Dire Dawa', 'ETH', 'Dire Dawa', 164851.0),
#  (758.0, 'Nazret', 'ETH', 'Oromia', 127842.0),
#  (759.0, 'Gonder', 'ETH', 'Amhara', 112249.0),
#  (760.0, 'Dese', 'ETH', 'Amhara', 97314.0),
#  (761.0, 'Mekele', 'ETH', 'Tigray', 96938.0),
#  (762.0, 'Bahir Dar', 'ETH', 'Amhara', 96140.0),
#  (763.0, 'Stanley', 'FLK', 'East Falkland', 1636.0),
#  (764.0, 'Suva', 'FJI', 'Central', 77366.0),
#  (765.0, 'Quezon', 'PHL', 'National Capital Reg', 2173831.0),
#  (766.0, 'Manila', 'PHL', 'National Capital Reg', 1581082.0),
#  (767.0, 'Kalookan', 'PHL', 'National Capital Reg', 1177604.0),
#  (768.0, 'Davao', 'PHL', 'Southern Mindanao', 1147116.0),
#  (769.0, 'Cebu', 'PHL', 'Central Visayas', 718821.0),
#  (770.0, 'Zamboanga', 'PHL', 'Western Mindanao', 601794.0),
#  (771.0, 'Pasig', 'PHL', 'National Capital Reg', 505058.0),
#  (772.0, 'Valenzuela', 'PHL', 'National Capital Reg', 485433.0),
#  (774.0, 'Antipolo', 'PHL', 'Southern Tagalog', 470866.0),
#  (775.0, 'Taguig', 'PHL', 'National Capital Reg', 467375.0),
#  (776.0, 'Cagayan de Oro', 'PHL', 'Northern Mindanao', 461877.0),
#  (778.0, 'Makati', 'PHL', 'National Capital Reg', 444867.0),
#  (779.0, 'Bacolod', 'PHL', 'Western Visayas', 429076.0),
#  (780.0, 'General Santos', 'PHL', 'Southern Mindanao', 411822.0),
#  (781.0, 'Marikina', 'PHL', 'National Capital Reg', 391170.0),
#  (783.0, 'Muntinlupa', 'PHL', 'National Capital Reg', 379310.0),
#  (784.0, 'Iloilo', 'PHL', 'Western Visayas', 365820.0),
#  (785.0, 'Pasay', 'PHL', 'National Capital Reg', 354908.0),
#  (786.0, 'Malabon', 'PHL', 'National Capital Reg', 338855.0),
#  (788.0, 'Bacoor', 'PHL', 'Southern Tagalog', 305699.0),
#  (789.0, 'Iligan', 'PHL', 'Central Mindanao', 285061.0),
#  (790.0, 'Calamba', 'PHL', 'Southern Tagalog', 281146.0),
#  (791.0, 'Mandaluyong', 'PHL', 'National Capital Reg', 278474.0),
#  (792.0, 'Butuan', 'PHL', 'Caraga', 267279.0),
#  (793.0, 'Angeles', 'PHL', 'Central Luzon', 263971.0),
#  (794.0, 'Tarlac', 'PHL', 'Central Luzon', 262481.0),
#  (795.0, 'Mandaue', 'PHL', 'Central Visayas', 259728.0),
#  (796.0, 'Baguio', 'PHL', 'CAR', 252386.0),
#  (797.0, 'Batangas', 'PHL', 'Southern Tagalog', 247588.0),
#  (798.0, 'Cainta', 'PHL', 'Southern Tagalog', 242511.0),
#  (799.0, 'San Pedro', 'PHL', 'Southern Tagalog', 231403.0),
#  (800.0, 'Navotas', 'PHL', 'National Capital Reg', 230403.0),
#  (801.0, 'Cabanatuan', 'PHL', 'Central Luzon', 222859.0),
#  (802.0, 'San Fernando', 'PHL', 'Central Luzon', 221857.0),
#  (803.0, 'Lipa', 'PHL', 'Southern Tagalog', 218447.0),
#  (804.0, 'Lapu-Lapu', 'PHL', 'Central Visayas', 217019.0),
#  (805.0, 'San Pablo', 'PHL', 'Southern Tagalog', 207927.0),
#  (807.0, 'Taytay', 'PHL', 'Southern Tagalog', 198183.0),
#  (808.0, 'Lucena', 'PHL', 'Southern Tagalog', 196075.0),
#  (809.0, 'Imus', 'PHL', 'Southern Tagalog', 195482.0),
#  (810.0, 'Olongapo', 'PHL', 'Central Luzon', 194260.0),
#  (811.0, 'Binangonan', 'PHL', 'Southern Tagalog', 187691.0),
#  (812.0, 'Santa Rosa', 'PHL', 'Southern Tagalog', 185633.0),
#  (813.0, 'Tagum', 'PHL', 'Southern Mindanao', 179531.0),
#  (814.0, 'Tacloban', 'PHL', 'Eastern Visayas', 178639.0),
#  (815.0, 'Malolos', 'PHL', 'Central Luzon', 175291.0),
#  (816.0, 'Mabalacat', 'PHL', 'Central Luzon', 171045.0),
#  (817.0, 'Cotabato', 'PHL', 'Central Mindanao', 163849.0),
#  (818.0, 'Meycauayan', 'PHL', 'Central Luzon', 163037.0),
#  (819.0, 'Puerto Princesa', 'PHL', 'Southern Tagalog', 161912.0),
#  (820.0, 'Legazpi', 'PHL', 'Bicol', 157010.0),
#  (821.0, 'Silang', 'PHL', 'Southern Tagalog', 156137.0),
#  (822.0, 'Ormoc', 'PHL', 'Eastern Visayas', 154297.0),
#  (823.0, 'San Carlos', 'PHL', 'Ilocos', 154264.0),
#  (824.0, 'Kabankalan', 'PHL', 'Western Visayas', 149769.0),
#  (825.0, 'Talisay', 'PHL', 'Central Visayas', 148110.0),
#  (826.0, 'Valencia', 'PHL', 'Northern Mindanao', 147924.0),
#  (827.0, 'Calbayog', 'PHL', 'Eastern Visayas', 147187.0),
#  (828.0, 'Santa Maria', 'PHL', 'Central Luzon', 144282.0),
#  (829.0, 'Pagadian', 'PHL', 'Western Mindanao', 142515.0),
#  (830.0, 'Cadiz', 'PHL', 'Western Visayas', 141954.0),
#  (831.0, 'Bago', 'PHL', 'Western Visayas', 141721.0),
#  (832.0, 'Toledo', 'PHL', 'Central Visayas', 141174.0),
#  (833.0, 'Naga', 'PHL', 'Bicol', 137810.0),
#  (834.0, 'San Mateo', 'PHL', 'Southern Tagalog', 135603.0),
#  (835.0, 'Panabo', 'PHL', 'Southern Mindanao', 133950.0),
#  (836.0, 'Koronadal', 'PHL', 'Southern Mindanao', 133786.0),
#  (837.0, 'Marawi', 'PHL', 'Central Mindanao', 131090.0),
#  (838.0, 'Dagupan', 'PHL', 'Ilocos', 130328.0),
#  (839.0, 'Sagay', 'PHL', 'Western Visayas', 129765.0),
#  (840.0, 'Roxas', 'PHL', 'Western Visayas', 126352.0),
#  (841.0, 'Lubao', 'PHL', 'Central Luzon', 125699.0),
#  (842.0, 'Digos', 'PHL', 'Southern Mindanao', 125171.0),
#  (843.0, 'San Miguel', 'PHL', 'Central Luzon', 123824.0),
#  (844.0, 'Malaybalay', 'PHL', 'Northern Mindanao', 123672.0),
#  (845.0, 'Tuguegarao', 'PHL', 'Cagayan Valley', 120645.0),
#  (846.0, 'Ilagan', 'PHL', 'Cagayan Valley', 119990.0),
#  (847.0, 'Baliuag', 'PHL', 'Central Luzon', 119675.0),
#  (848.0, 'Surigao', 'PHL', 'Caraga', 118534.0),
#  (849.0, 'San Carlos', 'PHL', 'Western Visayas', 118259.0),
#  (850.0, 'San Juan del Monte', 'PHL', 'National Capital Reg', 117680.0),
#  (851.0, 'Tanauan', 'PHL', 'Southern Tagalog', 117539.0),
#  (852.0, 'Concepcion', 'PHL', 'Central Luzon', 115171.0),
#  (853.0, 'Rodriguez (Montalban)', 'PHL', 'Southern Tagalog', 115167.0),
#  (854.0, 'Sariaya', 'PHL', 'Southern Tagalog', 114568.0),
#  (855.0, 'Malasiqui', 'PHL', 'Ilocos', 113190.0),
#  (856.0, 'General Mariano Alvarez', 'PHL', 'Southern Tagalog', 112446.0),
#  (857.0, 'Urdaneta', 'PHL', 'Ilocos', 111582.0),
#  (858.0, 'Hagonoy', 'PHL', 'Central Luzon', 111425.0),
#  (859.0, 'San Jose', 'PHL', 'Southern Tagalog', 111009.0),
#  (860.0, 'Polomolok', 'PHL', 'Southern Mindanao', 110709.0),
#  (861.0, 'Santiago', 'PHL', 'Cagayan Valley', 110531.0),
#  (862.0, 'Tanza', 'PHL', 'Southern Tagalog', 110517.0),
#  (863.0, 'Ozamis', 'PHL', 'Northern Mindanao', 110420.0),
#  (864.0, 'Mexico', 'PHL', 'Central Luzon', 109481.0),
#  (865.0, 'San Jose', 'PHL', 'Central Luzon', 108254.0),
#  (866.0, 'Silay', 'PHL', 'Western Visayas', 107722.0),
#  (867.0, 'General Trias', 'PHL', 'Southern Tagalog', 107691.0),
#  (868.0, 'Tabaco', 'PHL', 'Bicol', 107166.0),
#  (869.0, 'Cabuyao', 'PHL', 'Southern Tagalog', 106630.0),
#  (870.0, 'Calapan', 'PHL', 'Southern Tagalog', 105910.0),
#  (871.0, 'Mati', 'PHL', 'Southern Mindanao', 105908.0),
#  (872.0, 'Midsayap', 'PHL', 'Central Mindanao', 105760.0),
#  (873.0, 'Cauayan', 'PHL', 'Cagayan Valley', 103952.0),
#  (874.0, 'Gingoog', 'PHL', 'Northern Mindanao', 102379.0),
#  (875.0, 'Dumaguete', 'PHL', 'Central Visayas', 102265.0),
#  (876.0, 'San Fernando', 'PHL', 'Ilocos', 102082.0),
#  (877.0, 'Arayat', 'PHL', 'Central Luzon', 101792.0),
#  (878.0, 'Bayawan (Tulong)', 'PHL', 'Central Visayas', 101391.0),
#  (879.0, 'Kidapawan', 'PHL', 'Central Mindanao', 101205.0),
#  (880.0, 'Daraga (Locsin)', 'PHL', 'Bicol', 101031.0),
#  (881.0, 'Marilao', 'PHL', 'Central Luzon', 101017.0),
#  (882.0, 'Malita', 'PHL', 'Southern Mindanao', 100000.0),
#  (883.0, 'Dipolog', 'PHL', 'Western Mindanao', 99862.0),
#  (884.0, 'Cavite', 'PHL', 'Southern Tagalog', 99367.0),
#  (885.0, 'Danao', 'PHL', 'Central Visayas', 98781.0),
#  (886.0, 'Bislig', 'PHL', 'Caraga', 97860.0),
#  (887.0, 'Talavera', 'PHL', 'Central Luzon', 97329.0),
#  (888.0, 'Guagua', 'PHL', 'Central Luzon', 96858.0),
#  (889.0, 'Bayambang', 'PHL', 'Ilocos', 96609.0),
#  (890.0, 'Nasugbu', 'PHL', 'Southern Tagalog', 96113.0),
#  (891.0, 'Baybay', 'PHL', 'Eastern Visayas', 95630.0),
#  (892.0, 'Capas', 'PHL', 'Central Luzon', 95219.0),
#  (893.0, 'Sultan Kudarat', 'PHL', 'ARMM', 94861.0),
#  (894.0, 'Laoag', 'PHL', 'Ilocos', 94466.0),
#  (895.0, 'Bayugan', 'PHL', 'Caraga', 93623.0),
#  (896.0, 'Malungon', 'PHL', 'Southern Mindanao', 93232.0),
#  (897.0, 'Santa Cruz', 'PHL', 'Southern Tagalog', 92694.0),
#  (898.0, 'Sorsogon', 'PHL', 'Bicol', 92512.0),
#  (899.0, 'Candelaria', 'PHL', 'Southern Tagalog', 92429.0),
#  (900.0, 'Ligao', 'PHL', 'Bicol', 90603.0),
#  (902.0, 'Libreville', 'GAB', 'Estuaire', 419000.0),
#  (903.0, 'Serekunda', 'GMB', 'Kombo St Mary', 102600.0),
#  (904.0, 'Banjul', 'GMB', 'Banjul', 42326.0),
#  (905.0, 'Tbilisi', 'GEO', 'Tbilisi', 1235200.0),
#  (906.0, 'Kutaisi', 'GEO', 'Imereti', 240900.0),
#  (907.0, 'Rustavi', 'GEO', 'Kvemo Kartli', 155400.0),
#  (909.0, 'Sohumi', 'GEO', 'Abhasia [Aphazeti]', 111700.0),
#  (910.0, 'Accra', 'GHA', 'Greater Accra', 1070000.0),
#  (911.0, 'Kumasi', 'GHA', 'Ashanti', 385192.0),
#  (912.0, 'Tamale', 'GHA', 'Northern', 151069.0),
#  (913.0, 'Tema', 'GHA', 'Greater Accra', 109975.0),
#  (914.0, 'Sekondi-Takoradi', 'GHA', 'Western', 103653.0),
#  (917.0, 'Nuuk', 'GRL', 'Kitaa', 13445.0),
#  (918.0, 'Les Abymes', 'GLP', 'Grande-Terre', 62947.0),
#  (919.0, 'Basse-Terre', 'GLP', 'Basse-Terre', 12433.0),
#  (922.0, 'Ciudad de Guatemala', 'GTM', 'Guatemala', 823301.0),
#  (923.0, 'Mixco', 'GTM', 'Guatemala', 209791.0),
#  (924.0, 'Villa Nueva', 'GTM', 'Guatemala', 101295.0),
#  (925.0, 'Quetzaltenango', 'GTM', 'Quetzaltenango', 90801.0),
#  (926.0, 'Conakry', 'GIN', 'Conakry', 1090610.0),
#  (927.0, 'Bissau', 'GNB', 'Bissau', 241000.0),
#  (928.0, 'Georgetown', 'GUY', 'Georgetown', 254000.0),
#  (929.0, 'Port-au-Prince', 'HTI', 'Ouest', 884472.0),
#  (930.0, 'Carrefour', 'HTI', 'Ouest', 290204.0),
#  (931.0, 'Delmas', 'HTI', 'Ouest', 240429.0),
#  (933.0, 'Tegucigalpa', 'HND', 'Distrito Central', 813900.0),
#  (936.0, 'Kowloon and New Kowloon', 'HKG', 'Kowloon and New Kowl', 1987996.0),
#  (937.0, 'Victoria', 'HKG', 'Hongkong', 1312637.0),
#  (939.0, 'Jakarta', 'IDN', 'Jakarta Raya', 9604900.0),
#  (940.0, 'Surabaya', 'IDN', 'East Java', 2663820.0),
#  (941.0, 'Bandung', 'IDN', 'West Java', 2429000.0),
#  (942.0, 'Medan', 'IDN', 'Sumatera Utara', 1843919.0),
#  (943.0, 'Palembang', 'IDN', 'Sumatera Selatan', 1222764.0),
#  (944.0, 'Tangerang', 'IDN', 'West Java', 1198300.0),
#  (945.0, 'Semarang', 'IDN', 'Central Java', 1104405.0),
#  (946.0, 'Ujung Pandang', 'IDN', 'Sulawesi Selatan', 1060257.0),
#  (947.0, 'Malang', 'IDN', 'East Java', 716862.0),
#  (948.0, 'Bandar Lampung', 'IDN', 'Lampung', 680332.0),
#  (949.0, 'Bekasi', 'IDN', 'West Java', 644300.0),
#  (950.0, 'Padang', 'IDN', 'Sumatera Barat', 534474.0),
#  (951.0, 'Surakarta', 'IDN', 'Central Java', 518600.0),
#  (952.0, 'Banjarmasin', 'IDN', 'Kalimantan Selatan', 482931.0),
#  (953.0, 'Pekan Baru', 'IDN', 'Riau', 438638.0),
#  (954.0, 'Denpasar', 'IDN', 'Bali', 435000.0),
#  (955.0, 'Yogyakarta', 'IDN', 'Yogyakarta', 418944.0),
#  (956.0, 'Pontianak', 'IDN', 'Kalimantan Barat', 409632.0),
#  (957.0, 'Samarinda', 'IDN', 'Kalimantan Timur', 399175.0),
#  (958.0, 'Jambi', 'IDN', 'Jambi', 385201.0),
#  (959.0, 'Depok', 'IDN', 'West Java', 365200.0),
#  (960.0, 'Cimahi', 'IDN', 'West Java', 344600.0),
#  (961.0, 'Balikpapan', 'IDN', 'Kalimantan Timur', 338752.0),
#  (962.0, 'Manado', 'IDN', 'Sulawesi Utara', 332288.0),
#  (963.0, 'Mataram', 'IDN', 'Nusa Tenggara Barat', 306600.0),
#  (964.0, 'Pekalongan', 'IDN', 'Central Java', 301504.0),
#  (965.0, 'Tegal', 'IDN', 'Central Java', 289744.0),
#  (966.0, 'Bogor', 'IDN', 'West Java', 285114.0),
#  (967.0, 'Ciputat', 'IDN', 'West Java', 270800.0),
#  (968.0, 'Pondokgede', 'IDN', 'West Java', 263200.0),
#  (969.0, 'Cirebon', 'IDN', 'West Java', 254406.0),
#  (970.0, 'Kediri', 'IDN', 'East Java', 253760.0),
#  (971.0, 'Ambon', 'IDN', 'Molukit', 249312.0),
#  (972.0, 'Jember', 'IDN', 'East Java', 218500.0),
#  (973.0, 'Cilacap', 'IDN', 'Central Java', 206900.0),
#  (974.0, 'Cimanggis', 'IDN', 'West Java', 205100.0),
#  (975.0, 'Pematang Siantar', 'IDN', 'Sumatera Utara', 203056.0),
#  (976.0, 'Purwokerto', 'IDN', 'Central Java', 202500.0),
#  (977.0, 'Ciomas', 'IDN', 'West Java', 187400.0),
#  (978.0, 'Tasikmalaya', 'IDN', 'West Java', 179800.0),
#  (979.0, 'Madiun', 'IDN', 'East Java', 171532.0),
#  (980.0, 'Bengkulu', 'IDN', 'Bengkulu', 146439.0),
#  (981.0, 'Karawang', 'IDN', 'West Java', 145000.0),
#  (982.0, 'Banda Aceh', 'IDN', 'Aceh', 143409.0),
#  (983.0, 'Palu', 'IDN', 'Sulawesi Tengah', 142800.0),
#  (984.0, 'Pasuruan', 'IDN', 'East Java', 134019.0),
#  (985.0, 'Kupang', 'IDN', 'Nusa Tenggara Timur', 129300.0),
#  (986.0, 'Tebing Tinggi', 'IDN', 'Sumatera Utara', 129300.0),
#  (987.0, 'Percut Sei Tuan', 'IDN', 'Sumatera Utara', 129000.0),
#  (988.0, 'Binjai', 'IDN', 'Sumatera Utara', 127222.0),
#  (989.0, 'Sukabumi', 'IDN', 'West Java', 125766.0),
#  (990.0, 'Waru', 'IDN', 'East Java', 124300.0),
#  (991.0, 'Pangkal Pinang', 'IDN', 'Sumatera Selatan', 124000.0),
#  (992.0, 'Magelang', 'IDN', 'Central Java', 123800.0),
#  (993.0, 'Blitar', 'IDN', 'East Java', 122600.0),
#  (994.0, 'Serang', 'IDN', 'West Java', 122400.0),
#  (995.0, 'Probolinggo', 'IDN', 'East Java', 120770.0),
#  (996.0, 'Cilegon', 'IDN', 'West Java', 117000.0),
#  (997.0, 'Cianjur', 'IDN', 'West Java', 114300.0),
#  (998.0, 'Ciparay', 'IDN', 'West Java', 111500.0),
#  (999.0, 'Lhokseumawe', 'IDN', 'Aceh', 109600.0),
#  (1000.0, 'Taman', 'IDN', 'East Java', 107000.0),
#  (1001.0, 'Depok', 'IDN', 'Yogyakarta', 106800.0),
#  (1002.0, 'Citeureup', 'IDN', 'West Java', 105100.0),
#  (1003.0, 'Pemalang', 'IDN', 'Central Java', 103500.0),
#  (1004.0, 'Klaten', 'IDN', 'Central Java', 103300.0),
#  (1005.0, 'Salatiga', 'IDN', 'Central Java', 103000.0),
#  (1006.0, 'Cibinong', 'IDN', 'West Java', 101300.0),
#  (1007.0, 'Palangka Raya', 'IDN', 'Kalimantan Tengah', 99693.0),
#  (1008.0, 'Mojokerto', 'IDN', 'East Java', 96626.0),
#  (1009.0, 'Purwakarta', 'IDN', 'West Java', 95900.0),
#  (1010.0, 'Garut', 'IDN', 'West Java', 95800.0),
#  (1011.0, 'Kudus', 'IDN', 'Central Java', 95300.0),
#  (1012.0, 'Kendari', 'IDN', 'Sulawesi Tenggara', 94800.0),
#  (1013.0, 'Jaya Pura', 'IDN', 'West Irian', 94700.0),
#  (1014.0, 'Gorontalo', 'IDN', 'Sulawesi Utara', 94058.0),
#  (1015.0, 'Majalaya', 'IDN', 'West Java', 93200.0),
#  (1016.0, 'Pondok Aren', 'IDN', 'West Java', 92700.0),
#  (1017.0, 'Jombang', 'IDN', 'East Java', 92600.0),
#  (1018.0, 'Sunggal', 'IDN', 'Sumatera Utara', 92300.0),
#  (1019.0, 'Batam', 'IDN', 'Riau', 91871.0),
#  (1020.0, 'Padang Sidempuan', 'IDN', 'Sumatera Utara', 91200.0),
#  (1021.0, 'Sawangan', 'IDN', 'West Java', 91100.0),
#  (1022.0, 'Banyuwangi', 'IDN', 'East Java', 89900.0),
#  (1023.0, 'Tanjung Pinang', 'IDN', 'Riau', 89900.0),
#  (1024.0, 'Mumbai (Bombay)', 'IND', 'Maharashtra', 10500000.0),
#  (1025.0, 'Delhi', 'IND', 'Delhi', 7206704.0),
#  (1026.0, 'Calcutta [Kolkata]', 'IND', 'West Bengali', 4399819.0),
#  (1027.0, 'Chennai (Madras)', 'IND', 'Tamil Nadu', 3841396.0),
#  (1028.0, 'Hyderabad', 'IND', 'Andhra Pradesh', 2964638.0),
#  (1029.0, 'Ahmedabad', 'IND', 'Gujarat', 2876710.0),
#  (1030.0, 'Bangalore', 'IND', 'Karnataka', 2660088.0),
#  (1031.0, 'Kanpur', 'IND', 'Uttar Pradesh', 1874409.0),
#  (1032.0, 'Nagpur', 'IND', 'Maharashtra', 1624752.0),
#  (1033.0, 'Lucknow', 'IND', 'Uttar Pradesh', 1619115.0),
#  (1034.0, 'Pune', 'IND', 'Maharashtra', 1566651.0),
#  (1035.0, 'Surat', 'IND', 'Gujarat', 1498817.0),
#  (1036.0, 'Jaipur', 'IND', 'Rajasthan', 1458483.0),
#  (1037.0, 'Indore', 'IND', 'Madhya Pradesh', 1091674.0),
#  (1038.0, 'Bhopal', 'IND', 'Madhya Pradesh', 1062771.0),
#  (1039.0, 'Ludhiana', 'IND', 'Punjab', 1042740.0),
#  (1040.0, 'Vadodara (Baroda)', 'IND', 'Gujarat', 1031346.0),
#  (1041.0, 'Kalyan', 'IND', 'Maharashtra', 1014557.0),
#  (1042.0, 'Madurai', 'IND', 'Tamil Nadu', 977856.0),
#  (1043.0, 'Haora (Howrah)', 'IND', 'West Bengali', 950435.0),
#  (1044.0, 'Varanasi (Benares)', 'IND', 'Uttar Pradesh', 929270.0),
#  (1045.0, 'Patna', 'IND', 'Bihar', 917243.0),
#  (1046.0, 'Srinagar', 'IND', 'Jammu and Kashmir', 892506.0),
#  (1047.0, 'Agra', 'IND', 'Uttar Pradesh', 891790.0),
#  (1048.0, 'Coimbatore', 'IND', 'Tamil Nadu', 816321.0),
#  (1049.0, 'Thane (Thana)', 'IND', 'Maharashtra', 803389.0),
#  (1050.0, 'Allahabad', 'IND', 'Uttar Pradesh', 792858.0),
#  (1051.0, 'Meerut', 'IND', 'Uttar Pradesh', 753778.0),
#  (1052.0, 'Vishakhapatnam', 'IND', 'Andhra Pradesh', 752037.0),
#  (1053.0, 'Jabalpur', 'IND', 'Madhya Pradesh', 741927.0),
#  (1054.0, 'Amritsar', 'IND', 'Punjab', 708835.0),
#  (1055.0, 'Faridabad', 'IND', 'Haryana', 703592.0),
#  (1056.0, 'Vijayawada', 'IND', 'Andhra Pradesh', 701827.0),
#  (1057.0, 'Gwalior', 'IND', 'Madhya Pradesh', 690765.0),
#  (1058.0, 'Jodhpur', 'IND', 'Rajasthan', 666279.0),
#  (1059.0, 'Nashik (Nasik)', 'IND', 'Maharashtra', 656925.0),
#  (1060.0, 'Hubli-Dharwad', 'IND', 'Karnataka', 648298.0),
#  (1061.0, 'Solapur (Sholapur)', 'IND', 'Maharashtra', 604215.0),
#  (1062.0, 'Ranchi', 'IND', 'Jharkhand', 599306.0),
#  (1063.0, 'Bareilly', 'IND', 'Uttar Pradesh', 587211.0),
#  (1064.0, 'Guwahati (Gauhati)', 'IND', 'Assam', 584342.0),
#  (1065.0, 'Shambajinagar (Aurangabad)', 'IND', 'Maharashtra', 573272.0),
#  (1066.0, 'Cochin (Kochi)', 'IND', 'Kerala', 564589.0),
#  (1067.0, 'Rajkot', 'IND', 'Gujarat', 559407.0),
#  (1068.0, 'Kota', 'IND', 'Rajasthan', 537371.0),
#  (1069.0, 'Thiruvananthapuram (Trivandrum', 'IND', 'Kerala', 524006.0),
#  (1070.0, 'Pimpri-Chinchwad', 'IND', 'Maharashtra', 517083.0),
#  (1071.0, 'Jalandhar (Jullundur)', 'IND', 'Punjab', 509510.0),
#  (1072.0, 'Gorakhpur', 'IND', 'Uttar Pradesh', 505566.0),
#  (1073.0, 'Chandigarh', 'IND', 'Chandigarh', 504094.0),
#  (1074.0, 'Mysore', 'IND', 'Karnataka', 480692.0),
#  (1075.0, 'Aligarh', 'IND', 'Uttar Pradesh', 480520.0),
#  (1076.0, 'Guntur', 'IND', 'Andhra Pradesh', 471051.0),
#  (1077.0, 'Jamshedpur', 'IND', 'Jharkhand', 460577.0),
#  (1078.0, 'Ghaziabad', 'IND', 'Uttar Pradesh', 454156.0),
#  (1079.0, 'Warangal', 'IND', 'Andhra Pradesh', 447657.0),
#  (1080.0, 'Raipur', 'IND', 'Chhatisgarh', 438639.0),
#  (1081.0, 'Moradabad', 'IND', 'Uttar Pradesh', 429214.0),
#  (1082.0, 'Durgapur', 'IND', 'West Bengali', 425836.0),
#  (1083.0, 'Amravati', 'IND', 'Maharashtra', 421576.0),
#  (1084.0, 'Calicut (Kozhikode)', 'IND', 'Kerala', 419831.0),
#  (1085.0, 'Bikaner', 'IND', 'Rajasthan', 416289.0),
#  (1086.0, 'Bhubaneswar', 'IND', 'Orissa', 411542.0),
#  (1087.0, 'Kolhapur', 'IND', 'Maharashtra', 406370.0),
#  (1088.0, 'Kataka (Cuttack)', 'IND', 'Orissa', 403418.0),
#  (1089.0, 'Ajmer', 'IND', 'Rajasthan', 402700.0),
#  (1090.0, 'Bhavnagar', 'IND', 'Gujarat', 402338.0),
#  (1091.0, 'Tiruchirapalli', 'IND', 'Tamil Nadu', 387223.0),
#  (1092.0, 'Bhilai', 'IND', 'Chhatisgarh', 386159.0),
#  (1093.0, 'Bhiwandi', 'IND', 'Maharashtra', 379070.0),
#  (1094.0, 'Saharanpur', 'IND', 'Uttar Pradesh', 374945.0),
#  (1095.0, 'Ulhasnagar', 'IND', 'Maharashtra', 369077.0),
#  (1096.0, 'Salem', 'IND', 'Tamil Nadu', 366712.0),
#  (1097.0, 'Ujjain', 'IND', 'Madhya Pradesh', 362266.0),
#  (1098.0, 'Malegaon', 'IND', 'Maharashtra', 342595.0),
#  (1099.0, 'Jamnagar', 'IND', 'Gujarat', 341637.0),
#  (1100.0, 'Bokaro Steel City', 'IND', 'Jharkhand', 333683.0),
#  (1101.0, 'Akola', 'IND', 'Maharashtra', 328034.0),
#  (1102.0, 'Belgaum', 'IND', 'Karnataka', 326399.0),
#  (1103.0, 'Rajahmundry', 'IND', 'Andhra Pradesh', 324851.0),
#  (1104.0, 'Nellore', 'IND', 'Andhra Pradesh', 316606.0),
#  (1105.0, 'Udaipur', 'IND', 'Rajasthan', 308571.0),
#  (1106.0, 'New Bombay', 'IND', 'Maharashtra', 307297.0),
#  (1107.0, 'Bhatpara', 'IND', 'West Bengali', 304952.0),
#  (1108.0, 'Gulbarga', 'IND', 'Karnataka', 304099.0),
#  (1109.0, 'New Delhi', 'IND', 'Delhi', 301297.0),
#  (1110.0, 'Jhansi', 'IND', 'Uttar Pradesh', 300850.0),
#  (1111.0, 'Gaya', 'IND', 'Bihar', 291675.0),
#  (1112.0, 'Kakinada', 'IND', 'Andhra Pradesh', 279980.0),
#  (1113.0, 'Dhule (Dhulia)', 'IND', 'Maharashtra', 278317.0),
#  (1114.0, 'Panihati', 'IND', 'West Bengali', 275990.0),
#  (1115.0, 'Nanded (Nander)', 'IND', 'Maharashtra', 275083.0),
#  (1116.0, 'Mangalore', 'IND', 'Karnataka', 273304.0),
#  (1117.0, 'Dehra Dun', 'IND', 'Uttaranchal', 270159.0),
#  (1118.0, 'Kamarhati', 'IND', 'West Bengali', 266889.0),
#  (1119.0, 'Davangere', 'IND', 'Karnataka', 266082.0),
#  (1120.0, 'Asansol', 'IND', 'West Bengali', 262188.0),
#  (1121.0, 'Bhagalpur', 'IND', 'Bihar', 253225.0),
#  (1122.0, 'Bellary', 'IND', 'Karnataka', 245391.0),
#  (1123.0, 'Barddhaman (Burdwan)', 'IND', 'West Bengali', 245079.0),
#  (1124.0, 'Rampur', 'IND', 'Uttar Pradesh', 243742.0),
#  (1125.0, 'Jalgaon', 'IND', 'Maharashtra', 242193.0),
#  (1126.0, 'Muzaffarpur', 'IND', 'Bihar', 241107.0),
#  (1127.0, 'Nizamabad', 'IND', 'Andhra Pradesh', 241034.0),
#  (1128.0, 'Muzaffarnagar', 'IND', 'Uttar Pradesh', 240609.0),
#  (1129.0, 'Patiala', 'IND', 'Punjab', 238368.0),
#  (1130.0, 'Shahjahanpur', 'IND', 'Uttar Pradesh', 237713.0),
#  (1131.0, 'Kurnool', 'IND', 'Andhra Pradesh', 236800.0),
#  (1132.0, 'Tiruppur (Tirupper)', 'IND', 'Tamil Nadu', 235661.0),
#  (1133.0, 'Rohtak', 'IND', 'Haryana', 233400.0),
#  (1134.0, 'South Dum Dum', 'IND', 'West Bengali', 232811.0),
#  (1135.0, 'Mathura', 'IND', 'Uttar Pradesh', 226691.0),
#  (1136.0, 'Chandrapur', 'IND', 'Maharashtra', 226105.0),
#  (1137.0, 'Barahanagar (Baranagar)', 'IND', 'West Bengali', 224821.0),
#  (1138.0, 'Darbhanga', 'IND', 'Bihar', 218391.0),
#  (1139.0, 'Siliguri (Shiliguri)', 'IND', 'West Bengali', 216950.0),
#  (1140.0, 'Raurkela', 'IND', 'Orissa', 215489.0),
#  (1141.0, 'Ambattur', 'IND', 'Tamil Nadu', 215424.0),
#  (1142.0, 'Panipat', 'IND', 'Haryana', 215218.0),
#  (1143.0, 'Firozabad', 'IND', 'Uttar Pradesh', 215128.0),
#  (1144.0, 'Ichalkaranji', 'IND', 'Maharashtra', 214950.0),
#  (1145.0, 'Jammu', 'IND', 'Jammu and Kashmir', 214737.0),
#  (1146.0, 'Ramagundam', 'IND', 'Andhra Pradesh', 214384.0),
#  (1147.0, 'Eluru', 'IND', 'Andhra Pradesh', 212866.0),
#  (1148.0, 'Brahmapur', 'IND', 'Orissa', 210418.0),
#  (1149.0, 'Alwar', 'IND', 'Rajasthan', 205086.0),
#  (1150.0, 'Pondicherry', 'IND', 'Pondicherry', 203065.0),
#  (1151.0, 'Thanjavur', 'IND', 'Tamil Nadu', 202013.0),
#  (1152.0, 'Bihar Sharif', 'IND', 'Bihar', 201323.0),
#  (1153.0, 'Tuticorin', 'IND', 'Tamil Nadu', 199854.0),
#  (1154.0, 'Imphal', 'IND', 'Manipur', 198535.0),
#  (1155.0, 'Latur', 'IND', 'Maharashtra', 197408.0),
#  (1156.0, 'Sagar', 'IND', 'Madhya Pradesh', 195346.0),
#  (1157.0, 'Farrukhabad-cum-Fatehgarh', 'IND', 'Uttar Pradesh', 194567.0),
#  (1158.0, 'Sangli', 'IND', 'Maharashtra', 193197.0),
#  (1159.0, 'Parbhani', 'IND', 'Maharashtra', 190255.0),
#  (1160.0, 'Nagar Coil', 'IND', 'Tamil Nadu', 190084.0),
#  (1161.0, 'Bijapur', 'IND', 'Karnataka', 186939.0),
#  (1162.0, 'Kukatpalle', 'IND', 'Andhra Pradesh', 185378.0),
#  (1163.0, 'Bally', 'IND', 'West Bengali', 184474.0),
#  (1164.0, 'Bhilwara', 'IND', 'Rajasthan', 183965.0),
#  (1165.0, 'Ratlam', 'IND', 'Madhya Pradesh', 183375.0),
#  (1166.0, 'Avadi', 'IND', 'Tamil Nadu', 183215.0),
#  (1167.0, 'Dindigul', 'IND', 'Tamil Nadu', 182477.0),
#  (1168.0, 'Ahmadnagar', 'IND', 'Maharashtra', 181339.0),
#  (1169.0, 'Bilaspur', 'IND', 'Chhatisgarh', 179833.0),
#  (1170.0, 'Shimoga', 'IND', 'Karnataka', 179258.0),
#  (1171.0, 'Kharagpur', 'IND', 'West Bengali', 177989.0),
#  (1172.0, 'Mira Bhayandar', 'IND', 'Maharashtra', 175372.0),
#  (1173.0, 'Vellore', 'IND', 'Tamil Nadu', 175061.0),
#  (1174.0, 'Jalna', 'IND', 'Maharashtra', 174985.0),
#  (1175.0, 'Burnpur', 'IND', 'West Bengali', 174933.0),
#  (1176.0, 'Anantapur', 'IND', 'Andhra Pradesh', 174924.0),
#  (1177.0, 'Allappuzha (Alleppey)', 'IND', 'Kerala', 174666.0),
#  (1178.0, 'Tirupati', 'IND', 'Andhra Pradesh', 174369.0),
#  (1179.0, 'Karnal', 'IND', 'Haryana', 173751.0),
#  (1180.0, 'Burhanpur', 'IND', 'Madhya Pradesh', 172710.0),
#  (1181.0, 'Hisar (Hissar)', 'IND', 'Haryana', 172677.0),
#  (1182.0, 'Tiruvottiyur', 'IND', 'Tamil Nadu', 172562.0),
#  (1183.0, 'Mirzapur-cum-Vindhyachal', 'IND', 'Uttar Pradesh', 169336.0),
#  (1184.0, 'Secunderabad', 'IND', 'Andhra Pradesh', 167461.0),
#  (1185.0, 'Nadiad', 'IND', 'Gujarat', 167051.0),
#  (1186.0, 'Dewas', 'IND', 'Madhya Pradesh', 164364.0),
#  (1187.0, 'Murwara (Katni)', 'IND', 'Madhya Pradesh', 163431.0),
#  (1188.0, 'Ganganagar', 'IND', 'Rajasthan', 161482.0),
#  (1189.0, 'Vizianagaram', 'IND', 'Andhra Pradesh', 160359.0),
#  (1190.0, 'Erode', 'IND', 'Tamil Nadu', 159232.0),
#  (1191.0, 'Machilipatnam (Masulipatam)', 'IND', 'Andhra Pradesh', 159110.0),
#  (1192.0, 'Bhatinda (Bathinda)', 'IND', 'Punjab', 159042.0),
#  (1193.0, 'Raichur', 'IND', 'Karnataka', 157551.0),
#  (1194.0, 'Agartala', 'IND', 'Tripura', 157358.0),
#  (1195.0, 'Arrah (Ara)', 'IND', 'Bihar', 157082.0),
#  (1196.0, 'Satna', 'IND', 'Madhya Pradesh', 156630.0),
#  (1197.0, 'Lalbahadur Nagar', 'IND', 'Andhra Pradesh', 155500.0),
#  (1198.0, 'Aizawl', 'IND', 'Mizoram', 155240.0),
#  (1199.0, 'Uluberia', 'IND', 'West Bengali', 155172.0),
#  (1200.0, 'Katihar', 'IND', 'Bihar', 154367.0),
#  (1201.0, 'Cuddalore', 'IND', 'Tamil Nadu', 153086.0),
#  (1202.0, 'Hugli-Chinsurah', 'IND', 'West Bengali', 151806.0),
#  (1203.0, 'Dhanbad', 'IND', 'Jharkhand', 151789.0),
#  (1204.0, 'Raiganj', 'IND', 'West Bengali', 151045.0),
#  (1205.0, 'Sambhal', 'IND', 'Uttar Pradesh', 150869.0),
#  (1206.0, 'Durg', 'IND', 'Chhatisgarh', 150645.0),
#  (1207.0, 'Munger (Monghyr)', 'IND', 'Bihar', 150112.0),
#  (1208.0, 'Kanchipuram', 'IND', 'Tamil Nadu', 150100.0),
#  (1209.0, 'North Dum Dum', 'IND', 'West Bengali', 149965.0),
#  (1210.0, 'Karimnagar', 'IND', 'Andhra Pradesh', 148583.0),
#  (1211.0, 'Bharatpur', 'IND', 'Rajasthan', 148519.0),
#  (1212.0, 'Sikar', 'IND', 'Rajasthan', 148272.0),
#  (1213.0, 'Hardwar (Haridwar)', 'IND', 'Uttaranchal', 147305.0),
#  (1214.0, 'Dabgram', 'IND', 'West Bengali', 147217.0),
#  (1215.0, 'Morena', 'IND', 'Madhya Pradesh', 147124.0),
#  (1216.0, 'Noida', 'IND', 'Uttar Pradesh', 146514.0),
#  (1217.0, 'Hapur', 'IND', 'Uttar Pradesh', 146262.0),
#  (1218.0, 'Bhusawal', 'IND', 'Maharashtra', 145143.0),
#  (1219.0, 'Khandwa', 'IND', 'Madhya Pradesh', 145133.0),
#  (1220.0, 'Yamuna Nagar', 'IND', 'Haryana', 144346.0),
#  (1221.0, 'Sonipat (Sonepat)', 'IND', 'Haryana', 143922.0),
#  (1222.0, 'Tenali', 'IND', 'Andhra Pradesh', 143726.0),
#  (1223.0, 'Raurkela Civil Township', 'IND', 'Orissa', 140408.0),
#  (1224.0, 'Kollam (Quilon)', 'IND', 'Kerala', 139852.0),
#  (1225.0, 'Kumbakonam', 'IND', 'Tamil Nadu', 139483.0),
#  (1226.0, 'Ingraj Bazar (English Bazar)', 'IND', 'West Bengali', 139204.0),
#  (1227.0, 'Timkur', 'IND', 'Karnataka', 138903.0),
#  (1228.0, 'Amroha', 'IND', 'Uttar Pradesh', 137061.0),
#  (1229.0, 'Serampore', 'IND', 'West Bengali', 137028.0),
#  (1230.0, 'Chapra', 'IND', 'Bihar', 136877.0),
#  (1231.0, 'Pali', 'IND', 'Rajasthan', 136842.0),
#  (1232.0, 'Maunath Bhanjan', 'IND', 'Uttar Pradesh', 136697.0),
#  (1233.0, 'Adoni', 'IND', 'Andhra Pradesh', 136182.0),
#  (1234.0, 'Jaunpur', 'IND', 'Uttar Pradesh', 136062.0),
#  (1235.0, 'Tirunelveli', 'IND', 'Tamil Nadu', 135825.0),
#  (1236.0, 'Bahraich', 'IND', 'Uttar Pradesh', 135400.0),
#  (1237.0, 'Gadag Betigeri', 'IND', 'Karnataka', 134051.0),
#  (1238.0, 'Proddatur', 'IND', 'Andhra Pradesh', 133914.0),
#  (1239.0, 'Chittoor', 'IND', 'Andhra Pradesh', 133462.0),
#  (1240.0, 'Barrackpur', 'IND', 'West Bengali', 133265.0),
#  (1241.0, 'Bharuch (Broach)', 'IND', 'Gujarat', 133102.0),
#  (1242.0, 'Naihati', 'IND', 'West Bengali', 132701.0),
#  (1243.0, 'Shillong', 'IND', 'Meghalaya', 131719.0),
#  (1244.0, 'Sambalpur', 'IND', 'Orissa', 131138.0),
#  (1245.0, 'Junagadh', 'IND', 'Gujarat', 130484.0),
#  (1246.0, 'Rae Bareli', 'IND', 'Uttar Pradesh', 129904.0),
#  (1247.0, 'Rewa', 'IND', 'Madhya Pradesh', 128981.0),
#  (1248.0, 'Gurgaon', 'IND', 'Haryana', 128608.0),
#  (1249.0, 'Khammam', 'IND', 'Andhra Pradesh', 127992.0),
#  (1250.0, 'Bulandshahr', 'IND', 'Uttar Pradesh', 127201.0),
#  (1251.0, 'Navsari', 'IND', 'Gujarat', 126089.0),
#  (1252.0, 'Malkajgiri', 'IND', 'Andhra Pradesh', 126066.0),
#  (1253.0, 'Midnapore (Medinipur)', 'IND', 'West Bengali', 125498.0),
#  (1254.0, 'Miraj', 'IND', 'Maharashtra', 125407.0),
#  (1255.0, 'Raj Nandgaon', 'IND', 'Chhatisgarh', 125371.0),
#  (1256.0, 'Alandur', 'IND', 'Tamil Nadu', 125244.0),
#  (1257.0, 'Puri', 'IND', 'Orissa', 125199.0),
#  (1258.0, 'Navadwip', 'IND', 'West Bengali', 125037.0),
#  (1259.0, 'Sirsa', 'IND', 'Haryana', 125000.0),
#  (1260.0, 'Korba', 'IND', 'Chhatisgarh', 124501.0),
#  (1261.0, 'Faizabad', 'IND', 'Uttar Pradesh', 124437.0),
#  (1262.0, 'Etawah', 'IND', 'Uttar Pradesh', 124072.0),
#  (1263.0, 'Pathankot', 'IND', 'Punjab', 123930.0),
#  (1264.0, 'Gandhinagar', 'IND', 'Gujarat', 123359.0),
#  (1265.0, 'Palghat (Palakkad)', 'IND', 'Kerala', 123289.0),
#  (1266.0, 'Veraval', 'IND', 'Gujarat', 123000.0),
#  (1267.0, 'Hoshiarpur', 'IND', 'Punjab', 122705.0),
#  (1268.0, 'Ambala', 'IND', 'Haryana', 122596.0),
#  (1269.0, 'Sitapur', 'IND', 'Uttar Pradesh', 121842.0),
#  (1270.0, 'Bhiwani', 'IND', 'Haryana', 121629.0),
#  (1271.0, 'Cuddapah', 'IND', 'Andhra Pradesh', 121463.0),
#  (1272.0, 'Bhimavaram', 'IND', 'Andhra Pradesh', 121314.0),
#  (1273.0, 'Krishnanagar', 'IND', 'West Bengali', 121110.0),
#  (1274.0, 'Chandannagar', 'IND', 'West Bengali', 120378.0),
#  ...]

# %% [markdown]
# ## SELECT
#
#
# **TASK**: Now, only select the columns `Name` and `Population` from the `City` table.

# %%
# %sql SELECT Name, Population FROM City
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 3427 rows affected.
# [('Kabul', 1780000.0),
#  ('Qandahar', 237500.0),
#  ('Herat', 186800.0),
#  ('Mazar-e-Sharif', 127800.0),
#  ('Amsterdam', 731200.0),
#  ('Rotterdam', 593321.0),
#  ('Haag', 440900.0),
#  ('Utrecht', 234323.0),
#  ('Eindhoven', 201843.0),
#  ('Tilburg', 193238.0),
#  ('Groningen', 172701.0),
#  ('Breda', 160398.0),
#  ('Apeldoorn', 153491.0),
#  ('Nijmegen', 152463.0),
#  ('Enschede', 149544.0),
#  ('Haarlem', 148772.0),
#  ('Almere', 142465.0),
#  ('Arnhem', 138020.0),
#  ('Zaanstad', 135621.0),
#  ('Amersfoort', 126270.0),
#  ('Maastricht', 122087.0),
#  ('Dordrecht', 119811.0),
#  ('Leiden', 117196.0),
#  ('Haarlemmermeer', 110722.0),
#  ('Zoetermeer', 110214.0),
#  ('Emmen', 105853.0),
#  ('Zwolle', 105819.0),
#  ('Ede', 101574.0),
#  ('Delft', 95268.0),
#  ('Heerlen', 95052.0),
#  ('Alkmaar', 92713.0),
#  ('Tirana', 270000.0),
#  ('Alger', 2168000.0),
#  ('Oran', 609823.0),
#  ('Constantine', 443727.0),
#  ('Annaba', 222518.0),
#  ('Batna', 183377.0),
#  ('Skikda', 128747.0),
#  ('Biskra', 128281.0),
#  ('Blida (el-Boulaida)', 127284.0),
#  ('Mostaganem', 115212.0),
#  ('Tlemcen (Tilimsen)', 110242.0),
#  ('Tiaret', 100118.0),
#  ('Ech-Chleff (el-Asnam)', 96794.0),
#  ('Tafuna', 5200.0),
#  ('Fagatogo', 2323.0),
#  ('Andorra la Vella', 21189.0),
#  ('Luanda', 2022000.0),
#  ('Huambo', 163100.0),
#  ('Lobito', 130000.0),
#  ('Benguela', 128300.0),
#  ('Namibe', 118200.0),
#  ('Dubai', 669181.0),
#  ('Abu Dhabi', 398695.0),
#  ('Sharja', 320095.0),
#  ('al-Ayn', 225970.0),
#  ('Ajman', 114395.0),
#  ('Buenos Aires', 2982146.0),
#  ('La Matanza', 1266461.0),
#  ('Lomas de Zamora', 622013.0),
#  ('Quilmes', 559249.0),
#  ('Almirante Brown', 538918.0),
#  ('La Plata', 521936.0),
#  ('Mar del Plata', 512880.0),
#  ('Merlo', 463846.0),
#  ('Salta', 367550.0),
#  ('Moreno', 356993.0),
#  ('Avellaneda', 353046.0),
#  ('Tres de Febrero', 352311.0),
#  ('Florencio Varela', 315432.0),
#  ('San Isidro', 306341.0),
#  ('Tigre', 296226.0),
#  ('Malvinas Argentinas', 290335.0),
#  ('Berazategui', 276916.0),
#  ('Corrientes', 258103.0),
#  ('San Miguel', 248700.0),
#  ('Resistencia', 229212.0),
#  ('Godoy Cruz', 206998.0),
#  ('Posadas', 201273.0),
#  ('Santiago del Estero', 189947.0),
#  ('San Salvador de Jujuy', 178748.0),
#  ('Hurlingham', 170028.0),
#  ('San Fernando', 153036.0),
#  ('Formosa', 147636.0),
#  ('Las Heras', 145823.0),
#  ('La Rioja', 138117.0),
#  ('San Fernando del Valle de Cata', 134935.0),
#  ('Comodoro Rivadavia', 124104.0),
#  ('Mendoza', 123027.0),
#  ('San Juan', 119152.0),
#  ('Escobar', 116675.0),
#  ('Concordia', 116485.0),
#  ('Pilar', 113428.0),
#  ('San Luis', 110136.0),
#  ('Ezeiza', 99578.0),
#  ('San Rafael', 94651.0),
#  ('Tandil', 91101.0),
#  ('Yerevan', 1248700.0),
#  ('Vanadzor', 172700.0),
#  ('Sydney', 3276207.0),
#  ('Melbourne', 2865329.0),
#  ('Brisbane', 1291117.0),
#  ('Perth', 1096829.0),
#  ('Adelaide', 978100.0),
#  ('Canberra', 322723.0),
#  ('Gold Coast', 311932.0),
#  ('Newcastle', 270324.0),
#  ('Central Coast', 227657.0),
#  ('Wollongong', 219761.0),
#  ('Hobart', 126118.0),
#  ('Geelong', 125382.0),
#  ('Townsville', 109914.0),
#  ('Cairns', 92273.0),
#  ('Baku', 1787800.0),
#  ('Sumqayit', 283000.0),
#  ('Nassau', 172000.0),
#  ('al-Manama', 148000.0),
#  ('Dhaka', 3612850.0),
#  ('Chittagong', 1392860.0),
#  ('Khulna', 663340.0),
#  ('Rajshahi', 294056.0),
#  ('Narayanganj', 202134.0),
#  ('Rangpur', 191398.0),
#  ('Mymensingh', 188713.0),
#  ('Barisal', 170232.0),
#  ('Tungi', 168702.0),
#  ('Jessore', 139710.0),
#  ('Comilla', 135313.0),
#  ('Nawabganj', 130577.0),
#  ('Dinajpur', 127815.0),
#  ('Bogra', 120170.0),
#  ('Sylhet', 117396.0),
#  ('Brahmanbaria', 109032.0),
#  ('Tangail', 106004.0),
#  ('Jamalpur', 103556.0),
#  ('Pabna', 103277.0),
#  ('Naogaon', 101266.0),
#  ('Sirajganj', 99669.0),
#  ('Narsinghdi', 98342.0),
#  ('Saidpur', 96777.0),
#  ('Gazipur', 96717.0),
#  ('Bridgetown', 6070.0),
#  ('Antwerpen', 446525.0),
#  ('Gent', 224180.0),
#  ('Charleroi', 200827.0),
#  ('Bruxelles [Brussel]', 133859.0),
#  ('Brugge', 116246.0),
#  ('Schaerbeek', 105692.0),
#  ('Namur', 105419.0),
#  ('Mons', 90935.0),
#  ('Belize City', 55810.0),
#  ('Belmopan', 7105.0),
#  ('Cotonou', 536827.0),
#  ('Djougou', 134099.0),
#  ('Parakou', 103577.0),
#  ('Hamilton', 1200.0),
#  ('Thimphu', 22000.0),
#  ('Santa Cruz de la Sierra', 935361.0),
#  ('La Paz', 758141.0),
#  ('El Alto', 534466.0),
#  ('Cochabamba', 482800.0),
#  ('Oruro', 223553.0),
#  ('Sucre', 178426.0),
#  ('Tarija', 125255.0),
#  ('Sarajevo', 360000.0),
#  ('Banja Luka', 143079.0),
#  ('Zenica', 96027.0),
#  ('Gaborone', 213017.0),
#  ('Francistown', 101805.0),
#  ('Rio de Janeiro', 5598953.0),
#  ('Salvador', 2302832.0),
#  ('Belo Horizonte', 2139125.0),
#  ('Recife', 1378087.0),
#  ('Porto Alegre', 1314032.0),
#  ('Manaus', 1255049.0),
#  ('Duque de Caxias', 746758.0),
#  ('Natal', 688955.0),
#  ('Campo Grande', 649593.0),
#  ('Contagem', 520801.0),
#  ('Feira de Santana', 479992.0),
#  ('Juiz de Fora', 450288.0),
#  ('Aracaju', 445555.0),
#  ('Joinville', 428011.0),
#  ('Belford Roxo', 425194.0),
#  ('Campos dos Goytacazes', 398418.0),
#  ('Olinda', 354732.0),
#  ('Caxias do Sul', 349581.0),
#  ('Pelotas', 315415.0),
#  ('Betim', 302108.0),
#  ('Canoas', 294125.0),
#  ('Montes Claros', 286058.0),
#  ('Rio Branco', 259537.0),
#  ('Uberaba', 249225.0),
#  ('Paulista', 248473.0),
#  ('Blumenau', 244379.0),
#  ('Caruaru', 244247.0),
#  ('Volta Redonda', 240315.0),
#  ('Novo Hamburgo', 239940.0),
#  ('Santa Maria', 238473.0),
#  ('Governador Valadares', 231724.0),
#  ('Petrolina', 210540.0),
#  ('Ipatinga', 206338.0),
#  ('Juazeiro', 201073.0),
#  ('Sete Lagoas', 182984.0),
#  ('Rio Grande', 182222.0),
#  ('Itabuna', 182148.0),
#  ('Arapiraca', 178988.0),
#  ('Alvorada', 175574.0),
#  ('Nova Friburgo', 170697.0),
#  ('Barra Mansa', 168953.0),
#  ('Boa Vista', 167185.0),
#  ('Passo Fundo', 166343.0),
#  ('Dourados', 164716.0),
#  ('Santa Luzia', 164704.0),
#  ('Cabo de Santo Agostinho', 149964.0),
#  ('Lages', 139570.0),
#  ('Nossa Senhora do Socorro', 131351.0),
#  ('Barreiras', 127801.0),
#  ('Alagoinhas', 126820.0),
#  ('Uruguaiana', 126305.0),
#  ('Palmas', 121919.0),
#  ('Sapucaia do Sul', 120217.0),
#  ('Cabo Frio', 119503.0),
#  ('Patos de Minas', 119262.0),
#  ('Camaragibe', 118968.0),
#  ('Queimados', 115020.0),
#  ('Garanhuns', 114603.0),
#  ('Barbacena', 113079.0),
#  ('Lauro de Freitas', 109236.0),
#  ('Teixeira de Freitas', 108441.0),
#  ('Varginha', 108314.0),
#  ('Santa Cruz do Sul', 106734.0),
#  ('Cachoeirinha', 103240.0),
#  ('Itabira', 102217.0),
#  ('Resende', 100627.0),
#  ('Pouso Alegre', 100028.0),
#  ('Passos', 98570.0),
#  ('Araguari', 98399.0),
#  ('Conselheiro Lafaiete', 97507.0),
#  ('Paulo Afonso', 97291.0),
#  ('Angra dos Reis', 96864.0),
#  ('Parnamirim', 96210.0),
#  ('Jacobina', 96131.0),
#  ('Coronel Fabriciano', 95933.0),
#  ('Santana do Livramento', 91779.0),
#  ('Ituiutaba', 90507.0),
#  ('London', 7285000.0),
#  ('Birmingham', 1013000.0),
#  ('Glasgow', 619680.0),
#  ('Liverpool', 461000.0),
#  ('Edinburgh', 450180.0),
#  ('Sheffield', 431607.0),
#  ('Manchester', 430000.0),
#  ('Leeds', 424194.0),
#  ('Bristol', 402000.0),
#  ('Cardiff', 321000.0),
#  ('Coventry', 304000.0),
#  ('Leicester', 294000.0),
#  ('Bradford', 289376.0),
#  ('Belfast', 287500.0),
#  ('Nottingham', 287000.0),
#  ('Kingston upon Hull', 262000.0),
#  ('Plymouth', 253000.0),
#  ('Stoke-on-Trent', 252000.0),
#  ('Wolverhampton', 242000.0),
#  ('Derby', 236000.0),
#  ('Swansea', 230000.0),
#  ('Southampton', 216000.0),
#  ('Aberdeen', 213070.0),
#  ('Northampton', 196000.0),
#  ('Dudley', 192171.0),
#  ('Portsmouth', 190000.0),
#  ('Newcastle upon Tyne', 189150.0),
#  ('Sunderland', 183310.0),
#  ('Luton', 183000.0),
#  ('Swindon', 180000.0),
#  ('Southend-on-Sea', 176000.0),
#  ('Walsall', 174739.0),
#  ('Bournemouth', 162000.0),
#  ('Peterborough', 156000.0),
#  ('Brighton', 156124.0),
#  ('Blackpool', 151000.0),
#  ('Dundee', 146690.0),
#  ('West Bromwich', 146386.0),
#  ('Reading', 148000.0),
#  ('Oldbury/Smethwick (Warley)', 145542.0),
#  ('Middlesbrough', 145000.0),
#  ('Huddersfield', 143726.0),
#  ('Oxford', 144000.0),
#  ('Poole', 141000.0),
#  ('Bolton', 139020.0),
#  ('Blackburn', 140000.0),
#  ('Newport', 139000.0),
#  ('Preston', 135000.0),
#  ('Stockport', 132813.0),
#  ('Norwich', 124000.0),
#  ('Rotherham', 121380.0),
#  ('Cambridge', 121000.0),
#  ('Watford', 113080.0),
#  ('Ipswich', 114000.0),
#  ('Slough', 112000.0),
#  ('Exeter', 111000.0),
#  ('Cheltenham', 106000.0),
#  ('Gloucester', 107000.0),
#  ('Saint Helens', 106293.0),
#  ('Sutton Coldfield', 106001.0),
#  ('York', 104425.0),
#  ('Oldham', 103931.0),
#  ('Basildon', 100924.0),
#  ('Worthing', 100000.0),
#  ('Chelmsford', 97451.0),
#  ('Colchester', 96063.0),
#  ('Crawley', 97000.0),
#  ('Gillingham', 92000.0),
#  ('Solihull', 94531.0),
#  ('Rochdale', 94313.0),
#  ('Birkenhead', 93087.0),
#  ('Worcester', 95000.0),
#  ('Hartlepool', 92000.0),
#  ('Halifax', 91069.0),
#  ('Woking/Byfleet', 92000.0),
#  ('Southport', 90959.0),
#  ('Maidstone', 90878.0),
#  ('Eastbourne', 90000.0),
#  ('Grimsby', 89000.0),
#  ('Saint Helier', 27523.0),
#  ('Road Town', 8000.0),
#  ('Bandar Seri Begawan', 21484.0),
#  ('Sofija', 1122302.0),
#  ('Plovdiv', 342584.0),
#  ('Varna', 299801.0),
#  ('Burgas', 195255.0),
#  ('Ruse', 166467.0),
#  ('Stara Zagora', 147939.0),
#  ('Pleven', 121952.0),
#  ('Sliven', 105530.0),
#  ('Dobric', 100399.0),
#  ('Ouagadougou', 824000.0),
#  ('Bobo-Dioulasso', 300000.0),
#  ('Bujumbura', 300000.0),
#  ('George Town', 19600.0),
#  ('Santiago de Chile', 4703954.0),
#  ('Puente Alto', 386236.0),
#  ('Antofagasta', 251429.0),
#  ('San Bernardo', 241910.0),
#  ('Talca', 187557.0),
#  ('Puerto Montt', 152194.0),
#  ('Coquimbo', 143353.0),
#  ('Osorno', 141468.0),
#  ('La Serena', 137409.0),
#  ('Calama', 137265.0),
#  ('Valdivia', 133106.0),
#  ('Punta Arenas', 125631.0),
#  ('Ovalle', 94854.0),
#  ('Melipilla', 91056.0),
#  ('Avarua', 11900.0),
#  ('Djibouti', 383000.0),
#  ('Roseau', 16243.0),
#  ('Santiago de los Caballeros', 365463.0),
#  ('La Romana', 140204.0),
#  ('San Felipe de Puerto Plata', 89423.0),
#  ('Guayaquil', 2070040.0),
#  ('Quito', 1573458.0),
#  ('Cuenca', 270353.0),
#  ('Machala', 210368.0),
#  ('Santo Domingo de los Colorados', 202111.0),
#  ('Ambato', 169612.0),
#  ('Duran [Eloy Alfaro]', 152514.0),
#  ('Ibarra', 130643.0),
#  ('Milagro', 124177.0),
#  ('Loja', 123875.0),
#  ('Esmeraldas', 123045.0),
#  ('Cairo', 6789479.0),
#  ('Alexandria', 3328196.0),
#  ('Giza', 2221868.0),
#  ('Shubra al-Khayma', 870716.0),
#  ('Port Said', 469533.0),
#  ('Suez', 417610.0),
#  ('al-Mahallat al-Kubra', 395402.0),
#  ('Tanta', 371010.0),
#  ('al-Mansura', 369621.0),
#  ('Luxor', 360503.0),
#  ('Asyut', 343498.0),
#  ('Bahtim', 275807.0),
#  ('Zagazig', 267351.0),
#  ('al-Faiyum', 260964.0),
#  ('Ismailia', 254477.0),
#  ('Kafr al-Dawwar', 231978.0),
#  ('Assuan', 219017.0),
#  ('Damanhur', 212203.0),
#  ('al-Minya', 201360.0),
#  ('Bani Suwayf', 172032.0),
#  ('Qina', 171275.0),
#  ('Sawhaj', 170125.0),
#  ('Shibin al-Kawm', 159909.0),
#  ('Bulaq al-Dakrur', 148787.0),
#  ('Banha', 145792.0),
#  ('Warraq al-Arab', 127108.0),
#  ('Kafr al-Shaykh', 124819.0),
#  ('Mallawi', 119283.0),
#  ('Bilbays', 113608.0),
#  ('Mit Ghamr', 101801.0),
#  ('al-Arish', 100447.0),
#  ('Talkha', 97700.0),
#  ('Qalyub', 97200.0),
#  ('Jirja', 95400.0),
#  ('Idfu', 94200.0),
#  ('al-Hawamidiya', 91700.0),
#  ('Disuq', 91300.0),
#  ('San Salvador', 415346.0),
#  ('Santa Ana', 139389.0),
#  ('Mejicanos', 138800.0),
#  ('Soyapango', 129800.0),
#  ('San Miguel', 127696.0),
#  ('Nueva San Salvador', 98400.0),
#  ('Apopa', 88800.0),
#  ('Asmara', 431000.0),
#  ('Madrid', 2879052.0),
#  ('Barcelona', 1503451.0),
#  ('Valencia', 739412.0),
#  ('Sevilla', 701927.0),
#  ('Zaragoza', 603367.0),
#  ('Bilbao', 357589.0),
#  ('Las Palmas de Gran Canaria', 354757.0),
#  ('Murcia', 353504.0),
#  ('Palma de Mallorca', 326993.0),
#  ('Vigo', 283670.0),
#  ('Alicante [Alacant]', 272432.0),
#  ('Granada', 244767.0),
#  ('Vitoria-Gasteiz', 217154.0),
#  ('Santa Cruz de Tenerife', 213050.0),
#  ('Badalona', 209635.0),
#  ('Oviedo', 200453.0),
#  ('Elche [Elx]', 193174.0),
#  ('Sabadell', 184859.0),
#  ('Santander', 184165.0),
#  ('Jerez de la Frontera', 182660.0),
#  ('Cartagena', 177709.0),
#  ('Fuenlabrada', 171173.0),
#  ('Terrassa', 168695.0),
#  ('Albacete', 147527.0),
#  ('Getafe', 145371.0),
#  ('Huelva', 140583.0),
#  ('Badajoz', 136613.0),
#  ('Santa Coloma de Gramenet', 120802.0),
#  ('Tarragona', 113016.0),
#  ('Ourense (Orense)', 109120.0),
#  ('Algeciras', 103106.0),
#  ('Marbella', 101144.0),
#  ('Barakaldo', 98212.0),
#  ('Dos Hermanas', 94591.0),
#  ('Santiago de Compostela', 93745.0),
#  ('Cape Town', 2352121.0),
#  ('Soweto', 904165.0),
#  ('Johannesburg', 756653.0),
#  ('Port Elizabeth', 752319.0),
#  ('Pretoria', 658630.0),
#  ('Inanda', 634065.0),
#  ('Durban', 566120.0),
#  ('Vanderbijlpark', 468931.0),
#  ('Kempton Park', 442633.0),
#  ('Alberton', 410102.0),
#  ('Pinetown', 378810.0),
#  ('Pietermaritzburg', 370190.0),
#  ('Benoni', 365467.0),
#  ('Randburg', 341288.0),
#  ('Umlazi', 339233.0),
#  ('Bloemfontein', 334341.0),
#  ('Vereeniging', 328535.0),
#  ('Wonderboom', 283289.0),
#  ('Roodepoort', 279340.0),
#  ('Boksburg', 262648.0),
#  ('Klerksdorp', 261911.0),
#  ('Soshanguve', 242727.0),
#  ('Newcastle', 222993.0),
#  ('East London', 221047.0),
#  ('Welkom', 203296.0),
#  ('Kimberley', 197254.0),
#  ('Uitenhage', 192120.0),
#  ('Chatsworth', 189885.0),
#  ('Mdantsane', 182639.0),
#  ('Krugersdorp', 181503.0),
#  ('Botshabelo', 177971.0),
#  ('Brakpan', 171363.0),
#  ('Witbank', 167183.0),
#  ('Oberholzer', 164367.0),
#  ('Germiston', 164252.0),
#  ('Springs', 162072.0),
#  ('Westonaria', 159632.0),
#  ('Randfontein', 120838.0),
#  ('Paarl', 105768.0),
#  ('Potchefstroom', 101817.0),
#  ('Rustenburg', 97008.0),
#  ('Nigel', 96734.0),
#  ('George', 93818.0),
#  ('Ladysmith', 89292.0),
#  ('Addis Abeba', 2495000.0),
#  ('Dire Dawa', 164851.0),
#  ('Nazret', 127842.0),
#  ('Gonder', 112249.0),
#  ('Dese', 97314.0),
#  ('Mekele', 96938.0),
#  ('Bahir Dar', 96140.0),
#  ('Stanley', 1636.0),
#  ('Suva', 77366.0),
#  ('Quezon', 2173831.0),
#  ('Manila', 1581082.0),
#  ('Kalookan', 1177604.0),
#  ('Davao', 1147116.0),
#  ('Cebu', 718821.0),
#  ('Zamboanga', 601794.0),
#  ('Pasig', 505058.0),
#  ('Valenzuela', 485433.0),
#  ('Antipolo', 470866.0),
#  ('Taguig', 467375.0),
#  ('Cagayan de Oro', 461877.0),
#  ('Makati', 444867.0),
#  ('Bacolod', 429076.0),
#  ('General Santos', 411822.0),
#  ('Marikina', 391170.0),
#  ('Muntinlupa', 379310.0),
#  ('Iloilo', 365820.0),
#  ('Pasay', 354908.0),
#  ('Malabon', 338855.0),
#  ('Bacoor', 305699.0),
#  ('Iligan', 285061.0),
#  ('Calamba', 281146.0),
#  ('Mandaluyong', 278474.0),
#  ('Butuan', 267279.0),
#  ('Angeles', 263971.0),
#  ('Tarlac', 262481.0),
#  ('Mandaue', 259728.0),
#  ('Baguio', 252386.0),
#  ('Batangas', 247588.0),
#  ('Cainta', 242511.0),
#  ('San Pedro', 231403.0),
#  ('Navotas', 230403.0),
#  ('Cabanatuan', 222859.0),
#  ('San Fernando', 221857.0),
#  ('Lipa', 218447.0),
#  ('Lapu-Lapu', 217019.0),
#  ('San Pablo', 207927.0),
#  ('Taytay', 198183.0),
#  ('Lucena', 196075.0),
#  ('Imus', 195482.0),
#  ('Olongapo', 194260.0),
#  ('Binangonan', 187691.0),
#  ('Santa Rosa', 185633.0),
#  ('Tagum', 179531.0),
#  ('Tacloban', 178639.0),
#  ('Malolos', 175291.0),
#  ('Mabalacat', 171045.0),
#  ('Cotabato', 163849.0),
#  ('Meycauayan', 163037.0),
#  ('Puerto Princesa', 161912.0),
#  ('Legazpi', 157010.0),
#  ('Silang', 156137.0),
#  ('Ormoc', 154297.0),
#  ('San Carlos', 154264.0),
#  ('Kabankalan', 149769.0),
#  ('Talisay', 148110.0),
#  ('Valencia', 147924.0),
#  ('Calbayog', 147187.0),
#  ('Santa Maria', 144282.0),
#  ('Pagadian', 142515.0),
#  ('Cadiz', 141954.0),
#  ('Bago', 141721.0),
#  ('Toledo', 141174.0),
#  ('Naga', 137810.0),
#  ('San Mateo', 135603.0),
#  ('Panabo', 133950.0),
#  ('Koronadal', 133786.0),
#  ('Marawi', 131090.0),
#  ('Dagupan', 130328.0),
#  ('Sagay', 129765.0),
#  ('Roxas', 126352.0),
#  ('Lubao', 125699.0),
#  ('Digos', 125171.0),
#  ('San Miguel', 123824.0),
#  ('Malaybalay', 123672.0),
#  ('Tuguegarao', 120645.0),
#  ('Ilagan', 119990.0),
#  ('Baliuag', 119675.0),
#  ('Surigao', 118534.0),
#  ('San Carlos', 118259.0),
#  ('San Juan del Monte', 117680.0),
#  ('Tanauan', 117539.0),
#  ('Concepcion', 115171.0),
#  ('Rodriguez (Montalban)', 115167.0),
#  ('Sariaya', 114568.0),
#  ('Malasiqui', 113190.0),
#  ('General Mariano Alvarez', 112446.0),
#  ('Urdaneta', 111582.0),
#  ('Hagonoy', 111425.0),
#  ('San Jose', 111009.0),
#  ('Polomolok', 110709.0),
#  ('Santiago', 110531.0),
#  ('Tanza', 110517.0),
#  ('Ozamis', 110420.0),
#  ('Mexico', 109481.0),
#  ('San Jose', 108254.0),
#  ('Silay', 107722.0),
#  ('General Trias', 107691.0),
#  ('Tabaco', 107166.0),
#  ('Cabuyao', 106630.0),
#  ('Calapan', 105910.0),
#  ('Mati', 105908.0),
#  ('Midsayap', 105760.0),
#  ('Cauayan', 103952.0),
#  ('Gingoog', 102379.0),
#  ('Dumaguete', 102265.0),
#  ('San Fernando', 102082.0),
#  ('Arayat', 101792.0),
#  ('Bayawan (Tulong)', 101391.0),
#  ('Kidapawan', 101205.0),
#  ('Daraga (Locsin)', 101031.0),
#  ('Marilao', 101017.0),
#  ('Malita', 100000.0),
#  ('Dipolog', 99862.0),
#  ('Cavite', 99367.0),
#  ('Danao', 98781.0),
#  ('Bislig', 97860.0),
#  ('Talavera', 97329.0),
#  ('Guagua', 96858.0),
#  ('Bayambang', 96609.0),
#  ('Nasugbu', 96113.0),
#  ('Baybay', 95630.0),
#  ('Capas', 95219.0),
#  ('Sultan Kudarat', 94861.0),
#  ('Laoag', 94466.0),
#  ('Bayugan', 93623.0),
#  ('Malungon', 93232.0),
#  ('Santa Cruz', 92694.0),
#  ('Sorsogon', 92512.0),
#  ('Candelaria', 92429.0),
#  ('Ligao', 90603.0),
#  ('Libreville', 419000.0),
#  ('Serekunda', 102600.0),
#  ('Banjul', 42326.0),
#  ('Tbilisi', 1235200.0),
#  ('Kutaisi', 240900.0),
#  ('Rustavi', 155400.0),
#  ('Sohumi', 111700.0),
#  ('Accra', 1070000.0),
#  ('Kumasi', 385192.0),
#  ('Tamale', 151069.0),
#  ('Tema', 109975.0),
#  ('Sekondi-Takoradi', 103653.0),
#  ('Nuuk', 13445.0),
#  ('Les Abymes', 62947.0),
#  ('Basse-Terre', 12433.0),
#  ('Ciudad de Guatemala', 823301.0),
#  ('Mixco', 209791.0),
#  ('Villa Nueva', 101295.0),
#  ('Quetzaltenango', 90801.0),
#  ('Conakry', 1090610.0),
#  ('Bissau', 241000.0),
#  ('Georgetown', 254000.0),
#  ('Port-au-Prince', 884472.0),
#  ('Carrefour', 290204.0),
#  ('Delmas', 240429.0),
#  ('Tegucigalpa', 813900.0),
#  ('Kowloon and New Kowloon', 1987996.0),
#  ('Victoria', 1312637.0),
#  ('Jakarta', 9604900.0),
#  ('Surabaya', 2663820.0),
#  ('Bandung', 2429000.0),
#  ('Medan', 1843919.0),
#  ('Palembang', 1222764.0),
#  ('Tangerang', 1198300.0),
#  ('Semarang', 1104405.0),
#  ('Ujung Pandang', 1060257.0),
#  ('Malang', 716862.0),
#  ('Bandar Lampung', 680332.0),
#  ('Bekasi', 644300.0),
#  ('Padang', 534474.0),
#  ('Surakarta', 518600.0),
#  ('Banjarmasin', 482931.0),
#  ('Pekan Baru', 438638.0),
#  ('Denpasar', 435000.0),
#  ('Yogyakarta', 418944.0),
#  ('Pontianak', 409632.0),
#  ('Samarinda', 399175.0),
#  ('Jambi', 385201.0),
#  ('Depok', 365200.0),
#  ('Cimahi', 344600.0),
#  ('Balikpapan', 338752.0),
#  ('Manado', 332288.0),
#  ('Mataram', 306600.0),
#  ('Pekalongan', 301504.0),
#  ('Tegal', 289744.0),
#  ('Bogor', 285114.0),
#  ('Ciputat', 270800.0),
#  ('Pondokgede', 263200.0),
#  ('Cirebon', 254406.0),
#  ('Kediri', 253760.0),
#  ('Ambon', 249312.0),
#  ('Jember', 218500.0),
#  ('Cilacap', 206900.0),
#  ('Cimanggis', 205100.0),
#  ('Pematang Siantar', 203056.0),
#  ('Purwokerto', 202500.0),
#  ('Ciomas', 187400.0),
#  ('Tasikmalaya', 179800.0),
#  ('Madiun', 171532.0),
#  ('Bengkulu', 146439.0),
#  ('Karawang', 145000.0),
#  ('Banda Aceh', 143409.0),
#  ('Palu', 142800.0),
#  ('Pasuruan', 134019.0),
#  ('Kupang', 129300.0),
#  ('Tebing Tinggi', 129300.0),
#  ('Percut Sei Tuan', 129000.0),
#  ('Binjai', 127222.0),
#  ('Sukabumi', 125766.0),
#  ('Waru', 124300.0),
#  ('Pangkal Pinang', 124000.0),
#  ('Magelang', 123800.0),
#  ('Blitar', 122600.0),
#  ('Serang', 122400.0),
#  ('Probolinggo', 120770.0),
#  ('Cilegon', 117000.0),
#  ('Cianjur', 114300.0),
#  ('Ciparay', 111500.0),
#  ('Lhokseumawe', 109600.0),
#  ('Taman', 107000.0),
#  ('Depok', 106800.0),
#  ('Citeureup', 105100.0),
#  ('Pemalang', 103500.0),
#  ('Klaten', 103300.0),
#  ('Salatiga', 103000.0),
#  ('Cibinong', 101300.0),
#  ('Palangka Raya', 99693.0),
#  ('Mojokerto', 96626.0),
#  ('Purwakarta', 95900.0),
#  ('Garut', 95800.0),
#  ('Kudus', 95300.0),
#  ('Kendari', 94800.0),
#  ('Jaya Pura', 94700.0),
#  ('Gorontalo', 94058.0),
#  ('Majalaya', 93200.0),
#  ('Pondok Aren', 92700.0),
#  ('Jombang', 92600.0),
#  ('Sunggal', 92300.0),
#  ('Batam', 91871.0),
#  ('Padang Sidempuan', 91200.0),
#  ('Sawangan', 91100.0),
#  ('Banyuwangi', 89900.0),
#  ('Tanjung Pinang', 89900.0),
#  ('Mumbai (Bombay)', 10500000.0),
#  ('Delhi', 7206704.0),
#  ('Calcutta [Kolkata]', 4399819.0),
#  ('Chennai (Madras)', 3841396.0),
#  ('Hyderabad', 2964638.0),
#  ('Ahmedabad', 2876710.0),
#  ('Bangalore', 2660088.0),
#  ('Kanpur', 1874409.0),
#  ('Nagpur', 1624752.0),
#  ('Lucknow', 1619115.0),
#  ('Pune', 1566651.0),
#  ('Surat', 1498817.0),
#  ('Jaipur', 1458483.0),
#  ('Indore', 1091674.0),
#  ('Bhopal', 1062771.0),
#  ('Ludhiana', 1042740.0),
#  ('Vadodara (Baroda)', 1031346.0),
#  ('Kalyan', 1014557.0),
#  ('Madurai', 977856.0),
#  ('Haora (Howrah)', 950435.0),
#  ('Varanasi (Benares)', 929270.0),
#  ('Patna', 917243.0),
#  ('Srinagar', 892506.0),
#  ('Agra', 891790.0),
#  ('Coimbatore', 816321.0),
#  ('Thane (Thana)', 803389.0),
#  ('Allahabad', 792858.0),
#  ('Meerut', 753778.0),
#  ('Vishakhapatnam', 752037.0),
#  ('Jabalpur', 741927.0),
#  ('Amritsar', 708835.0),
#  ('Faridabad', 703592.0),
#  ('Vijayawada', 701827.0),
#  ('Gwalior', 690765.0),
#  ('Jodhpur', 666279.0),
#  ('Nashik (Nasik)', 656925.0),
#  ('Hubli-Dharwad', 648298.0),
#  ('Solapur (Sholapur)', 604215.0),
#  ('Ranchi', 599306.0),
#  ('Bareilly', 587211.0),
#  ('Guwahati (Gauhati)', 584342.0),
#  ('Shambajinagar (Aurangabad)', 573272.0),
#  ('Cochin (Kochi)', 564589.0),
#  ('Rajkot', 559407.0),
#  ('Kota', 537371.0),
#  ('Thiruvananthapuram (Trivandrum', 524006.0),
#  ('Pimpri-Chinchwad', 517083.0),
#  ('Jalandhar (Jullundur)', 509510.0),
#  ('Gorakhpur', 505566.0),
#  ('Chandigarh', 504094.0),
#  ('Mysore', 480692.0),
#  ('Aligarh', 480520.0),
#  ('Guntur', 471051.0),
#  ('Jamshedpur', 460577.0),
#  ('Ghaziabad', 454156.0),
#  ('Warangal', 447657.0),
#  ('Raipur', 438639.0),
#  ('Moradabad', 429214.0),
#  ('Durgapur', 425836.0),
#  ('Amravati', 421576.0),
#  ('Calicut (Kozhikode)', 419831.0),
#  ('Bikaner', 416289.0),
#  ('Bhubaneswar', 411542.0),
#  ('Kolhapur', 406370.0),
#  ('Kataka (Cuttack)', 403418.0),
#  ('Ajmer', 402700.0),
#  ('Bhavnagar', 402338.0),
#  ('Tiruchirapalli', 387223.0),
#  ('Bhilai', 386159.0),
#  ('Bhiwandi', 379070.0),
#  ('Saharanpur', 374945.0),
#  ('Ulhasnagar', 369077.0),
#  ('Salem', 366712.0),
#  ('Ujjain', 362266.0),
#  ('Malegaon', 342595.0),
#  ('Jamnagar', 341637.0),
#  ('Bokaro Steel City', 333683.0),
#  ('Akola', 328034.0),
#  ('Belgaum', 326399.0),
#  ('Rajahmundry', 324851.0),
#  ('Nellore', 316606.0),
#  ('Udaipur', 308571.0),
#  ('New Bombay', 307297.0),
#  ('Bhatpara', 304952.0),
#  ('Gulbarga', 304099.0),
#  ('New Delhi', 301297.0),
#  ('Jhansi', 300850.0),
#  ('Gaya', 291675.0),
#  ('Kakinada', 279980.0),
#  ('Dhule (Dhulia)', 278317.0),
#  ('Panihati', 275990.0),
#  ('Nanded (Nander)', 275083.0),
#  ('Mangalore', 273304.0),
#  ('Dehra Dun', 270159.0),
#  ('Kamarhati', 266889.0),
#  ('Davangere', 266082.0),
#  ('Asansol', 262188.0),
#  ('Bhagalpur', 253225.0),
#  ('Bellary', 245391.0),
#  ('Barddhaman (Burdwan)', 245079.0),
#  ('Rampur', 243742.0),
#  ('Jalgaon', 242193.0),
#  ('Muzaffarpur', 241107.0),
#  ('Nizamabad', 241034.0),
#  ('Muzaffarnagar', 240609.0),
#  ('Patiala', 238368.0),
#  ('Shahjahanpur', 237713.0),
#  ('Kurnool', 236800.0),
#  ('Tiruppur (Tirupper)', 235661.0),
#  ('Rohtak', 233400.0),
#  ('South Dum Dum', 232811.0),
#  ('Mathura', 226691.0),
#  ('Chandrapur', 226105.0),
#  ('Barahanagar (Baranagar)', 224821.0),
#  ('Darbhanga', 218391.0),
#  ('Siliguri (Shiliguri)', 216950.0),
#  ('Raurkela', 215489.0),
#  ('Ambattur', 215424.0),
#  ('Panipat', 215218.0),
#  ('Firozabad', 215128.0),
#  ('Ichalkaranji', 214950.0),
#  ('Jammu', 214737.0),
#  ('Ramagundam', 214384.0),
#  ('Eluru', 212866.0),
#  ('Brahmapur', 210418.0),
#  ('Alwar', 205086.0),
#  ('Pondicherry', 203065.0),
#  ('Thanjavur', 202013.0),
#  ('Bihar Sharif', 201323.0),
#  ('Tuticorin', 199854.0),
#  ('Imphal', 198535.0),
#  ('Latur', 197408.0),
#  ('Sagar', 195346.0),
#  ('Farrukhabad-cum-Fatehgarh', 194567.0),
#  ('Sangli', 193197.0),
#  ('Parbhani', 190255.0),
#  ('Nagar Coil', 190084.0),
#  ('Bijapur', 186939.0),
#  ('Kukatpalle', 185378.0),
#  ('Bally', 184474.0),
#  ('Bhilwara', 183965.0),
#  ('Ratlam', 183375.0),
#  ('Avadi', 183215.0),
#  ('Dindigul', 182477.0),
#  ('Ahmadnagar', 181339.0),
#  ('Bilaspur', 179833.0),
#  ('Shimoga', 179258.0),
#  ('Kharagpur', 177989.0),
#  ('Mira Bhayandar', 175372.0),
#  ('Vellore', 175061.0),
#  ('Jalna', 174985.0),
#  ('Burnpur', 174933.0),
#  ('Anantapur', 174924.0),
#  ('Allappuzha (Alleppey)', 174666.0),
#  ('Tirupati', 174369.0),
#  ('Karnal', 173751.0),
#  ('Burhanpur', 172710.0),
#  ('Hisar (Hissar)', 172677.0),
#  ('Tiruvottiyur', 172562.0),
#  ('Mirzapur-cum-Vindhyachal', 169336.0),
#  ('Secunderabad', 167461.0),
#  ('Nadiad', 167051.0),
#  ('Dewas', 164364.0),
#  ('Murwara (Katni)', 163431.0),
#  ('Ganganagar', 161482.0),
#  ('Vizianagaram', 160359.0),
#  ('Erode', 159232.0),
#  ('Machilipatnam (Masulipatam)', 159110.0),
#  ('Bhatinda (Bathinda)', 159042.0),
#  ('Raichur', 157551.0),
#  ('Agartala', 157358.0),
#  ('Arrah (Ara)', 157082.0),
#  ('Satna', 156630.0),
#  ('Lalbahadur Nagar', 155500.0),
#  ('Aizawl', 155240.0),
#  ('Uluberia', 155172.0),
#  ('Katihar', 154367.0),
#  ('Cuddalore', 153086.0),
#  ('Hugli-Chinsurah', 151806.0),
#  ('Dhanbad', 151789.0),
#  ('Raiganj', 151045.0),
#  ('Sambhal', 150869.0),
#  ('Durg', 150645.0),
#  ('Munger (Monghyr)', 150112.0),
#  ('Kanchipuram', 150100.0),
#  ('North Dum Dum', 149965.0),
#  ('Karimnagar', 148583.0),
#  ('Bharatpur', 148519.0),
#  ('Sikar', 148272.0),
#  ('Hardwar (Haridwar)', 147305.0),
#  ('Dabgram', 147217.0),
#  ('Morena', 147124.0),
#  ('Noida', 146514.0),
#  ('Hapur', 146262.0),
#  ('Bhusawal', 145143.0),
#  ('Khandwa', 145133.0),
#  ('Yamuna Nagar', 144346.0),
#  ('Sonipat (Sonepat)', 143922.0),
#  ('Tenali', 143726.0),
#  ('Raurkela Civil Township', 140408.0),
#  ('Kollam (Quilon)', 139852.0),
#  ('Kumbakonam', 139483.0),
#  ('Ingraj Bazar (English Bazar)', 139204.0),
#  ('Timkur', 138903.0),
#  ('Amroha', 137061.0),
#  ('Serampore', 137028.0),
#  ('Chapra', 136877.0),
#  ('Pali', 136842.0),
#  ('Maunath Bhanjan', 136697.0),
#  ('Adoni', 136182.0),
#  ('Jaunpur', 136062.0),
#  ('Tirunelveli', 135825.0),
#  ('Bahraich', 135400.0),
#  ('Gadag Betigeri', 134051.0),
#  ('Proddatur', 133914.0),
#  ('Chittoor', 133462.0),
#  ('Barrackpur', 133265.0),
#  ('Bharuch (Broach)', 133102.0),
#  ('Naihati', 132701.0),
#  ('Shillong', 131719.0),
#  ('Sambalpur', 131138.0),
#  ('Junagadh', 130484.0),
#  ('Rae Bareli', 129904.0),
#  ('Rewa', 128981.0),
#  ('Gurgaon', 128608.0),
#  ('Khammam', 127992.0),
#  ('Bulandshahr', 127201.0),
#  ('Navsari', 126089.0),
#  ('Malkajgiri', 126066.0),
#  ('Midnapore (Medinipur)', 125498.0),
#  ('Miraj', 125407.0),
#  ('Raj Nandgaon', 125371.0),
#  ('Alandur', 125244.0),
#  ('Puri', 125199.0),
#  ('Navadwip', 125037.0),
#  ('Sirsa', 125000.0),
#  ('Korba', 124501.0),
#  ('Faizabad', 124437.0),
#  ('Etawah', 124072.0),
#  ('Pathankot', 123930.0),
#  ('Gandhinagar', 123359.0),
#  ('Palghat (Palakkad)', 123289.0),
#  ('Veraval', 123000.0),
#  ('Hoshiarpur', 122705.0),
#  ('Ambala', 122596.0),
#  ('Sitapur', 121842.0),
#  ('Bhiwani', 121629.0),
#  ('Cuddapah', 121463.0),
#  ('Bhimavaram', 121314.0),
#  ('Krishnanagar', 121110.0),
#  ('Chandannagar', 120378.0),
#  ...]

# %% [markdown]
# ## SELECT DISTINCT
#
# Often your results will include many duplicate values. If you want to **select all the unique values from a column**, you can use the `DISTINCT` keyword.
#
# `SELECT DISTINCT <column name> FROM <table>`.
#
# This might be useful if, for example, you're interested in knowing which languages are represented in the `CountryLanguage` table.

# %% [markdown]
# ## SELECT DISTINCT
#
# **TASK**: Select all distinct languages in the `CountryLanguage` table.

# %%
# %%sql
# SELECT DISTINCT Language
# FROM CountryLanguage
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 457 rows affected.
# [('Dutch',),
#  ('English',),
#  ('Papiamento',),
#  ('Spanish',),
#  ('Balochi',),
#  ('Dari',),
#  ('Pashto',),
#  ('Turkmenian',),
#  ('Uzbek',),
#  ('Ambo',),
#  ('Chokwe',),
#  ('Kongo',),
#  ('Luchazi',),
#  ('Luimbe-nganguela',),
#  ('Luvale',),
#  ('Mbundu',),
#  ('Nyaneka-nkhumbi',),
#  ('Ovimbundu',),
#  ('Albaniana',),
#  ('Greek',),
#  ('Macedonian',),
#  ('Catalan',),
#  ('French',),
#  ('Portuguese',),
#  ('Arabic',),
#  ('Hindi',),
#  ('Indian Languages',),
#  ('Italian',),
#  ('Armenian',),
#  ('Azerbaijani',),
#  ('Samoan',),
#  ('Tongan',),
#  ('Creole English',),
#  ('Canton Chinese',),
#  ('German',),
#  ('Serbo-Croatian',),
#  ('Vietnamese',),
#  ('Czech',),
#  ('Hungarian',),
#  ('Polish',),
#  ('Romanian',),
#  ('Slovene',),
#  ('Turkish',),
#  ('Lezgian',),
#  ('Russian',),
#  ('Kirundi',),
#  ('Swahili',),
#  ('Adja',),
#  ('Aizo',),
#  ('Bariba',),
#  ('Fon',),
#  ('Ful',),
#  ('Joruba',),
#  ('Somba',),
#  ('Busansi',),
#  ('Dagara',),
#  ('Dyula',),
#  ('Gurma',),
#  ('Mossi',),
#  ('Bengali',),
#  ('Chakma',),
#  ('Garo',),
#  ('Khasi',),
#  ('Marma',),
#  ('Santhali',),
#  ('Tripuri',),
#  ('Bulgariana',),
#  ('Romani',),
#  ('Creole French',),
#  ('Belorussian',),
#  ('Ukrainian',),
#  ('Garifuna',),
#  ('Maya Languages',),
#  ('Aimará',),
#  ('Guaraní',),
#  ('Ketšua',),
#  ('Japanese',),
#  ('Bajan',),
#  ('Chinese',),
#  ('Malay',),
#  ('Malay-English',),
#  ('Asami',),
#  ('Dzongkha',),
#  ('Nepali',),
#  ('Khoekhoe',),
#  ('Ndebele',),
#  ('San',),
#  ('Shona',),
#  ('Tswana',),
#  ('Banda',),
#  ('Gbaya',),
#  ('Mandjia',),
#  ('Mbum',),
#  ('Ngbaka',),
#  ('Sara',),
#  ('Eskimo Languages',),
#  ('Punjabi',),
#  ('Romansh',),
#  ('Araucan',),
#  ('Rapa nui',),
#  ('Dong',),
#  ('Hui',),
#  ('Mantšu',),
#  ('Miao',),
#  ('Mongolian',),
#  ('Puyi',),
#  ('Tibetan',),
#  ('Tujia',),
#  ('Uighur',),
#  ('Yi',),
#  ('Zhuang',),
#  ('Akan',),
#  ('Gur',),
#  ('Kru',),
#  ('Malinke',),
#  ('[South]Mande',),
#  ('Bamileke-bamum',),
#  ('Duala',),
#  ('Fang',),
#  ('Maka',),
#  ('Mandara',),
#  ('Masana',),
#  ('Tikar',),
#  ('Boa',),
#  ('Luba',),
#  ('Mongo',),
#  ('Ngala and Bangi',),
#  ('Rundi',),
#  ('Rwanda',),
#  ('Teke',),
#  ('Zande',),
#  ('Mbete',),
#  ('Mboshi',),
#  ('Punu',),
#  ('Sango',),
#  ('Maori',),
#  ('Arawakan',),
#  ('Caribbean',),
#  ('Chibcha',),
#  ('Comorian',),
#  ('Comorian-Arabic',),
#  ('Comorian-French',),
#  ('Comorian-madagassi',),
#  ('Comorian-Swahili',),
#  ('Crioulo',),
#  ('Moravian',),
#  ('Silesiana',),
#  ('Slovak',),
#  ('Southern Slavic Languages',),
#  ('Afar',),
#  ('Somali',),
#  ('Danish',),
#  ('Norwegian',),
#  ('Swedish',),
#  ('Berberi',),
#  ('Sinaberberi',),
#  ('Bilin',),
#  ('Hadareb',),
#  ('Saho',),
#  ('Tigre',),
#  ('Tigrinja',),
#  ('Basque',),
#  ('Galecian',),
#  ('Estonian',),
#  ('Finnish',),
#  ('Amhara',),
#  ('Gurage',),
#  ('Oromo',),
#  ('Sidamo',),
#  ('Walaita',),
#  ('Saame',),
#  ('Fijian',),
#  ('Faroese',),
#  ('Kosrean',),
#  ('Mortlock',),
#  ('Pohnpei',),
#  ('Trukese',),
#  ('Wolea',),
#  ('Yap',),
#  ('Mpongwe',),
#  ('Punu-sira-nzebi',),
#  ('Gaeli',),
#  ('Kymri',),
#  ('Abhyasi',),
#  ('Georgiana',),
#  ('Osseetti',),
#  ('Ewe',),
#  ('Ga-adangme',),
#  ('Kissi',),
#  ('Kpelle',),
#  ('Loma',),
#  ('Susu',),
#  ('Yalunka',),
#  ('Diola',),
#  ('Soninke',),
#  ('Wolof',),
#  ('Balante',),
#  ('Mandyako',),
#  ('Bubi',),
#  ('Greenlandic',),
#  ('Cakchiquel',),
#  ('Kekchí',),
#  ('Mam',),
#  ('Quiché',),
#  ('Chamorro',),
#  ('Korean',),
#  ('Philippene Languages',),
#  ('Chiu chau',),
#  ('Fukien',),
#  ('Hakka',),
#  ('Miskito',),
#  ('Haiti Creole',),
#  ('Bali',),
#  ('Banja',),
#  ('Batakki',),
#  ('Bugi',),
#  ('Javanese',),
#  ('Madura',),
#  ('Minangkabau',),
#  ('Sunda',),
#  ('Gujarati',),
#  ('Kannada',),
#  ('Malajalam',),
#  ('Marathi',),
#  ('Orija',),
#  ('Tamil',),
#  ('Telugu',),
#  ('Urdu',),
#  ('Irish',),
#  ('Bakhtyari',),
#  ('Gilaki',),
#  ('Kurdish',),
#  ('Luri',),
#  ('Mazandarani',),
#  ('Persian',),
#  ('Assyrian',),
#  ('Icelandic',),
#  ('Hebrew',),
#  ('Friuli',),
#  ('Sardinian',),
#  ('Circassian',),
#  ('Ainu',),
#  ('Kazakh',),
#  ('Tatar',),
#  ('Gusii',),
#  ('Kalenjin',),
#  ('Kamba',),
#  ('Kikuyu',),
#  ('Luhya',),
#  ('Luo',),
#  ('Masai',),
#  ('Meru',),
#  ('Nyika',),
#  ('Turkana',),
#  ('Kirgiz',),
#  ('Tadzhik',),
#  ('Khmer',),
#  ('Tšam',),
#  ('Kiribati',),
#  ('Tuvalu',),
#  ('Lao',),
#  ('Lao-Soung',),
#  ('Mon-khmer',),
#  ('Thai',),
#  ('Bassa',),
#  ('Gio',),
#  ('Grebo',),
#  ('Mano',),
#  ('Mixed Languages',),
#  ('Singali',),
#  ('Sotho',),
#  ('Zulu',),
#  ('Lithuanian',),
#  ('Luxembourgish',),
#  ('Latvian',),
#  ('Mandarin Chinese',),
#  ('Monegasque',),
#  ('Gagauzi',),
#  ('Malagasy',),
#  ('Dhivehi',),
#  ('Mixtec',),
#  ('Náhuatl',),
#  ('Otomí',),
#  ('Yucatec',),
#  ('Zapotec',),
#  ('Marshallese',),
#  ('Bambara',),
#  ('Senufo and Minianka',),
#  ('Songhai',),
#  ('Tamashek',),
#  ('Maltese',),
#  ('Burmese',),
#  ('Chin',),
#  ('Kachin',),
#  ('Karen',),
#  ('Kayah',),
#  ('Mon',),
#  ('Rakhine',),
#  ('Shan',),
#  ('Bajad',),
#  ('Buryat',),
#  ('Dariganga',),
#  ('Dorbet',),
#  ('Carolinian',),
#  ('Chuabo',),
#  ('Lomwe',),
#  ('Makua',),
#  ('Marendje',),
#  ('Nyanja',),
#  ('Ronga',),
#  ('Sena',),
#  ('Tsonga',),
#  ('Tswa',),
#  ('Hassaniya',),
#  ('Tukulor',),
#  ('Zenaga',),
#  ('Bhojpuri',),
#  ('Chichewa',),
#  ('Ngoni',),
#  ('Yao',),
#  ('Dusun',),
#  ('Iban',),
#  ('Mahoré',),
#  ('Afrikaans',),
#  ('Caprivi',),
#  ('Herero',),
#  ('Kavango',),
#  ('Nama',),
#  ('Ovambo',),
#  ('Malenasian Languages',),
#  ('Polynesian Languages',),
#  ('Hausa',),
#  ('Kanuri',),
#  ('Songhai-zerma',),
#  ('Bura',),
#  ('Edo',),
#  ('Ibibio',),
#  ('Ibo',),
#  ('Ijo',),
#  ('Tiv',),
#  ('Sumo',),
#  ('Niue',),
#  ('Fries',),
#  ('Maithili',),
#  ('Newari',),
#  ('Tamang',),
#  ('Tharu',),
#  ('Nauru',),
#  ('Brahui',),
#  ('Hindko',),
#  ('Saraiki',),
#  ('Sindhi',),
#  ('Cuna',),
#  ('Embera',),
#  ('Guaymí',),
#  ('Pitcairnese',),
#  ('Bicol',),
#  ('Cebuano',),
#  ('Hiligaynon',),
#  ('Ilocano',),
#  ('Maguindanao',),
#  ('Maranao',),
#  ('Pampango',),
#  ('Pangasinan',),
#  ('Pilipino',),
#  ('Waray-waray',),
#  ('Palau',),
#  ('Papuan Languages',),
#  ('Tahitian',),
#  ('Avarian',),
#  ('Bashkir',),
#  ('Chechen',),
#  ('Chuvash',),
#  ('Mari',),
#  ('Mordva',),
#  ('Udmur',),
#  ('Bari',),
#  ('Beja',),
#  ('Chilluk',),
#  ('Dinka',),
#  ('Fur',),
#  ('Lotuko',),
#  ('Nubian Languages',),
#  ('Nuer',),
#  ('Serer',),
#  ('Bullom-sherbro',),
#  ('Kono-vai',),
#  ('Kuranko',),
#  ('Limba',),
#  ('Mende',),
#  ('Temne',),
#  ('Nahua',),
#  ('Sranantonga',),
#  ('Czech and Moravian',),
#  ('Ukrainian and Russian',),
#  ('Swazi',),
#  ('Seselwa',),
#  ('Gorane',),
#  ('Hadjarai',),
#  ('Kanem-bornu',),
#  ('Mayo-kebbi',),
#  ('Ouaddai',),
#  ('Tandjile',),
#  ('Ane',),
#  ('Kabyé',),
#  ('Kotokoli',),
#  ('Moba',),
#  ('Naudemba',),
#  ('Watyi',),
#  ('Kuy',),
#  ('Tokelau',),
#  ('Arabic-French',),
#  ('Arabic-French-English',),
#  ('Ami',),
#  ('Atayal',),
#  ('Min',),
#  ('Paiwan',),
#  ('Chaga and Pare',),
#  ('Gogo',),
#  ('Ha',),
#  ('Haya',),
#  ('Hehet',),
#  ('Luguru',),
#  ('Makonde',),
#  ('Nyakusa',),
#  ('Nyamwesi',),
#  ('Shambala',),
#  ('Acholi',),
#  ('Ganda',),
#  ('Gisu',),
#  ('Kiga',),
#  ('Lango',),
#  ('Lugbara',),
#  ('Nkole',),
#  ('Soga',),
#  ('Teso',),
#  ('Tagalog',),
#  ('Karakalpak',),
#  ('Goajiro',),
#  ('Warrau',),
#  ('Man',),
#  ('Muong',),
#  ('Nung',),
#  ('Tho',),
#  ('Bislama',),
#  ('Futuna',),
#  ('Wallis',),
#  ('Samoan-English',),
#  ('Soqutri',),
#  ('Northsotho',),
#  ('Southsotho',),
#  ('Venda',),
#  ('Xhosa',),
#  ('Bemba',),
#  ('Chewa',),
#  ('Lozi',),
#  ('Nsenga',)]

# %% [markdown]
# ## SELECT DISTINCT
#
# **TASK**: Select all unique `GovernmentForm` mentions in the `Country` table.

# %%
# %%sql
# SELECT DISTINCT GovernmentForm
# FROM Country
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 35 rows affected.
# [('Nonmetropolitan Territory of The Netherlands',),
#  ('Islamic Emirate',),
#  ('Republic',),
#  ('Dependent Territory of the UK',),
#  ('Parliamentary Coprincipality',),
#  ('Emirate Federation',),
#  ('Federal Republic',),
#  ('US Territory',),
#  ('Co-administrated',),
#  ('Nonmetropolitan Territory of France',),
#  ('Constitutional Monarchy',),
#  ('Constitutional Monarchy, Federation',),
#  ('Monarchy (Emirate)',),
#  ('Monarchy (Sultanate)',),
#  ('Monarchy',),
#  ('Dependent Territory of Norway',),
#  ('Territory of Australia',),
#  ('Federation',),
#  ("People'sRepublic",),
#  ('Nonmetropolitan Territory of New Zealand',),
#  ('Socialistic Republic',),
#  ('Occupied by Marocco',),
#  ('Part of Denmark',),
#  ('Overseas Department of France',),
#  ('Special Administrative Region of China',),
#  ('Islamic Republic',),
#  ('Constitutional Monarchy (Emirate)',),
#  ('Socialistic State',),
#  ('Commonwealth of the US',),
#  ('Territorial Collectivity of France',),
#  ('Autonomous Area',),
#  ('Administrated by the UN',),
#  ('Dependent Territory of the US',),
#  ('Independent Church State',),
#  ('Parlementary Monarchy',)]

# %% [markdown]
# ## COUNT
#
# What if you want to count the number of countries in your countries table? The `COUNT` statement lets you do this by returning the **number of rows in one or more columns**.
#
# For example, this counts the number of countries:

# %%
# %%sql
# SELECT COUNT(*)
# FROM Country
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(239,)]

# %% [markdown]
# ## COUNT
#
# As you've seen, `COUNT(*)` tells you how many rows are in a table. However, if you want to count the **number of non-missing values in a particular column**, you can call `COUNT` on just that column.
#
# **TASK**: Check for how many countries the column  `IndepYear` is not missing.

# %%
# %%sql
# SELECT COUNT(IndepYear)
# FROM Country
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(192,)]

# %% [markdown]
# ## COUNT
#
# Let's compare missingness across columns.
#
# **TASK**: Generate counts of `Name` and `LifeExpectancy` in a single SQL statement (Hint: Separate by comma).

# %%
# %%sql
# SELECT COUNT(Name), COUNT(LifeExpectancy)
# FROM Country
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(239, 222)]

# %% [markdown]
# ## COUNT
#
# Now combine with `DISTINCT`.
#
# **Task:** Count how many distinct languages there are.

# %%
# %%sql
# SELECT COUNT(DISTINCT Language)
# FROM CountryLanguage
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(457,)]

# %% [markdown]
# ## Filtering rows
#
# Now, let's learn how to **filter tables for rows satisfying some specified condition**.
#
# The `WHERE` keyword allows to apply filters to both text and numeric values. The basic setup is:
#
#     SELECT column1, column2, ...
#     FROM table_name
#     WHERE condition

# %% [markdown]
# ## WHERE
#
# There are a few different comparison operators you can use with the `WHERE` clause:
#
# | Operator      | Description   |
# | ------------- |:-------------:|
# | =             | Equal         |
# | <>            | Not equal     |
# | >             | Greater than  |
# | <             | Less than     |
# | >=            | Greater than or equal  |
# | <=            | Less than or equal  |
# | BETWEEN       | Between an inclusive range  |
# | LIKE          | Search for a pattern  |
# | IN            | To specify multiple possible values for a column  |

# %% [markdown]
# ## WHERE
#
# The following statement, returns all countries in the region of Antarctica.
#
# ```{sql}
# SELECT Name
# FROM Country
# WHERE Region = 'Antarctica'
# ```

# %% [markdown]
# ## WHERE
#
# **Task:** Show all countries with `LifeExpectancy` larger than 80 years.

# %%
# %%sql
# SELECT Name
# FROM Country
# WHERE LifeExpectancy > 80
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 5 rows affected.
# [('Andorra',), ('Japan',), ('Macao',), ('Singapore',), ('San Marino',)]

# %% [markdown]
# ## WHERE
#
# **Task:** Get the `Name`, `Region`, and `IndepYear` for all countries with independence years before the year 1000.

# %%
# %%sql
# SELECT Name, Region, IndepYear
# FROM Country
# WHERE IndepYear < 1000
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 7 rows affected.
# [('China', 'Eastern Asia', -1523),
#  ('Denmark', 'Nordic Countries', 800),
#  ('Ethiopia', 'Eastern Africa', -1000),
#  ('France', 'Western Europe', 843),
#  ('Japan', 'Eastern Asia', -660),
#  ('San Marino', 'Southern Europe', 885),
#  ('Sweden', 'Nordic Countries', 836)]

# %% [markdown]
# ## WHERE
#
# The `WHERE` clause can also be used to filter text results, such as names or countries.
#
# **Task:** Get the number of countries in South America (hint: `Region`).

# %%
# %%sql
# SELECT COUNT(*)
# FROM Country
# WHERE Region = 'South America'
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(14,)]

# %% [markdown]
# ## WHERE AND
#
# Often, you'll want to **select data based on multiple conditions**. You can build up your `WHERE` queries by combining multiple conditions with the `AND` keyword.

# %%
# %%sql
# SELECT Name, IndepYear, Population
# FROM Country
# WHERE IndepYear < 1500
# AND Population > 10000000
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 7 rows affected.
# [('China', -1523, 1277558000),
#  ('Spain', 1492, 39441700),
#  ('Ethiopia', -1000, 62565000),
#  ('France', 843, 59225700),
#  ('United Kingdom', 1066, 59623400),
#  ('Japan', -660, 126714000),
#  ('Thailand', 1350, 61399000)]

# %% [markdown]
# ## WHERE AND
#
# Note that you **need to specify the column name separately for every `AND` condition**, so the following would be incorrect:

# %% [markdown]
# ```{sql}
# SELECT Name, IndepYear
# FROM Country
# WHERE IndepYear < 1500 AND <1900
# ```

# %% [markdown]
# ## WHERE AND
#
# **Task:** Get the `CountryCode`, `Language`, and the `Percentage` that speak it from the `CountryLanguage` table for all languages that are  official (`IsOfficial`) and less than 3 percent of the population speak it (`Percentage`).</span>

# %%
# %%sql
# SELECT CountryCode, Language, Percentage
# FROM CountryLanguage
# WHERE IsOfficial = TRUE
# AND Percentage < 3
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 48 rows affected.
# [('AIA', 'English', 0.0),
#  ('ANT', 'Dutch', 0.0),
#  ('ATG', 'English', 0.0),
#  ('BDI', 'French', 0.0),
#  ('BEL', 'German', 1.0),
#  ('BRB', 'English', 0.0),
#  ('CCK', 'English', 0.0),
#  ('CHE', 'Romansh', 0.6),
#  ('COK', 'Maori', 0.0),
#  ('CPV', 'Portuguese', 0.0),
#  ('CXR', 'English', 0.0),
#  ('CYM', 'English', 0.0),
#  ('FLK', 'English', 0.0),
#  ('FRO', 'Danish', 0.0),
#  ('GLP', 'French', 0.0),
#  ('HKG', 'English', 2.2),
#  ('HTI', 'French', 0.0),
#  ('IRL', 'Irish', 1.6),
#  ('KNA', 'English', 0.0),
#  ('LSO', 'English', 0.0),
#  ('LUX', 'German', 2.3),
#  ('MAC', 'Portuguese', 2.3),
#  ('MDG', 'French', 0.0),
#  ('MHL', 'English', 0.0),
#  ('MLT', 'English', 2.1),
#  ('MSR', 'English', 0.0),
#  ('MTQ', 'French', 0.0),
#  ('NFK', 'English', 0.0),
#  ('NIU', 'English', 0.0),
#  ('PER', 'Aimará', 2.3),
#  ('ROM', 'Romani', 0.7),
#  ('RWA', 'French', 0.0),
#  ('SHN', 'English', 0.0),
#  ('SJM', 'Norwegian', 0.0),
#  ('SOM', 'Arabic', 0.0),
#  ('SPM', 'French', 0.0),
#  ('SYC', 'French', 1.3),
#  ('TCA', 'English', 0.0),
#  ('TKL', 'English', 0.0),
#  ('TMP', 'Portuguese', 0.0),
#  ('TON', 'English', 0.0),
#  ('TUV', 'English', 0.0),
#  ('UMI', 'English', 0.0),
#  ('VAT', 'Italian', 0.0),
#  ('VCT', 'English', 0.0),
#  ('VGB', 'English', 0.0),
#  ('WSM', 'English', 0.6),
#  ('ZWE', 'English', 2.2)]

# %% [markdown]
# ## WHERE AND OR
#
# What if you want to select rows based on multiple conditions where **some but not all of the conditions need to be met**? For this, SQL has the `OR` operator.

# %% [markdown]
# **Task:** Select `Name`, `SurfaceArea` and `Population` for all countries with population larger than 300 million `OR` surface area larger than 5 million square km.</span>

# %% [markdown]
# ## WHERE AND OR

# %%
# %%sql
# SELECT Name, SurfaceArea, Population
# FROM Country
# WHERE SurfaceArea > 5000000
# OR Population > 300000000
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 8 rows affected.
# [('Antarctica', 13120000.0, 0),
#  ('Australia', 7741220.0, 18886000),
#  ('Brazil', 8547403.0, 170115000),
#  ('Canada', 9970610.0, 31147000),
#  ('China', 9572900.0, 1277558000),
#  ('India', 3287263.0, 1013662000),
#  ('Russian Federation', 17075400.0, 146934000),
#  ('United States', 9363520.0, 278357000)]

# %% [markdown]
# ## WHERE AND OR
#
# When combining AND and OR, we need to place the individual clauses in parentheses, like so:

# %%
# %%sql
# SELECT Name, SurfaceArea, Population
# FROM Country
# WHERE (SurfaceArea <    1000 AND Population > 1000000)
# OR    (SurfaceArea > 1000000 AND Population < 1000000)
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 3 rows affected.
# [('Antarctica', 13120000.0, 0),
#  ('Greenland', 2166090.0, 56000),
#  ('Singapore', 618.0, 3567000)]

# %% [markdown]
# ## WHERE AND OR
#
# **Task:** Select `CountryCode`, `Language`, and `Percentage` for all English entries where the language is either (a) not official (`IsOfficial`) and spoken by the majority, or (b) official and spoken by less than 1 percent but more than 0 percent.

# %%
# %%sql
# SELECT CountryCode, Language, Percentage
# FROM CountryLanguage
# WHERE Language = 'English'
# AND (IsOfficial = 'F' AND Percentage > 50)
# OR  (IsOfficial = 'T' AND Percentage < 1 AND Percentage > 0)
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 4 rows affected.
# [('CHE', 'Romansh', 0.6),
#  ('ROM', 'Romani', 0.7),
#  ('TTO', 'English', 93.5),
#  ('WSM', 'English', 0.6)]

# %% [markdown]
# ## BETWEEN
#
# Checking for ranges, as we just did, is fairly common.
#
# The `BETWEEN` operator selects values within a given range.
#
# The `BETWEEN` operator is inclusive: begin and end values are included.

# %% [markdown]
# ```
# SELECT column_name(s)
# FROM table_name
# WHERE column_name BETWEEN value1 AND value2;
# ```

# %% [markdown]
# ## BETWEEN
#
# **Task:** List city `Name`s and `Population` of cities whose population is between 8 and 10 million.

# %%
# %%sql
# SELECT Name, Population
# FROM   City
# WHERE  Population BETWEEN 8000000 AND 10000000
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 7 rows affected.
# [('Jakarta', 9604900.0),
#  ('Shanghai', 9696300.0),
#  ('Seoul', 9981619.0),
#  ('Karachi', 9269265.0),
#  ('Istanbul', 8787958.0),
#  ('Moscow', 8389200.0),
#  ('New York', 8008278.0)]

# %% [markdown]
# ## WHERE IN
#
# The `WHERE` operator works great but gets unwieldy if we have lots of conditions.
#
# The `IN` operator works a lot like the `%in%` operator in dplyr. The `IN` operator allows you to specify multiple values in a `WHERE` clause, making it easier and quicker to specify multiple `OR` conditions!

# %%
# %%sql
# SELECT COUNT(*)
# FROM  Country
# WHERE Region IN ('Eastern Asia', 'Eastern Africa',
#                  'Southern and Central Asia')
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(42,)]

# %% [markdown]
# ## WHERE IN
#
# **Task**: Count the number of countries (hint: `CountryCode`) in the `CountryLanguage` table in which one of the official languages is either English, French, or Spanish.

# %%
# %%sql
# SELECT COUNT(DISTINCT CountryCode)
# FROM   CountryLanguage
# WHERE  Language IN ('English', 'French', 'Spanish') AND IsOfficial = TRUE
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(79,)]

# %% [markdown]
# ## LIKE and NOT LIKE
#
# Thus far, we have only used exact matches to filter text data.
#
# The `LIKE` operator can be used if we want **to search for a pattern** using the `WHERE` clause rather than a specific text string.
#
# SQL has two **wildcards as a placeholders** for some other values that can be used with `LIKE`. A wildcard character is used to substitute any other character(s) in a string.
#
# There are two wildcards used in conjunction with the LIKE operator:
#
# - **`%`** - The percent sign represents **zero, one, or multiple characters**.
#
# - **`_`** - The underscore represents a **single character**.

# %% [markdown]
# ## LIKE and NOT LIKE
#
# The wildcards can also be used in combinations! Here are some examples showing different LIKE operators with `%` and `_` wildcards:
#
# | LIKE Operator      | Description   |
# | ------------- |:-------------:|
# | WHERE CustomerName LIKE 'a%'	| Finds any values that starts with "a" |
# | WHERE CustomerName LIKE '%a'	| 	Finds any values that ends with "a" |
# | WHERE CustomerName LIKE '%or%'	| 	Finds any values that have "or" in any position |
# | WHERE CustomerName LIKE '_r%'	| 	Finds any values that have "r" in the second position |
# | WHERE CustomerName LIKE 'a_%_%'	| 	Finds any values that starts with "a" and are at least 3 characters in length |
# | WHERE ContactName LIKE 'a%o'	| 	Finds any values that starts with "a" and ends with "o" |

# %% [markdown]
# ## LIKE and NOT LIKE
#
# For example: Select the names of all countries that start with `Q`.

# %%
# %%sql
# SELECT Name
# FROM   Country
# WHERE  Name LIKE 'Q%'
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [('Qatar',)]

# %% [markdown]
# ## WHERE IN
#
# **Task:** Show all city `Name`s in the `City` table that have an "x" as their second letter.

# %%
# %%sql
# SELECT Name
# FROM   City
# WHERE  Name LIKE '_x%'
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 3 rows affected.
# [('Oxford',), ('Exeter',), ('Oxnard',)]

# %% [markdown]
# ## Aggregate functions
#
# SQL allows you to perform some simple calculations on the data in a database using **aggregate functions**. Here are some of the most common:
#
# | Aggregate Operator  | Description   |
# | ------------- |:-------------:|
# | MIN	 | returns the smallest value in a given column  |
# | MAX	 | returns the largest value in a given column  |
# | SUM	 | returns the sum of the numeric values in a given column |
# | AVG	 | returns the average value of a given column |
# | MEDIAN | returns the average value of a given column |
# | ROUND	 | returns a number rounded to a certain number of decimal places |
#
# The syntax for the these aggregate functions is:
#
# ```{sql}
# aggregate_function (DISTINCT | ALL expression)
# ```

# %% [markdown]
# ## Aggregate functions
#
# **Example:** What is the average `Percentage` of the population an unofficial language is spoken by?

# %%
# %%sql
# SELECT AVG(Percentage)
# FROM   CountryLanguage
# WHERE IsOfficial = 'F'
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(10.40858,)]

# %% [markdown]
# ## Aggregate functions
#
# **Task:** Find the smallest, largest and average `LifeExpectancy` on the `Continent` of Africa (using the `Country` table)?</span>

# %%
# %%sql
# SELECT MIN(LifeExpectancy), AVG(LifeExpectancy), MAX(LifeExpectancy)
# FROM   Country
# WHERE  Continent = 'Africa'
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(37.2, 52.57193, 76.8)]

# %% [markdown]
# ## Greatest n by group
#
# Hmmh, that's nice. But often what we really want is **the entry for which a condition is true**.
#
# For one group that is easy.

# %%
# %%sql
# SELECT LifeExpectancy, Name
# FROM  Country
# WHERE Continent = 'Africa'
# ORDER  BY LifeExpectancy DESC
# LIMIT 1
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# [(76.8, 'Saint Helena')]

# %% [markdown]
# For multiple groups, this is such a common question (with so many possible answers), that stackoverflow has created a special tag for the [greatest-n-per-group](https://stackoverflow.com/questions/tagged/greatest-n-per-group) questions.

# %% [markdown]
# ## Greatest n by group
#
# To get the highest life expectancy by continent is a bit more complicated (and differs by SQL dialect). Lot's of possible ways to do this.

# %%
# %%sql
# SELECT a.Continent, a.Name, a.LifeExpectancy
# FROM Country AS a
# WHERE (SELECT COUNT(*)
#        FROM Country AS b
#        WHERE b.Continent = a.Continent
#          AND b.LifeExpectancy >= a.LifeExpectancy) <= 1
#   AND a.LifeExpectancy is not NULL
# ORDER BY a.Continent ASC, a.LifeExpectancy DESC
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 6 rows affected.
# [('Asia', 'Macao', 81.6),
#  ('Europe', 'Andorra', 83.5),
#  ('North America', 'Canada', 79.4),
#  ('Africa', 'Saint Helena', 76.8),
#  ('Oceania', 'Australia', 79.8),
#  ('South America', 'French Guiana', 76.1)]

# %% [markdown]
# ## ORDER BY
#
# You noticed that we used the command `ORDER BY` to obtain a sorted column.
#
# The `ORDER BY` keyword is used to sort the result-set in ascending or descending order. Ascending order is the default. To sort the records in descending order, use the `DESC` keyword.

# %% [markdown]
# ```{sql}
# -- ORDER BY Syntax
# SELECT column1, column2, ...
# FROM table_name
# ORDER BY column1, column2, ... ASC|DESC;
# ```

# %% [markdown]
# ## ORDER BY
#
# **Task:** Find the `Name`s of the 5 largest cities (and their `Population`s) in the dataset.

# %%
# %%sql
# SELECT Name, Population
# FROM   City
# ORDER  BY Population DESC
# LIMIT 5
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 5 rows affected.
# [('Mumbai (Bombay)', 10500000.0),
#  ('Seoul', 9981619.0),
#  ('Shanghai', 9696300.0),
#  ('Jakarta', 9604900.0),
#  ('Karachi', 9269265.0)]

# %% [markdown]
# ## GROUP BY
#
# Just as in `pandas`, SQL allows you to obtain results aggregated by subgroups.
#
# ```
# -- GROUP BY Syntax
# SELECT column_name(s)
# FROM table_name
# WHERE condition
# GROUP BY column_name(s)
# ORDER BY column_name(s);
# ```

# %% [markdown]
# ## GROUP BY
#
# **Task:** Count how many countries are on each `Continent`.

# %%
# %%sql
# SELECT Continent, COUNT(*)
# FROM   Country
# GROUP BY Continent
# ORDER BY COUNT(*) DESC
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 7 rows affected.
# [('Africa', 58),
#  ('Asia', 51),
#  ('Europe', 46),
#  ('North America', 37),
#  ('Oceania', 28),
#  ('South America', 14),
#  ('Antarctica', 5)]

# %% [markdown]
# ## Aliasing with AS
#
# The result is pretty good with a small wrinkle. The column name of the number of countries is `COUNT(*)`.
#
# In general, the column name of the result is just the name of the function you used.
#
# SQL allows us to use **aliases** to give a table, or a column in a table, a temporary name. Aliases are often used to make column names more readable and only exists for the duration of the query.
#
# ```{sql, eval=FALSE}
# -- Alias Column Syntax
# SELECT column_name AS alias_name
# FROM table_name;
# -- Alias Table Syntax
# SELECT column_name(s)
# FROM table_name AS alias_name;
# ```

# %% [markdown]
# ## Aliasing with AS
#
# **Task:** Rename the column name of the count "Number of Countries".

# %%
# %%sql
# SELECT Continent, COUNT(*)
# FROM   Country
# GROUP BY Continent
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 7 rows affected.
# [('Asia', 51),
#  ('Europe', 46),
#  ('North America', 37),
#  ('Africa', 58),
#  ('Oceania', 28),
#  ('Antarctica', 5),
#  ('South America', 14)]

# %% [markdown]
# ## Aliasing with AS

# %%
# %%sql
# SELECT Continent, COUNT(*) AS "Number of Countries"
# FROM   Country
# GROUP BY Continent
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 7 rows affected.
# [('Asia', 51),
#  ('Europe', 46),
#  ('North America', 37),
#  ('Africa', 58),
#  ('Oceania', 28),
#  ('Antarctica', 5),
#  ('South America', 14)]

# %% [markdown]
# ## Combining commands
#
# Let's combine a few commands: AVG, WHERE IN, GROUP BY
#
# **Task** Calculate the average `Percentage` of the population a `Language` is spoken by for each of the following languages: English, Spanish, German, Portuguese.

# %% [markdown]
# ## Combining commands

# %%
# %%sql
# SELECT Language, AVG(Percentage) AS 'Avg Percentage'
# FROM   CountryLanguage
# WHERE Language IN ('English', 'Spanish', 'German', 'Portuguese')
# GROUP BY Language
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 4 rows affected.
# [('English', 18.775),
#  ('German', 18.47895),
#  ('Portuguese', 19.66667),
#  ('Spanish', 66.05)]

# %% [markdown]
# ## Combining commands
#
# **Task:** Now alter the previous command to separate by whether a language `IsOfficial` or not.
#
#     SELECT AVG(Percentage), Language
#     FROM   CountryLanguage
#     WHERE Language IN ('English', 'Spanish', 'German', 'Portuguese')
#     GROUP BY Language

# %% [markdown]
# ## Combining commands

# %%
# %%sql
# SELECT AVG(Percentage), Language, IsOfficial
# FROM   CountryLanguage
# WHERE Language IN ('English', 'Spanish', 'German', 'Portuguese')
# GROUP BY Language, IsOfficial
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 8 rows affected.
# [(21.72045, 'English', 'T'),
#  (10.675, 'English', 'F'),
#  (56.53333, 'German', 'T'),
#  (0.91538, 'German', 'F'),
#  (34.48333, 'Portuguese', 'T'),
#  (4.85, 'Portuguese', 'F'),
#  (87.165, 'Spanish', 'T'),
#  (13.2625, 'Spanish', 'F')]

# %% [markdown]
# ## Welcome to the nerd (SQL) club
#
# ![](images/sql_funny.png)

# %% [markdown]
# ## Saving output from SQL
#
# You can **save the output from a SQL back to Python** in several ways. Let's start with `ipython-sql`. A single number can be returned directly:

# %%
obs_num = %sql SELECT COUNT(DISTINCT Language) FROM CountryLanguage
print(obs_num)
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 1 rows affected.
# +--------------------------+
# | COUNT(DISTINCT Language) |
# +--------------------------+
# |           457            |
# +--------------------------+

# %% [markdown]
# To actually get the value, we can use:

# %%
obs_num[0][0]
# Out:
# 457

# %% [markdown]
# ## From SQL to Pandas

# %%
result = %sql SELECT * FROM CountryLanguage WHERE IsOfficial = True
df = result.DataFrame()
df.head()
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 238 rows affected.
#   CountryCode   Language IsOfficial  Percentage
# 0         ABW      Dutch          T         5.3
# 1         AFG       Dari          T        32.1
# 2         AFG     Pashto          T        52.4
# 3         AIA    English          T         0.0
# 4         ALB  Albaniana          T        97.9

# %% [markdown]
# ## From SQL to Pandas

# %%
import pandas as pd
pd.read_sql('SELECT * FROM CountryLanguage WHERE IsOfficial = True', engine)
# Out:
#     CountryCode   Language IsOfficial  Percentage
# 0           ABW      Dutch          T         5.3
# 1           AFG       Dari          T        32.1
# 2           AFG     Pashto          T        52.4
# 3           AIA    English          T         0.0
# 4           ALB  Albaniana          T        97.9
# ..          ...        ...        ...         ...
# 233         ZAF  Afrikaans          T        14.3
# 234         ZAF    English          T         8.5
# 235         ZAF      Xhosa          T        17.7
# 236         ZAF       Zulu          T        22.7
# 237         ZWE    English          T         2.2
#
# [238 rows x 4 columns]

# %% [markdown]
# ## Other Commands
#
# **What we covered:**
#
# `SELECT, SELECT DISTINCT, IN, BETWEEN, WHERE, AND, OR, NOT, ORDER BY, MIN, MAX, COUNT, AVG, SUM, LIKE, %, _, AS`
#
# **Next steps to explore:**
#
# `HAVING, SELECT TOP, NULL, EXISTS, ANY, ALL`

# %% [markdown]
# # Joins
#
# ![](images/join_intro_pic.png)

# %% [markdown]
# ##
#
# ![](images/joke_join.png)

# %% [markdown]
# ## Combining Information across DB Tables
#
# - unlike in your usual (single) dataframe in `pandas`,  in a relational database relevant **information** for a question may be **spread across several tables**
# - to present information from several tables in the DB, we need to **join these tables**

# %% [markdown]
# ## Example: Percentage of Population
#
# What is the percentage of the population of a country that lives in its capital city?
#
# ![](images/world_database.png)

# %% [markdown]
# ## Types of Joins
#
# ![](images/sql_joins.png)

# %% [markdown]
# ## General Syntax
#
# ```{sql}
# SELECT column-names
#   FROM table-name1 INNER JOIN table-name2
#     ON column-name1 = column-name2
#  WHERE condition
# ```
#
# Note: The `INNER` keyword is optional: it is the default as well as the most commmonly used `JOIN` operation.

# %% [markdown]
# ## Example: Joining `City` and `Country`

# %%
# %%sql
# SELECT City.Name, Country.Name
# FROM City
# JOIN Country
# ON City.CountryCode = Country.Code
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 3427 rows affected.
# [('Kabul', 'Afghanistan'),
#  ('Qandahar', 'Afghanistan'),
#  ('Herat', 'Afghanistan'),
#  ('Mazar-e-Sharif', 'Afghanistan'),
#  ('Amsterdam', 'Netherlands'),
#  ('Rotterdam', 'Netherlands'),
#  ('Haag', 'Netherlands'),
#  ('Utrecht', 'Netherlands'),
#  ('Eindhoven', 'Netherlands'),
#  ('Tilburg', 'Netherlands'),
#  ('Groningen', 'Netherlands'),
#  ('Breda', 'Netherlands'),
#  ('Apeldoorn', 'Netherlands'),
#  ('Nijmegen', 'Netherlands'),
#  ('Enschede', 'Netherlands'),
#  ('Haarlem', 'Netherlands'),
#  ('Almere', 'Netherlands'),
#  ('Arnhem', 'Netherlands'),
#  ('Zaanstad', 'Netherlands'),
#  ('Amersfoort', 'Netherlands'),
#  ('Maastricht', 'Netherlands'),
#  ('Dordrecht', 'Netherlands'),
#  ('Leiden', 'Netherlands'),
#  ('Haarlemmermeer', 'Netherlands'),
#  ('Zoetermeer', 'Netherlands'),
#  ('Emmen', 'Netherlands'),
#  ('Zwolle', 'Netherlands'),
#  ('Ede', 'Netherlands'),
#  ('Delft', 'Netherlands'),
#  ('Heerlen', 'Netherlands'),
#  ('Alkmaar', 'Netherlands'),
#  ('Tirana', 'Albania'),
#  ('Alger', 'Algeria'),
#  ('Oran', 'Algeria'),
#  ('Constantine', 'Algeria'),
#  ('Annaba', 'Algeria'),
#  ('Batna', 'Algeria'),
#  ('Skikda', 'Algeria'),
#  ('Biskra', 'Algeria'),
#  ('Blida (el-Boulaida)', 'Algeria'),
#  ('Mostaganem', 'Algeria'),
#  ('Tlemcen (Tilimsen)', 'Algeria'),
#  ('Tiaret', 'Algeria'),
#  ('Ech-Chleff (el-Asnam)', 'Algeria'),
#  ('Tafuna', 'American Samoa'),
#  ('Fagatogo', 'American Samoa'),
#  ('Andorra la Vella', 'Andorra'),
#  ('Luanda', 'Angola'),
#  ('Huambo', 'Angola'),
#  ('Lobito', 'Angola'),
#  ('Benguela', 'Angola'),
#  ('Namibe', 'Angola'),
#  ('Dubai', 'United Arab Emirates'),
#  ('Abu Dhabi', 'United Arab Emirates'),
#  ('Sharja', 'United Arab Emirates'),
#  ('al-Ayn', 'United Arab Emirates'),
#  ('Ajman', 'United Arab Emirates'),
#  ('Buenos Aires', 'Argentina'),
#  ('La Matanza', 'Argentina'),
#  ('Lomas de Zamora', 'Argentina'),
#  ('Quilmes', 'Argentina'),
#  ('Almirante Brown', 'Argentina'),
#  ('La Plata', 'Argentina'),
#  ('Mar del Plata', 'Argentina'),
#  ('Merlo', 'Argentina'),
#  ('Salta', 'Argentina'),
#  ('Moreno', 'Argentina'),
#  ('Avellaneda', 'Argentina'),
#  ('Tres de Febrero', 'Argentina'),
#  ('Florencio Varela', 'Argentina'),
#  ('San Isidro', 'Argentina'),
#  ('Tigre', 'Argentina'),
#  ('Malvinas Argentinas', 'Argentina'),
#  ('Berazategui', 'Argentina'),
#  ('Corrientes', 'Argentina'),
#  ('San Miguel', 'Argentina'),
#  ('Resistencia', 'Argentina'),
#  ('Godoy Cruz', 'Argentina'),
#  ('Posadas', 'Argentina'),
#  ('Santiago del Estero', 'Argentina'),
#  ('San Salvador de Jujuy', 'Argentina'),
#  ('Hurlingham', 'Argentina'),
#  ('San Fernando', 'Argentina'),
#  ('Formosa', 'Argentina'),
#  ('Las Heras', 'Argentina'),
#  ('La Rioja', 'Argentina'),
#  ('San Fernando del Valle de Cata', 'Argentina'),
#  ('Comodoro Rivadavia', 'Argentina'),
#  ('Mendoza', 'Argentina'),
#  ('San Juan', 'Argentina'),
#  ('Escobar', 'Argentina'),
#  ('Concordia', 'Argentina'),
#  ('Pilar', 'Argentina'),
#  ('San Luis', 'Argentina'),
#  ('Ezeiza', 'Argentina'),
#  ('San Rafael', 'Argentina'),
#  ('Tandil', 'Argentina'),
#  ('Yerevan', 'Armenia'),
#  ('Vanadzor', 'Armenia'),
#  ('Sydney', 'Australia'),
#  ('Melbourne', 'Australia'),
#  ('Brisbane', 'Australia'),
#  ('Perth', 'Australia'),
#  ('Adelaide', 'Australia'),
#  ('Canberra', 'Australia'),
#  ('Gold Coast', 'Australia'),
#  ('Newcastle', 'Australia'),
#  ('Central Coast', 'Australia'),
#  ('Wollongong', 'Australia'),
#  ('Hobart', 'Australia'),
#  ('Geelong', 'Australia'),
#  ('Townsville', 'Australia'),
#  ('Cairns', 'Australia'),
#  ('Baku', 'Azerbaijan'),
#  ('Sumqayit', 'Azerbaijan'),
#  ('Nassau', 'Bahamas'),
#  ('al-Manama', 'Bahrain'),
#  ('Dhaka', 'Bangladesh'),
#  ('Chittagong', 'Bangladesh'),
#  ('Khulna', 'Bangladesh'),
#  ('Rajshahi', 'Bangladesh'),
#  ('Narayanganj', 'Bangladesh'),
#  ('Rangpur', 'Bangladesh'),
#  ('Mymensingh', 'Bangladesh'),
#  ('Barisal', 'Bangladesh'),
#  ('Tungi', 'Bangladesh'),
#  ('Jessore', 'Bangladesh'),
#  ('Comilla', 'Bangladesh'),
#  ('Nawabganj', 'Bangladesh'),
#  ('Dinajpur', 'Bangladesh'),
#  ('Bogra', 'Bangladesh'),
#  ('Sylhet', 'Bangladesh'),
#  ('Brahmanbaria', 'Bangladesh'),
#  ('Tangail', 'Bangladesh'),
#  ('Jamalpur', 'Bangladesh'),
#  ('Pabna', 'Bangladesh'),
#  ('Naogaon', 'Bangladesh'),
#  ('Sirajganj', 'Bangladesh'),
#  ('Narsinghdi', 'Bangladesh'),
#  ('Saidpur', 'Bangladesh'),
#  ('Gazipur', 'Bangladesh'),
#  ('Bridgetown', 'Barbados'),
#  ('Antwerpen', 'Belgium'),
#  ('Gent', 'Belgium'),
#  ('Charleroi', 'Belgium'),
#  ('Bruxelles [Brussel]', 'Belgium'),
#  ('Brugge', 'Belgium'),
#  ('Schaerbeek', 'Belgium'),
#  ('Namur', 'Belgium'),
#  ('Mons', 'Belgium'),
#  ('Belize City', 'Belize'),
#  ('Belmopan', 'Belize'),
#  ('Cotonou', 'Benin'),
#  ('Djougou', 'Benin'),
#  ('Parakou', 'Benin'),
#  ('Hamilton', 'Bermuda'),
#  ('Thimphu', 'Bhutan'),
#  ('Santa Cruz de la Sierra', 'Bolivia'),
#  ('La Paz', 'Bolivia'),
#  ('El Alto', 'Bolivia'),
#  ('Cochabamba', 'Bolivia'),
#  ('Oruro', 'Bolivia'),
#  ('Sucre', 'Bolivia'),
#  ('Tarija', 'Bolivia'),
#  ('Sarajevo', 'Bosnia and Herzegovina'),
#  ('Banja Luka', 'Bosnia and Herzegovina'),
#  ('Zenica', 'Bosnia and Herzegovina'),
#  ('Gaborone', 'Botswana'),
#  ('Francistown', 'Botswana'),
#  ('Rio de Janeiro', 'Brazil'),
#  ('Salvador', 'Brazil'),
#  ('Belo Horizonte', 'Brazil'),
#  ('Recife', 'Brazil'),
#  ('Porto Alegre', 'Brazil'),
#  ('Manaus', 'Brazil'),
#  ('Duque de Caxias', 'Brazil'),
#  ('Natal', 'Brazil'),
#  ('Campo Grande', 'Brazil'),
#  ('Contagem', 'Brazil'),
#  ('Feira de Santana', 'Brazil'),
#  ('Juiz de Fora', 'Brazil'),
#  ('Aracaju', 'Brazil'),
#  ('Joinville', 'Brazil'),
#  ('Belford Roxo', 'Brazil'),
#  ('Campos dos Goytacazes', 'Brazil'),
#  ('Olinda', 'Brazil'),
#  ('Caxias do Sul', 'Brazil'),
#  ('Pelotas', 'Brazil'),
#  ('Betim', 'Brazil'),
#  ('Canoas', 'Brazil'),
#  ('Montes Claros', 'Brazil'),
#  ('Rio Branco', 'Brazil'),
#  ('Uberaba', 'Brazil'),
#  ('Paulista', 'Brazil'),
#  ('Blumenau', 'Brazil'),
#  ('Caruaru', 'Brazil'),
#  ('Volta Redonda', 'Brazil'),
#  ('Novo Hamburgo', 'Brazil'),
#  ('Santa Maria', 'Brazil'),
#  ('Governador Valadares', 'Brazil'),
#  ('Petrolina', 'Brazil'),
#  ('Ipatinga', 'Brazil'),
#  ('Juazeiro', 'Brazil'),
#  ('Sete Lagoas', 'Brazil'),
#  ('Rio Grande', 'Brazil'),
#  ('Itabuna', 'Brazil'),
#  ('Arapiraca', 'Brazil'),
#  ('Alvorada', 'Brazil'),
#  ('Nova Friburgo', 'Brazil'),
#  ('Barra Mansa', 'Brazil'),
#  ('Boa Vista', 'Brazil'),
#  ('Passo Fundo', 'Brazil'),
#  ('Dourados', 'Brazil'),
#  ('Santa Luzia', 'Brazil'),
#  ('Cabo de Santo Agostinho', 'Brazil'),
#  ('Lages', 'Brazil'),
#  ('Nossa Senhora do Socorro', 'Brazil'),
#  ('Barreiras', 'Brazil'),
#  ('Alagoinhas', 'Brazil'),
#  ('Uruguaiana', 'Brazil'),
#  ('Palmas', 'Brazil'),
#  ('Sapucaia do Sul', 'Brazil'),
#  ('Cabo Frio', 'Brazil'),
#  ('Patos de Minas', 'Brazil'),
#  ('Camaragibe', 'Brazil'),
#  ('Queimados', 'Brazil'),
#  ('Garanhuns', 'Brazil'),
#  ('Barbacena', 'Brazil'),
#  ('Lauro de Freitas', 'Brazil'),
#  ('Teixeira de Freitas', 'Brazil'),
#  ('Varginha', 'Brazil'),
#  ('Santa Cruz do Sul', 'Brazil'),
#  ('Cachoeirinha', 'Brazil'),
#  ('Itabira', 'Brazil'),
#  ('Resende', 'Brazil'),
#  ('Pouso Alegre', 'Brazil'),
#  ('Passos', 'Brazil'),
#  ('Araguari', 'Brazil'),
#  ('Conselheiro Lafaiete', 'Brazil'),
#  ('Paulo Afonso', 'Brazil'),
#  ('Angra dos Reis', 'Brazil'),
#  ('Parnamirim', 'Brazil'),
#  ('Jacobina', 'Brazil'),
#  ('Coronel Fabriciano', 'Brazil'),
#  ('Santana do Livramento', 'Brazil'),
#  ('Ituiutaba', 'Brazil'),
#  ('London', 'United Kingdom'),
#  ('Birmingham', 'United Kingdom'),
#  ('Glasgow', 'United Kingdom'),
#  ('Liverpool', 'United Kingdom'),
#  ('Edinburgh', 'United Kingdom'),
#  ('Sheffield', 'United Kingdom'),
#  ('Manchester', 'United Kingdom'),
#  ('Leeds', 'United Kingdom'),
#  ('Bristol', 'United Kingdom'),
#  ('Cardiff', 'United Kingdom'),
#  ('Coventry', 'United Kingdom'),
#  ('Leicester', 'United Kingdom'),
#  ('Bradford', 'United Kingdom'),
#  ('Belfast', 'United Kingdom'),
#  ('Nottingham', 'United Kingdom'),
#  ('Kingston upon Hull', 'United Kingdom'),
#  ('Plymouth', 'United Kingdom'),
#  ('Stoke-on-Trent', 'United Kingdom'),
#  ('Wolverhampton', 'United Kingdom'),
#  ('Derby', 'United Kingdom'),
#  ('Swansea', 'United Kingdom'),
#  ('Southampton', 'United Kingdom'),
#  ('Aberdeen', 'United Kingdom'),
#  ('Northampton', 'United Kingdom'),
#  ('Dudley', 'United Kingdom'),
#  ('Portsmouth', 'United Kingdom'),
#  ('Newcastle upon Tyne', 'United Kingdom'),
#  ('Sunderland', 'United Kingdom'),
#  ('Luton', 'United Kingdom'),
#  ('Swindon', 'United Kingdom'),
#  ('Southend-on-Sea', 'United Kingdom'),
#  ('Walsall', 'United Kingdom'),
#  ('Bournemouth', 'United Kingdom'),
#  ('Peterborough', 'United Kingdom'),
#  ('Brighton', 'United Kingdom'),
#  ('Blackpool', 'United Kingdom'),
#  ('Dundee', 'United Kingdom'),
#  ('West Bromwich', 'United Kingdom'),
#  ('Reading', 'United Kingdom'),
#  ('Oldbury/Smethwick (Warley)', 'United Kingdom'),
#  ('Middlesbrough', 'United Kingdom'),
#  ('Huddersfield', 'United Kingdom'),
#  ('Oxford', 'United Kingdom'),
#  ('Poole', 'United Kingdom'),
#  ('Bolton', 'United Kingdom'),
#  ('Blackburn', 'United Kingdom'),
#  ('Newport', 'United Kingdom'),
#  ('Preston', 'United Kingdom'),
#  ('Stockport', 'United Kingdom'),
#  ('Norwich', 'United Kingdom'),
#  ('Rotherham', 'United Kingdom'),
#  ('Cambridge', 'United Kingdom'),
#  ('Watford', 'United Kingdom'),
#  ('Ipswich', 'United Kingdom'),
#  ('Slough', 'United Kingdom'),
#  ('Exeter', 'United Kingdom'),
#  ('Cheltenham', 'United Kingdom'),
#  ('Gloucester', 'United Kingdom'),
#  ('Saint Helens', 'United Kingdom'),
#  ('Sutton Coldfield', 'United Kingdom'),
#  ('York', 'United Kingdom'),
#  ('Oldham', 'United Kingdom'),
#  ('Basildon', 'United Kingdom'),
#  ('Worthing', 'United Kingdom'),
#  ('Chelmsford', 'United Kingdom'),
#  ('Colchester', 'United Kingdom'),
#  ('Crawley', 'United Kingdom'),
#  ('Gillingham', 'United Kingdom'),
#  ('Solihull', 'United Kingdom'),
#  ('Rochdale', 'United Kingdom'),
#  ('Birkenhead', 'United Kingdom'),
#  ('Worcester', 'United Kingdom'),
#  ('Hartlepool', 'United Kingdom'),
#  ('Halifax', 'United Kingdom'),
#  ('Woking/Byfleet', 'United Kingdom'),
#  ('Southport', 'United Kingdom'),
#  ('Maidstone', 'United Kingdom'),
#  ('Eastbourne', 'United Kingdom'),
#  ('Grimsby', 'United Kingdom'),
#  ('Saint Helier', 'United Kingdom'),
#  ('Road Town', 'Virgin Islands, British'),
#  ('Bandar Seri Begawan', 'Brunei'),
#  ('Sofija', 'Bulgaria'),
#  ('Plovdiv', 'Bulgaria'),
#  ('Varna', 'Bulgaria'),
#  ('Burgas', 'Bulgaria'),
#  ('Ruse', 'Bulgaria'),
#  ('Stara Zagora', 'Bulgaria'),
#  ('Pleven', 'Bulgaria'),
#  ('Sliven', 'Bulgaria'),
#  ('Dobric', 'Bulgaria'),
#  ('Ouagadougou', 'Burkina Faso'),
#  ('Bobo-Dioulasso', 'Burkina Faso'),
#  ('Bujumbura', 'Burundi'),
#  ('George Town', 'Cayman Islands'),
#  ('Santiago de Chile', 'Chile'),
#  ('Puente Alto', 'Chile'),
#  ('Antofagasta', 'Chile'),
#  ('San Bernardo', 'Chile'),
#  ('Talca', 'Chile'),
#  ('Puerto Montt', 'Chile'),
#  ('Coquimbo', 'Chile'),
#  ('Osorno', 'Chile'),
#  ('La Serena', 'Chile'),
#  ('Calama', 'Chile'),
#  ('Valdivia', 'Chile'),
#  ('Punta Arenas', 'Chile'),
#  ('Ovalle', 'Chile'),
#  ('Melipilla', 'Chile'),
#  ('Avarua', 'Cook Islands'),
#  ('Djibouti', 'Djibouti'),
#  ('Roseau', 'Dominica'),
#  ('Santiago de los Caballeros', 'Dominican Republic'),
#  ('La Romana', 'Dominican Republic'),
#  ('San Felipe de Puerto Plata', 'Dominican Republic'),
#  ('Guayaquil', 'Ecuador'),
#  ('Quito', 'Ecuador'),
#  ('Cuenca', 'Ecuador'),
#  ('Machala', 'Ecuador'),
#  ('Santo Domingo de los Colorados', 'Ecuador'),
#  ('Ambato', 'Ecuador'),
#  ('Duran [Eloy Alfaro]', 'Ecuador'),
#  ('Ibarra', 'Ecuador'),
#  ('Milagro', 'Ecuador'),
#  ('Loja', 'Ecuador'),
#  ('Esmeraldas', 'Ecuador'),
#  ('Cairo', 'Egypt'),
#  ('Alexandria', 'Egypt'),
#  ('Giza', 'Egypt'),
#  ('Shubra al-Khayma', 'Egypt'),
#  ('Port Said', 'Egypt'),
#  ('Suez', 'Egypt'),
#  ('al-Mahallat al-Kubra', 'Egypt'),
#  ('Tanta', 'Egypt'),
#  ('al-Mansura', 'Egypt'),
#  ('Luxor', 'Egypt'),
#  ('Asyut', 'Egypt'),
#  ('Bahtim', 'Egypt'),
#  ('Zagazig', 'Egypt'),
#  ('al-Faiyum', 'Egypt'),
#  ('Ismailia', 'Egypt'),
#  ('Kafr al-Dawwar', 'Egypt'),
#  ('Assuan', 'Egypt'),
#  ('Damanhur', 'Egypt'),
#  ('al-Minya', 'Egypt'),
#  ('Bani Suwayf', 'Egypt'),
#  ('Qina', 'Egypt'),
#  ('Sawhaj', 'Egypt'),
#  ('Shibin al-Kawm', 'Egypt'),
#  ('Bulaq al-Dakrur', 'Egypt'),
#  ('Banha', 'Egypt'),
#  ('Warraq al-Arab', 'Egypt'),
#  ('Kafr al-Shaykh', 'Egypt'),
#  ('Mallawi', 'Egypt'),
#  ('Bilbays', 'Egypt'),
#  ('Mit Ghamr', 'Egypt'),
#  ('al-Arish', 'Egypt'),
#  ('Talkha', 'Egypt'),
#  ('Qalyub', 'Egypt'),
#  ('Jirja', 'Egypt'),
#  ('Idfu', 'Egypt'),
#  ('al-Hawamidiya', 'Egypt'),
#  ('Disuq', 'Egypt'),
#  ('San Salvador', 'El Salvador'),
#  ('Santa Ana', 'El Salvador'),
#  ('Mejicanos', 'El Salvador'),
#  ('Soyapango', 'El Salvador'),
#  ('San Miguel', 'El Salvador'),
#  ('Nueva San Salvador', 'El Salvador'),
#  ('Apopa', 'El Salvador'),
#  ('Asmara', 'Eritrea'),
#  ('Madrid', 'Spain'),
#  ('Barcelona', 'Spain'),
#  ('Valencia', 'Spain'),
#  ('Sevilla', 'Spain'),
#  ('Zaragoza', 'Spain'),
#  ('Bilbao', 'Spain'),
#  ('Las Palmas de Gran Canaria', 'Spain'),
#  ('Murcia', 'Spain'),
#  ('Palma de Mallorca', 'Spain'),
#  ('Vigo', 'Spain'),
#  ('Alicante [Alacant]', 'Spain'),
#  ('Granada', 'Spain'),
#  ('Vitoria-Gasteiz', 'Spain'),
#  ('Santa Cruz de Tenerife', 'Spain'),
#  ('Badalona', 'Spain'),
#  ('Oviedo', 'Spain'),
#  ('Elche [Elx]', 'Spain'),
#  ('Sabadell', 'Spain'),
#  ('Santander', 'Spain'),
#  ('Jerez de la Frontera', 'Spain'),
#  ('Cartagena', 'Spain'),
#  ('Fuenlabrada', 'Spain'),
#  ('Terrassa', 'Spain'),
#  ('Albacete', 'Spain'),
#  ('Getafe', 'Spain'),
#  ('Huelva', 'Spain'),
#  ('Badajoz', 'Spain'),
#  ('Santa Coloma de Gramenet', 'Spain'),
#  ('Tarragona', 'Spain'),
#  ('Ourense (Orense)', 'Spain'),
#  ('Algeciras', 'Spain'),
#  ('Marbella', 'Spain'),
#  ('Barakaldo', 'Spain'),
#  ('Dos Hermanas', 'Spain'),
#  ('Santiago de Compostela', 'Spain'),
#  ('Cape Town', 'South Africa'),
#  ('Soweto', 'South Africa'),
#  ('Johannesburg', 'South Africa'),
#  ('Port Elizabeth', 'South Africa'),
#  ('Pretoria', 'South Africa'),
#  ('Inanda', 'South Africa'),
#  ('Durban', 'South Africa'),
#  ('Vanderbijlpark', 'South Africa'),
#  ('Kempton Park', 'South Africa'),
#  ('Alberton', 'South Africa'),
#  ('Pinetown', 'South Africa'),
#  ('Pietermaritzburg', 'South Africa'),
#  ('Benoni', 'South Africa'),
#  ('Randburg', 'South Africa'),
#  ('Umlazi', 'South Africa'),
#  ('Bloemfontein', 'South Africa'),
#  ('Vereeniging', 'South Africa'),
#  ('Wonderboom', 'South Africa'),
#  ('Roodepoort', 'South Africa'),
#  ('Boksburg', 'South Africa'),
#  ('Klerksdorp', 'South Africa'),
#  ('Soshanguve', 'South Africa'),
#  ('Newcastle', 'South Africa'),
#  ('East London', 'South Africa'),
#  ('Welkom', 'South Africa'),
#  ('Kimberley', 'South Africa'),
#  ('Uitenhage', 'South Africa'),
#  ('Chatsworth', 'South Africa'),
#  ('Mdantsane', 'South Africa'),
#  ('Krugersdorp', 'South Africa'),
#  ('Botshabelo', 'South Africa'),
#  ('Brakpan', 'South Africa'),
#  ('Witbank', 'South Africa'),
#  ('Oberholzer', 'South Africa'),
#  ('Germiston', 'South Africa'),
#  ('Springs', 'South Africa'),
#  ('Westonaria', 'South Africa'),
#  ('Randfontein', 'South Africa'),
#  ('Paarl', 'South Africa'),
#  ('Potchefstroom', 'South Africa'),
#  ('Rustenburg', 'South Africa'),
#  ('Nigel', 'South Africa'),
#  ('George', 'South Africa'),
#  ('Ladysmith', 'South Africa'),
#  ('Addis Abeba', 'Ethiopia'),
#  ('Dire Dawa', 'Ethiopia'),
#  ('Nazret', 'Ethiopia'),
#  ('Gonder', 'Ethiopia'),
#  ('Dese', 'Ethiopia'),
#  ('Mekele', 'Ethiopia'),
#  ('Bahir Dar', 'Ethiopia'),
#  ('Stanley', 'Falkland Islands'),
#  ('Suva', 'Fiji Islands'),
#  ('Quezon', 'Philippines'),
#  ('Manila', 'Philippines'),
#  ('Kalookan', 'Philippines'),
#  ('Davao', 'Philippines'),
#  ('Cebu', 'Philippines'),
#  ('Zamboanga', 'Philippines'),
#  ('Pasig', 'Philippines'),
#  ('Valenzuela', 'Philippines'),
#  ('Antipolo', 'Philippines'),
#  ('Taguig', 'Philippines'),
#  ('Cagayan de Oro', 'Philippines'),
#  ('Makati', 'Philippines'),
#  ('Bacolod', 'Philippines'),
#  ('General Santos', 'Philippines'),
#  ('Marikina', 'Philippines'),
#  ('Muntinlupa', 'Philippines'),
#  ('Iloilo', 'Philippines'),
#  ('Pasay', 'Philippines'),
#  ('Malabon', 'Philippines'),
#  ('Bacoor', 'Philippines'),
#  ('Iligan', 'Philippines'),
#  ('Calamba', 'Philippines'),
#  ('Mandaluyong', 'Philippines'),
#  ('Butuan', 'Philippines'),
#  ('Angeles', 'Philippines'),
#  ('Tarlac', 'Philippines'),
#  ('Mandaue', 'Philippines'),
#  ('Baguio', 'Philippines'),
#  ('Batangas', 'Philippines'),
#  ('Cainta', 'Philippines'),
#  ('San Pedro', 'Philippines'),
#  ('Navotas', 'Philippines'),
#  ('Cabanatuan', 'Philippines'),
#  ('San Fernando', 'Philippines'),
#  ('Lipa', 'Philippines'),
#  ('Lapu-Lapu', 'Philippines'),
#  ('San Pablo', 'Philippines'),
#  ('Taytay', 'Philippines'),
#  ('Lucena', 'Philippines'),
#  ('Imus', 'Philippines'),
#  ('Olongapo', 'Philippines'),
#  ('Binangonan', 'Philippines'),
#  ('Santa Rosa', 'Philippines'),
#  ('Tagum', 'Philippines'),
#  ('Tacloban', 'Philippines'),
#  ('Malolos', 'Philippines'),
#  ('Mabalacat', 'Philippines'),
#  ('Cotabato', 'Philippines'),
#  ('Meycauayan', 'Philippines'),
#  ('Puerto Princesa', 'Philippines'),
#  ('Legazpi', 'Philippines'),
#  ('Silang', 'Philippines'),
#  ('Ormoc', 'Philippines'),
#  ('San Carlos', 'Philippines'),
#  ('Kabankalan', 'Philippines'),
#  ('Talisay', 'Philippines'),
#  ('Valencia', 'Philippines'),
#  ('Calbayog', 'Philippines'),
#  ('Santa Maria', 'Philippines'),
#  ('Pagadian', 'Philippines'),
#  ('Cadiz', 'Philippines'),
#  ('Bago', 'Philippines'),
#  ('Toledo', 'Philippines'),
#  ('Naga', 'Philippines'),
#  ('San Mateo', 'Philippines'),
#  ('Panabo', 'Philippines'),
#  ('Koronadal', 'Philippines'),
#  ('Marawi', 'Philippines'),
#  ('Dagupan', 'Philippines'),
#  ('Sagay', 'Philippines'),
#  ('Roxas', 'Philippines'),
#  ('Lubao', 'Philippines'),
#  ('Digos', 'Philippines'),
#  ('San Miguel', 'Philippines'),
#  ('Malaybalay', 'Philippines'),
#  ('Tuguegarao', 'Philippines'),
#  ('Ilagan', 'Philippines'),
#  ('Baliuag', 'Philippines'),
#  ('Surigao', 'Philippines'),
#  ('San Carlos', 'Philippines'),
#  ('San Juan del Monte', 'Philippines'),
#  ('Tanauan', 'Philippines'),
#  ('Concepcion', 'Philippines'),
#  ('Rodriguez (Montalban)', 'Philippines'),
#  ('Sariaya', 'Philippines'),
#  ('Malasiqui', 'Philippines'),
#  ('General Mariano Alvarez', 'Philippines'),
#  ('Urdaneta', 'Philippines'),
#  ('Hagonoy', 'Philippines'),
#  ('San Jose', 'Philippines'),
#  ('Polomolok', 'Philippines'),
#  ('Santiago', 'Philippines'),
#  ('Tanza', 'Philippines'),
#  ('Ozamis', 'Philippines'),
#  ('Mexico', 'Philippines'),
#  ('San Jose', 'Philippines'),
#  ('Silay', 'Philippines'),
#  ('General Trias', 'Philippines'),
#  ('Tabaco', 'Philippines'),
#  ('Cabuyao', 'Philippines'),
#  ('Calapan', 'Philippines'),
#  ('Mati', 'Philippines'),
#  ('Midsayap', 'Philippines'),
#  ('Cauayan', 'Philippines'),
#  ('Gingoog', 'Philippines'),
#  ('Dumaguete', 'Philippines'),
#  ('San Fernando', 'Philippines'),
#  ('Arayat', 'Philippines'),
#  ('Bayawan (Tulong)', 'Philippines'),
#  ('Kidapawan', 'Philippines'),
#  ('Daraga (Locsin)', 'Philippines'),
#  ('Marilao', 'Philippines'),
#  ('Malita', 'Philippines'),
#  ('Dipolog', 'Philippines'),
#  ('Cavite', 'Philippines'),
#  ('Danao', 'Philippines'),
#  ('Bislig', 'Philippines'),
#  ('Talavera', 'Philippines'),
#  ('Guagua', 'Philippines'),
#  ('Bayambang', 'Philippines'),
#  ('Nasugbu', 'Philippines'),
#  ('Baybay', 'Philippines'),
#  ('Capas', 'Philippines'),
#  ('Sultan Kudarat', 'Philippines'),
#  ('Laoag', 'Philippines'),
#  ('Bayugan', 'Philippines'),
#  ('Malungon', 'Philippines'),
#  ('Santa Cruz', 'Philippines'),
#  ('Sorsogon', 'Philippines'),
#  ('Candelaria', 'Philippines'),
#  ('Ligao', 'Philippines'),
#  ('Libreville', 'Gabon'),
#  ('Serekunda', 'Gambia'),
#  ('Banjul', 'Gambia'),
#  ('Tbilisi', 'Georgia'),
#  ('Kutaisi', 'Georgia'),
#  ('Rustavi', 'Georgia'),
#  ('Sohumi', 'Georgia'),
#  ('Accra', 'Ghana'),
#  ('Kumasi', 'Ghana'),
#  ('Tamale', 'Ghana'),
#  ('Tema', 'Ghana'),
#  ('Sekondi-Takoradi', 'Ghana'),
#  ('Nuuk', 'Greenland'),
#  ('Les Abymes', 'Guadeloupe'),
#  ('Basse-Terre', 'Guadeloupe'),
#  ('Ciudad de Guatemala', 'Guatemala'),
#  ('Mixco', 'Guatemala'),
#  ('Villa Nueva', 'Guatemala'),
#  ('Quetzaltenango', 'Guatemala'),
#  ('Conakry', 'Guinea'),
#  ('Bissau', 'Guinea-Bissau'),
#  ('Georgetown', 'Guyana'),
#  ('Port-au-Prince', 'Haiti'),
#  ('Carrefour', 'Haiti'),
#  ('Delmas', 'Haiti'),
#  ('Tegucigalpa', 'Honduras'),
#  ('Kowloon and New Kowloon', 'Hong Kong'),
#  ('Victoria', 'Hong Kong'),
#  ('Jakarta', 'Indonesia'),
#  ('Surabaya', 'Indonesia'),
#  ('Bandung', 'Indonesia'),
#  ('Medan', 'Indonesia'),
#  ('Palembang', 'Indonesia'),
#  ('Tangerang', 'Indonesia'),
#  ('Semarang', 'Indonesia'),
#  ('Ujung Pandang', 'Indonesia'),
#  ('Malang', 'Indonesia'),
#  ('Bandar Lampung', 'Indonesia'),
#  ('Bekasi', 'Indonesia'),
#  ('Padang', 'Indonesia'),
#  ('Surakarta', 'Indonesia'),
#  ('Banjarmasin', 'Indonesia'),
#  ('Pekan Baru', 'Indonesia'),
#  ('Denpasar', 'Indonesia'),
#  ('Yogyakarta', 'Indonesia'),
#  ('Pontianak', 'Indonesia'),
#  ('Samarinda', 'Indonesia'),
#  ('Jambi', 'Indonesia'),
#  ('Depok', 'Indonesia'),
#  ('Cimahi', 'Indonesia'),
#  ('Balikpapan', 'Indonesia'),
#  ('Manado', 'Indonesia'),
#  ('Mataram', 'Indonesia'),
#  ('Pekalongan', 'Indonesia'),
#  ('Tegal', 'Indonesia'),
#  ('Bogor', 'Indonesia'),
#  ('Ciputat', 'Indonesia'),
#  ('Pondokgede', 'Indonesia'),
#  ('Cirebon', 'Indonesia'),
#  ('Kediri', 'Indonesia'),
#  ('Ambon', 'Indonesia'),
#  ('Jember', 'Indonesia'),
#  ('Cilacap', 'Indonesia'),
#  ('Cimanggis', 'Indonesia'),
#  ('Pematang Siantar', 'Indonesia'),
#  ('Purwokerto', 'Indonesia'),
#  ('Ciomas', 'Indonesia'),
#  ('Tasikmalaya', 'Indonesia'),
#  ('Madiun', 'Indonesia'),
#  ('Bengkulu', 'Indonesia'),
#  ('Karawang', 'Indonesia'),
#  ('Banda Aceh', 'Indonesia'),
#  ('Palu', 'Indonesia'),
#  ('Pasuruan', 'Indonesia'),
#  ('Kupang', 'Indonesia'),
#  ('Tebing Tinggi', 'Indonesia'),
#  ('Percut Sei Tuan', 'Indonesia'),
#  ('Binjai', 'Indonesia'),
#  ('Sukabumi', 'Indonesia'),
#  ('Waru', 'Indonesia'),
#  ('Pangkal Pinang', 'Indonesia'),
#  ('Magelang', 'Indonesia'),
#  ('Blitar', 'Indonesia'),
#  ('Serang', 'Indonesia'),
#  ('Probolinggo', 'Indonesia'),
#  ('Cilegon', 'Indonesia'),
#  ('Cianjur', 'Indonesia'),
#  ('Ciparay', 'Indonesia'),
#  ('Lhokseumawe', 'Indonesia'),
#  ('Taman', 'Indonesia'),
#  ('Depok', 'Indonesia'),
#  ('Citeureup', 'Indonesia'),
#  ('Pemalang', 'Indonesia'),
#  ('Klaten', 'Indonesia'),
#  ('Salatiga', 'Indonesia'),
#  ('Cibinong', 'Indonesia'),
#  ('Palangka Raya', 'Indonesia'),
#  ('Mojokerto', 'Indonesia'),
#  ('Purwakarta', 'Indonesia'),
#  ('Garut', 'Indonesia'),
#  ('Kudus', 'Indonesia'),
#  ('Kendari', 'Indonesia'),
#  ('Jaya Pura', 'Indonesia'),
#  ('Gorontalo', 'Indonesia'),
#  ('Majalaya', 'Indonesia'),
#  ('Pondok Aren', 'Indonesia'),
#  ('Jombang', 'Indonesia'),
#  ('Sunggal', 'Indonesia'),
#  ('Batam', 'Indonesia'),
#  ('Padang Sidempuan', 'Indonesia'),
#  ('Sawangan', 'Indonesia'),
#  ('Banyuwangi', 'Indonesia'),
#  ('Tanjung Pinang', 'Indonesia'),
#  ('Mumbai (Bombay)', 'India'),
#  ('Delhi', 'India'),
#  ('Calcutta [Kolkata]', 'India'),
#  ('Chennai (Madras)', 'India'),
#  ('Hyderabad', 'India'),
#  ('Ahmedabad', 'India'),
#  ('Bangalore', 'India'),
#  ('Kanpur', 'India'),
#  ('Nagpur', 'India'),
#  ('Lucknow', 'India'),
#  ('Pune', 'India'),
#  ('Surat', 'India'),
#  ('Jaipur', 'India'),
#  ('Indore', 'India'),
#  ('Bhopal', 'India'),
#  ('Ludhiana', 'India'),
#  ('Vadodara (Baroda)', 'India'),
#  ('Kalyan', 'India'),
#  ('Madurai', 'India'),
#  ('Haora (Howrah)', 'India'),
#  ('Varanasi (Benares)', 'India'),
#  ('Patna', 'India'),
#  ('Srinagar', 'India'),
#  ('Agra', 'India'),
#  ('Coimbatore', 'India'),
#  ('Thane (Thana)', 'India'),
#  ('Allahabad', 'India'),
#  ('Meerut', 'India'),
#  ('Vishakhapatnam', 'India'),
#  ('Jabalpur', 'India'),
#  ('Amritsar', 'India'),
#  ('Faridabad', 'India'),
#  ('Vijayawada', 'India'),
#  ('Gwalior', 'India'),
#  ('Jodhpur', 'India'),
#  ('Nashik (Nasik)', 'India'),
#  ('Hubli-Dharwad', 'India'),
#  ('Solapur (Sholapur)', 'India'),
#  ('Ranchi', 'India'),
#  ('Bareilly', 'India'),
#  ('Guwahati (Gauhati)', 'India'),
#  ('Shambajinagar (Aurangabad)', 'India'),
#  ('Cochin (Kochi)', 'India'),
#  ('Rajkot', 'India'),
#  ('Kota', 'India'),
#  ('Thiruvananthapuram (Trivandrum', 'India'),
#  ('Pimpri-Chinchwad', 'India'),
#  ('Jalandhar (Jullundur)', 'India'),
#  ('Gorakhpur', 'India'),
#  ('Chandigarh', 'India'),
#  ('Mysore', 'India'),
#  ('Aligarh', 'India'),
#  ('Guntur', 'India'),
#  ('Jamshedpur', 'India'),
#  ('Ghaziabad', 'India'),
#  ('Warangal', 'India'),
#  ('Raipur', 'India'),
#  ('Moradabad', 'India'),
#  ('Durgapur', 'India'),
#  ('Amravati', 'India'),
#  ('Calicut (Kozhikode)', 'India'),
#  ('Bikaner', 'India'),
#  ('Bhubaneswar', 'India'),
#  ('Kolhapur', 'India'),
#  ('Kataka (Cuttack)', 'India'),
#  ('Ajmer', 'India'),
#  ('Bhavnagar', 'India'),
#  ('Tiruchirapalli', 'India'),
#  ('Bhilai', 'India'),
#  ('Bhiwandi', 'India'),
#  ('Saharanpur', 'India'),
#  ('Ulhasnagar', 'India'),
#  ('Salem', 'India'),
#  ('Ujjain', 'India'),
#  ('Malegaon', 'India'),
#  ('Jamnagar', 'India'),
#  ('Bokaro Steel City', 'India'),
#  ('Akola', 'India'),
#  ('Belgaum', 'India'),
#  ('Rajahmundry', 'India'),
#  ('Nellore', 'India'),
#  ('Udaipur', 'India'),
#  ('New Bombay', 'India'),
#  ('Bhatpara', 'India'),
#  ('Gulbarga', 'India'),
#  ('New Delhi', 'India'),
#  ('Jhansi', 'India'),
#  ('Gaya', 'India'),
#  ('Kakinada', 'India'),
#  ('Dhule (Dhulia)', 'India'),
#  ('Panihati', 'India'),
#  ('Nanded (Nander)', 'India'),
#  ('Mangalore', 'India'),
#  ('Dehra Dun', 'India'),
#  ('Kamarhati', 'India'),
#  ('Davangere', 'India'),
#  ('Asansol', 'India'),
#  ('Bhagalpur', 'India'),
#  ('Bellary', 'India'),
#  ('Barddhaman (Burdwan)', 'India'),
#  ('Rampur', 'India'),
#  ('Jalgaon', 'India'),
#  ('Muzaffarpur', 'India'),
#  ('Nizamabad', 'India'),
#  ('Muzaffarnagar', 'India'),
#  ('Patiala', 'India'),
#  ('Shahjahanpur', 'India'),
#  ('Kurnool', 'India'),
#  ('Tiruppur (Tirupper)', 'India'),
#  ('Rohtak', 'India'),
#  ('South Dum Dum', 'India'),
#  ('Mathura', 'India'),
#  ('Chandrapur', 'India'),
#  ('Barahanagar (Baranagar)', 'India'),
#  ('Darbhanga', 'India'),
#  ('Siliguri (Shiliguri)', 'India'),
#  ('Raurkela', 'India'),
#  ('Ambattur', 'India'),
#  ('Panipat', 'India'),
#  ('Firozabad', 'India'),
#  ('Ichalkaranji', 'India'),
#  ('Jammu', 'India'),
#  ('Ramagundam', 'India'),
#  ('Eluru', 'India'),
#  ('Brahmapur', 'India'),
#  ('Alwar', 'India'),
#  ('Pondicherry', 'India'),
#  ('Thanjavur', 'India'),
#  ('Bihar Sharif', 'India'),
#  ('Tuticorin', 'India'),
#  ('Imphal', 'India'),
#  ('Latur', 'India'),
#  ('Sagar', 'India'),
#  ('Farrukhabad-cum-Fatehgarh', 'India'),
#  ('Sangli', 'India'),
#  ('Parbhani', 'India'),
#  ('Nagar Coil', 'India'),
#  ('Bijapur', 'India'),
#  ('Kukatpalle', 'India'),
#  ('Bally', 'India'),
#  ('Bhilwara', 'India'),
#  ('Ratlam', 'India'),
#  ('Avadi', 'India'),
#  ('Dindigul', 'India'),
#  ('Ahmadnagar', 'India'),
#  ('Bilaspur', 'India'),
#  ('Shimoga', 'India'),
#  ('Kharagpur', 'India'),
#  ('Mira Bhayandar', 'India'),
#  ('Vellore', 'India'),
#  ('Jalna', 'India'),
#  ('Burnpur', 'India'),
#  ('Anantapur', 'India'),
#  ('Allappuzha (Alleppey)', 'India'),
#  ('Tirupati', 'India'),
#  ('Karnal', 'India'),
#  ('Burhanpur', 'India'),
#  ('Hisar (Hissar)', 'India'),
#  ('Tiruvottiyur', 'India'),
#  ('Mirzapur-cum-Vindhyachal', 'India'),
#  ('Secunderabad', 'India'),
#  ('Nadiad', 'India'),
#  ('Dewas', 'India'),
#  ('Murwara (Katni)', 'India'),
#  ('Ganganagar', 'India'),
#  ('Vizianagaram', 'India'),
#  ('Erode', 'India'),
#  ('Machilipatnam (Masulipatam)', 'India'),
#  ('Bhatinda (Bathinda)', 'India'),
#  ('Raichur', 'India'),
#  ('Agartala', 'India'),
#  ('Arrah (Ara)', 'India'),
#  ('Satna', 'India'),
#  ('Lalbahadur Nagar', 'India'),
#  ('Aizawl', 'India'),
#  ('Uluberia', 'India'),
#  ('Katihar', 'India'),
#  ('Cuddalore', 'India'),
#  ('Hugli-Chinsurah', 'India'),
#  ('Dhanbad', 'India'),
#  ('Raiganj', 'India'),
#  ('Sambhal', 'India'),
#  ('Durg', 'India'),
#  ('Munger (Monghyr)', 'India'),
#  ('Kanchipuram', 'India'),
#  ('North Dum Dum', 'India'),
#  ('Karimnagar', 'India'),
#  ('Bharatpur', 'India'),
#  ('Sikar', 'India'),
#  ('Hardwar (Haridwar)', 'India'),
#  ('Dabgram', 'India'),
#  ('Morena', 'India'),
#  ('Noida', 'India'),
#  ('Hapur', 'India'),
#  ('Bhusawal', 'India'),
#  ('Khandwa', 'India'),
#  ('Yamuna Nagar', 'India'),
#  ('Sonipat (Sonepat)', 'India'),
#  ('Tenali', 'India'),
#  ('Raurkela Civil Township', 'India'),
#  ('Kollam (Quilon)', 'India'),
#  ('Kumbakonam', 'India'),
#  ('Ingraj Bazar (English Bazar)', 'India'),
#  ('Timkur', 'India'),
#  ('Amroha', 'India'),
#  ('Serampore', 'India'),
#  ('Chapra', 'India'),
#  ('Pali', 'India'),
#  ('Maunath Bhanjan', 'India'),
#  ('Adoni', 'India'),
#  ('Jaunpur', 'India'),
#  ('Tirunelveli', 'India'),
#  ('Bahraich', 'India'),
#  ('Gadag Betigeri', 'India'),
#  ('Proddatur', 'India'),
#  ('Chittoor', 'India'),
#  ('Barrackpur', 'India'),
#  ('Bharuch (Broach)', 'India'),
#  ('Naihati', 'India'),
#  ('Shillong', 'India'),
#  ('Sambalpur', 'India'),
#  ('Junagadh', 'India'),
#  ('Rae Bareli', 'India'),
#  ('Rewa', 'India'),
#  ('Gurgaon', 'India'),
#  ('Khammam', 'India'),
#  ('Bulandshahr', 'India'),
#  ('Navsari', 'India'),
#  ('Malkajgiri', 'India'),
#  ('Midnapore (Medinipur)', 'India'),
#  ('Miraj', 'India'),
#  ('Raj Nandgaon', 'India'),
#  ('Alandur', 'India'),
#  ('Puri', 'India'),
#  ('Navadwip', 'India'),
#  ('Sirsa', 'India'),
#  ('Korba', 'India'),
#  ('Faizabad', 'India'),
#  ('Etawah', 'India'),
#  ('Pathankot', 'India'),
#  ('Gandhinagar', 'India'),
#  ('Palghat (Palakkad)', 'India'),
#  ('Veraval', 'India'),
#  ('Hoshiarpur', 'India'),
#  ('Ambala', 'India'),
#  ('Sitapur', 'India'),
#  ('Bhiwani', 'India'),
#  ('Cuddapah', 'India'),
#  ('Bhimavaram', 'India'),
#  ('Krishnanagar', 'India'),
#  ('Chandannagar', 'India'),
#  ...]

# %% [markdown]
# ## Example: Joining `City` and `Country`
#
# Now let's select only capital cities and keep relevant columns.

# %%
# %%sql
# SELECT
#   City.Name AS Name,
#   City.Population AS CityPop,
#   Country.Population AS CountryPop,
#   Country.Name AS Country
# FROM City
# JOIN Country
# ON  City.ID = Country.Capital
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 192 rows affected.
# [('Kabul', 1780000.0, 22720000, 'Afghanistan'),
#  ('Amsterdam', 731200.0, 15864000, 'Netherlands'),
#  ('Tirana', 270000.0, 3401200, 'Albania'),
#  ('Alger', 2168000.0, 31471000, 'Algeria'),
#  ('Fagatogo', 2323.0, 68000, 'American Samoa'),
#  ('Andorra la Vella', 21189.0, 78000, 'Andorra'),
#  ('Luanda', 2022000.0, 12878000, 'Angola'),
#  ('Abu Dhabi', 398695.0, 2441000, 'United Arab Emirates'),
#  ('Buenos Aires', 2982146.0, 37032000, 'Argentina'),
#  ('Yerevan', 1248700.0, 3520000, 'Armenia'),
#  ('Canberra', 322723.0, 18886000, 'Australia'),
#  ('Baku', 1787800.0, 7734000, 'Azerbaijan'),
#  ('Nassau', 172000.0, 307000, 'Bahamas'),
#  ('al-Manama', 148000.0, 617000, 'Bahrain'),
#  ('Dhaka', 3612850.0, 129155000, 'Bangladesh'),
#  ('Bridgetown', 6070.0, 270000, 'Barbados'),
#  ('Bruxelles [Brussel]', 133859.0, 10239000, 'Belgium'),
#  ('Belmopan', 7105.0, 241000, 'Belize'),
#  ('Hamilton', 1200.0, 65000, 'Bermuda'),
#  ('Thimphu', 22000.0, 2124000, 'Bhutan'),
#  ('La Paz', 758141.0, 8329000, 'Bolivia'),
#  ('Sarajevo', 360000.0, 3972000, 'Bosnia and Herzegovina'),
#  ('Gaborone', 213017.0, 1622000, 'Botswana'),
#  ('London', 7285000.0, 59623400, 'United Kingdom'),
#  ('Road Town', 8000.0, 21000, 'Virgin Islands, British'),
#  ('Bandar Seri Begawan', 21484.0, 328000, 'Brunei'),
#  ('Sofija', 1122302.0, 8190900, 'Bulgaria'),
#  ('Ouagadougou', 824000.0, 11937000, 'Burkina Faso'),
#  ('Bujumbura', 300000.0, 6695000, 'Burundi'),
#  ('George Town', 19600.0, 38000, 'Cayman Islands'),
#  ('Santiago de Chile', 4703954.0, 15211000, 'Chile'),
#  ('Avarua', 11900.0, 20000, 'Cook Islands'),
#  ('Djibouti', 383000.0, 638000, 'Djibouti'),
#  ('Roseau', 16243.0, 71000, 'Dominica'),
#  ('Quito', 1573458.0, 12646000, 'Ecuador'),
#  ('Cairo', 6789479.0, 68470000, 'Egypt'),
#  ('San Salvador', 415346.0, 6276000, 'El Salvador'),
#  ('Asmara', 431000.0, 3850000, 'Eritrea'),
#  ('Madrid', 2879052.0, 39441700, 'Spain'),
#  ('Pretoria', 658630.0, 40377000, 'South Africa'),
#  ('Addis Abeba', 2495000.0, 62565000, 'Ethiopia'),
#  ('Stanley', 1636.0, 2000, 'Falkland Islands'),
#  ('Suva', 77366.0, 817000, 'Fiji Islands'),
#  ('Manila', 1581082.0, 75967000, 'Philippines'),
#  ('Libreville', 419000.0, 1226000, 'Gabon'),
#  ('Banjul', 42326.0, 1305000, 'Gambia'),
#  ('Tbilisi', 1235200.0, 4968000, 'Georgia'),
#  ('Accra', 1070000.0, 20212000, 'Ghana'),
#  ('Nuuk', 13445.0, 56000, 'Greenland'),
#  ('Basse-Terre', 12433.0, 456000, 'Guadeloupe'),
#  ('Ciudad de Guatemala', 823301.0, 11385000, 'Guatemala'),
#  ('Conakry', 1090610.0, 7430000, 'Guinea'),
#  ('Bissau', 241000.0, 1213000, 'Guinea-Bissau'),
#  ('Georgetown', 254000.0, 861000, 'Guyana'),
#  ('Port-au-Prince', 884472.0, 8222000, 'Haiti'),
#  ('Tegucigalpa', 813900.0, 6485000, 'Honduras'),
#  ('Victoria', 1312637.0, 6782000, 'Hong Kong'),
#  ('Jakarta', 9604900.0, 212107000, 'Indonesia'),
#  ('New Delhi', 301297.0, 1013662000, 'India'),
#  ('Baghdad', 4336000.0, 23115000, 'Iraq'),
#  ('Teheran', 6758845.0, 67702000, 'Iran'),
#  ('Dublin', 481854.0, 3775100, 'Ireland'),
#  ('Jerusalem', 633700.0, 6217000, 'Israel'),
#  ('Roma', 2643581.0, 57680000, 'Italy'),
#  ('Dili', 47900.0, 885000, 'East Timor'),
#  ('Wien', 1608144.0, 8091800, 'Austria'),
#  ('Kingston', 103962.0, 2583000, 'Jamaica'),
#  ('Tokyo', 7980230.0, 126714000, 'Japan'),
#  ('Sanaa', 503600.0, 18112000, 'Yemen'),
#  ('Amman', 1000000.0, 5083000, 'Jordan'),
#  ('Beograd', 1204000.0, 10640000, 'Yugoslavia'),
#  ('Phnom Penh', 570155.0, 11168000, 'Cambodia'),
#  ('Ottawa', 335277.0, 31147000, 'Canada'),
#  ('Astana', 311200.0, 16223000, 'Kazakstan'),
#  ('Nairobi', 2290000.0, 30080000, 'Kenya'),
#  ('Bangui', 524000.0, 3615000, 'Central African Republic'),
#  ('Peking', 7472000.0, 1277558000, 'China'),
#  ('Bishkek', 589400.0, 4699000, 'Kyrgyzstan'),
#  ('Bairiki', 2226.0, 83000, 'Kiribati'),
#  ('Moroni', 36000.0, 578000, 'Comoros'),
#  ('Brazzaville', 950000.0, 2943000, 'Congo'),
#  ('Kinshasa', 5064000.0, 51654000, 'Congo, The Democratic Republic of the'),
#  ('West Island', 167.0, 600, 'Cocos (Keeling) Islands'),
#  ('Pyongyang', 2484000.0, 24039000, 'North Korea'),
#  ('Seoul', 9981619.0, 46844000, 'South Korea'),
#  ('Athenai', 772072.0, 10545700, 'Greece'),
#  ('Zagreb', 706770.0, 4473000, 'Croatia'),
#  ('La Habana', 2256000.0, 11201000, 'Cuba'),
#  ('Kuwait', 28859.0, 1972000, 'Kuwait'),
#  ('Nicosia', 195000.0, 754700, 'Cyprus'),
#  ('Vientiane', 531800.0, 5433000, 'Laos'),
#  ('Riga', 764328.0, 2424200, 'Latvia'),
#  ('Maseru', 297000.0, 2153000, 'Lesotho'),
#  ('Beirut', 1100000.0, 3282000, 'Lebanon'),
#  ('Monrovia', 850000.0, 3154000, 'Liberia'),
#  ('Tripoli', 1682000.0, 5605000, 'Libyan Arab Jamahiriya'),
#  ('Vaduz', 5043.0, 32300, 'Liechtenstein'),
#  ('Vilnius', 577969.0, 3698500, 'Lithuania'),
#  ('Macao', 437500.0, 473000, 'Macao'),
#  ('Antananarivo', 675669.0, 15942000, 'Madagascar'),
#  ('Skopje', 444299.0, 2024000, 'Macedonia'),
#  ('Lilongwe', 435964.0, 10925000, 'Malawi'),
#  ('Male', 71000.0, 286000, 'Maldives'),
#  ('Kuala Lumpur', 1297526.0, 22244000, 'Malaysia'),
#  ('Bamako', 809552.0, 11234000, 'Mali'),
#  ('Valletta', 7073.0, 380200, 'Malta'),
#  ('Dalap-Uliga-Darrit', 28000.0, 64000, 'Marshall Islands'),
#  ('Fort-de-France', 94050.0, 395000, 'Martinique'),
#  ('Nouakchott', 667300.0, 2670000, 'Mauritania'),
#  ('Port-Louis', 138200.0, 1158000, 'Mauritius'),
#  ('Mamoutzou', 12000.0, 149000, 'Mayotte'),
#  ('Palikir', 8600.0, 119000, 'Micronesia, Federated States of'),
#  ('Chisinau', 719900.0, 4380000, 'Moldova'),
#  ('Ulan Bator', 773700.0, 2662000, 'Mongolia'),
#  ('Plymouth', 2000.0, 11000, 'Montserrat'),
#  ('Maputo', 1018938.0, 19680000, 'Mozambique'),
#  ('Rangoon (Yangon)', 3361700.0, 45611000, 'Myanmar'),
#  ('Windhoek', 169000.0, 1726000, 'Namibia'),
#  ('Kathmandu', 591835.0, 23930000, 'Nepal'),
#  ('Managua', 959000.0, 5074000, 'Nicaragua'),
#  ('Niamey', 420000.0, 10730000, 'Niger'),
#  ('Abuja', 350100.0, 111506000, 'Nigeria'),
#  ('Oslo', 508726.0, 4478500, 'Norway'),
#  ('Yamoussoukro', 130000.0, 14786000, 'Côte d’Ivoire'),
#  ('Masqat', 51969.0, 2542000, 'Oman'),
#  ('Islamabad', 524500.0, 156483000, 'Pakistan'),
#  ('Koror', 12000.0, 19000, 'Palau'),
#  ('Port Moresby', 247000.0, 4807000, 'Papua New Guinea'),
#  ('Lima', 6464693.0, 25662000, 'Peru'),
#  ('Garapan', 9200.0, 78000, 'Northern Mariana Islands'),
#  ('Lisboa', 563210.0, 9997600, 'Portugal'),
#  ('San Juan', 434374.0, 3869000, 'Puerto Rico'),
#  ('Warszawa', 1615369.0, 38653600, 'Poland'),
#  ('Malabo', 40000.0, 453000, 'Equatorial Guinea'),
#  ('Doha', 355000.0, 599000, 'Qatar'),
#  ('Cayenne', 50699.0, 181000, 'French Guiana'),
#  ('Papeete', 25553.0, 235000, 'French Polynesia'),
#  ('Saint-Denis', 131480.0, 699000, 'Réunion'),
#  ('Bucuresti', 2016131.0, 22455500, 'Romania'),
#  ('Kigali', 286000.0, 7733000, 'Rwanda'),
#  ('Stockholm', 750348.0, 8861400, 'Sweden'),
#  ('Jamestown', 1500.0, 6000, 'Saint Helena'),
#  ('Basseterre', 11600.0, 38000, 'Saint Kitts and Nevis'),
#  ('Castries', 2301.0, 154000, 'Saint Lucia'),
#  ('Kingstown', 17100.0, 114000, 'Saint Vincent and the Grenadines'),
#  ('Saint-Pierre', 5808.0, 7000, 'Saint Pierre and Miquelon'),
#  ('Berlin', 3386667.0, 82164700, 'Germany'),
#  ('Honiara', 50100.0, 444000, 'Solomon Islands'),
#  ('Lusaka', 1317000.0, 9169000, 'Zambia'),
#  ('Apia', 35900.0, 180000, 'Samoa'),
#  ('San Marino', 2294.0, 27000, 'San Marino'),
#  ('Riyadh', 3324000.0, 21607000, 'Saudi Arabia'),
#  ('Dakar', 785071.0, 9481000, 'Senegal'),
#  ('Freetown', 850000.0, 4854000, 'Sierra Leone'),
#  ('Bratislava', 448292.0, 5398700, 'Slovakia'),
#  ('Ljubljana', 270986.0, 1987800, 'Slovenia'),
#  ('Mogadishu', 997000.0, 10097000, 'Somalia'),
#  ('Colombo', 645000.0, 18827000, 'Sri Lanka'),
#  ('Khartum', 947483.0, 29490000, 'Sudan'),
#  ('Helsinki [Helsingfors]', 555474.0, 5171300, 'Finland'),
#  ('Paramaribo', 112000.0, 417000, 'Suriname'),
#  ('Mbabane', 61000.0, 1008000, 'Swaziland'),
#  ('Bern', 122700.0, 7160400, 'Switzerland'),
#  ('Damascus', 1347000.0, 16125000, 'Syria'),
#  ('Dushanbe', 524000.0, 6188000, 'Tajikistan'),
#  ('Taipei', 2641312.0, 22256000, 'Taiwan'),
#  ('Dodoma', 189000.0, 33517000, 'Tanzania'),
#  ('Bangkok', 6320174.0, 61399000, 'Thailand'),
#  ('Fakaofo', 300.0, 2000, 'Tokelau'),
#  ('Port-of-Spain', 43396.0, 1295000, 'Trinidad and Tobago'),
#  ('Tunis', 690600.0, 9586000, 'Tunisia'),
#  ('Ankara', 3038159.0, 66591000, 'Turkey'),
#  ('Ashgabat', 540600.0, 4459000, 'Turkmenistan'),
#  ('Cockburn Town', 4800.0, 17000, 'Turks and Caicos Islands'),
#  ('Funafuti', 4600.0, 12000, 'Tuvalu'),
#  ('Kampala', 890800.0, 21778000, 'Uganda'),
#  ('Kyiv', 2624000.0, 50456000, 'Ukraine'),
#  ('Budapest', 1811552.0, 10043200, 'Hungary'),
#  ('Montevideo', 1236000.0, 3337000, 'Uruguay'),
#  ('Wellington', 166700.0, 3862000, 'New Zealand'),
#  ('Toskent', 2117500.0, 24318000, 'Uzbekistan'),
#  ('Minsk', 1674000.0, 10236000, 'Belarus'),
#  ('Mata-Utu', 1137.0, 15000, 'Wallis and Futuna'),
#  ('Port-Vila', 33700.0, 190000, 'Vanuatu'),
#  ('Caracas', 1975294.0, 24170000, 'Venezuela'),
#  ('Moscow', 8389200.0, 146934000, 'Russian Federation'),
#  ('Hanoi', 1410000.0, 79832000, 'Vietnam'),
#  ('Tallinn', 403981.0, 1439200, 'Estonia'),
#  ('Washington', 572059.0, 278357000, 'United States'),
#  ('Charlotte Amalie', 13000.0, 93000, 'Virgin Islands, U.S.'),
#  ('Harare', 1410000.0, 11669000, 'Zimbabwe'),
#  ('Gaza', 353632.0, 3101000, 'Palestine')]

# %% [markdown]
# ## Example: Joining `City` and `Country`
#
# Compute share of population living in capital and sort.

# %%
# %%sql
# SELECT
#   City.Name AS Name,
#   Country.Name AS Country,
#   (City.Population / Country.Population * 100) AS PopShare,
#   City.Population AS CityPop,
#   Country.Population AS CountryPop
# FROM City
# JOIN Country
# ON  City.ID = Country.Capital
# ORDER BY PopShare DESC
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 192 rows affected.
# [('Macao', 'Macao', 92.49471458773785, 437500.0, 473000),
#  ('Saint-Pierre', 'Saint Pierre and Miquelon', 82.97142857142858, 5808.0, 7000),
#  ('Stanley', 'Falkland Islands', 81.8, 1636.0, 2000),
#  ('Koror', 'Palau', 63.1578947368421, 12000.0, 19000),
#  ('Djibouti', 'Djibouti', 60.03134796238244, 383000.0, 638000),
#  ('Avarua', 'Cook Islands', 59.5, 11900.0, 20000),
#  ('Doha', 'Qatar', 59.26544240400668, 355000.0, 599000),
#  ('Nassau', 'Bahamas', 56.02605863192183, 172000.0, 307000),
#  ('George Town', 'Cayman Islands', 51.578947368421055, 19600.0, 38000),
#  ('Dalap-Uliga-Darrit', 'Marshall Islands', 43.75, 28000.0, 64000),
#  ('Funafuti', 'Tuvalu', 38.333333333333336, 4600.0, 12000),
#  ('Road Town', 'Virgin Islands, British', 38.095238095238095, 8000.0, 21000),
#  ('Montevideo', 'Uruguay', 37.03925681750075, 1236000.0, 3337000),
#  ('Yerevan', 'Armenia', 35.47443181818182, 1248700.0, 3520000),
#  ('Libreville', 'Gabon', 34.176182707993476, 419000.0, 1226000),
#  ('Beirut', 'Lebanon', 33.516148689823275, 1100000.0, 3282000),
#  ('Brazzaville', 'Congo', 32.27998640842677, 950000.0, 2943000),
#  ('Riga', 'Latvia', 31.529081758930783, 764328.0, 2424200),
#  ('Santiago de Chile', 'Chile', 30.92468608244034, 4703954.0, 15211000),
#  ('Basseterre', 'Saint Kitts and Nevis', 30.526315789473685, 11600.0, 38000),
#  ('Tripoli', 'Libyan Arab Jamahiriya', 30.008920606601247, 1682000.0, 5605000),
#  ('Georgetown', 'Guyana', 29.500580720092916, 254000.0, 861000),
#  ('Ulan Bator', 'Mongolia', 29.06461307287754, 773700.0, 2662000),
#  ('Cockburn Town', 'Turks and Caicos Islands', 28.235294117647058, 4800.0, 17000),
#  ('Tallinn', 'Estonia', 28.069830461367427, 403981.0, 1439200),
#  ('Cayenne', 'French Guiana', 28.01049723756906, 50699.0, 181000),
#  ('West Island', 'Cocos (Keeling) Islands', 27.833333333333332, 167.0, 600),
#  ('Andorra la Vella', 'Andorra', 27.165384615384614, 21189.0, 78000),
#  ('Monrovia', 'Liberia', 26.949904882688646, 850000.0, 3154000),
#  ('Paramaribo', 'Suriname', 26.85851318944844, 112000.0, 417000),
#  ('Nicosia', 'Cyprus', 25.83808135683053, 195000.0, 754700),
#  ('Lima', 'Peru', 25.191695892759725, 6464693.0, 25662000),
#  ('Jamestown', 'Saint Helena', 25.0, 1500.0, 6000),
#  ('Nouakchott', 'Mauritania', 24.99250936329588, 667300.0, 2670000),
#  ('Tbilisi', 'Georgia', 24.863123993558776, 1235200.0, 4968000),
#  ('Male', 'Maldives', 24.825174825174827, 71000.0, 286000),
#  ('Nuuk', 'Greenland', 24.008928571428573, 13445.0, 56000),
#  ('al-Manama', 'Bahrain', 23.9870340356564, 148000.0, 617000),
#  ('Fort-de-France', 'Martinique', 23.810126582278482, 94050.0, 395000),
#  ('Baku', 'Azerbaijan', 23.11611068011378, 1787800.0, 7734000),
#  ('Roseau', 'Dominica', 22.877464788732393, 16243.0, 71000),
#  ('Skopje', 'Macedonia', 21.95153162055336, 444299.0, 2024000),
#  ('Seoul', 'South Korea', 21.308212364443683, 9981619.0, 46844000),
#  ('La Habana', 'Cuba', 20.141058834032677, 2256000.0, 11201000),
#  ('Apia', 'Samoa', 19.944444444444446, 35900.0, 180000),
#  ('Wien', 'Austria', 19.87374873328555, 1608144.0, 8091800),
#  ('Bissau', 'Guinea-Bissau', 19.868095630667764, 241000.0, 1213000),
#  ('Amman', 'Jordan', 19.67342120794806, 1000000.0, 5083000),
#  ('Victoria', 'Hong Kong', 19.354718372161607, 1312637.0, 6782000),
#  ('Managua', 'Nicaragua', 18.900275916436737, 959000.0, 5074000),
#  ('Saint-Denis', 'Réunion', 18.80972818311874, 131480.0, 699000),
#  ('Baghdad', 'Iraq', 18.758382003028338, 4336000.0, 23115000),
#  ('Plymouth', 'Montserrat', 18.181818181818183, 2000.0, 11000),
#  ('Budapest', 'Hungary', 18.03759757846105, 1811552.0, 10043200),
#  ('Port-Vila', 'Vanuatu', 17.736842105263158, 33700.0, 190000),
#  ('Freetown', 'Sierra Leone', 17.511330861145446, 850000.0, 4854000),
#  ('Chisinau', 'Moldova', 16.43607305936073, 719900.0, 4380000),
#  ('Minsk', 'Belarus', 16.354044548651817, 1674000.0, 10236000),
#  ('Abu Dhabi', 'United Arab Emirates', 16.3332650553052, 398695.0, 2441000),
#  ('Zagreb', 'Croatia', 15.800804828973844, 706770.0, 4473000),
#  ('Luanda', 'Angola', 15.701195837863022, 2022000.0, 12878000),
#  ('Vilnius', 'Lithuania', 15.627119102338785, 577969.0, 3698500),
#  ('Vaduz', 'Liechtenstein', 15.61300309597523, 5043.0, 32300),
#  ('Riyadh', 'Saudi Arabia', 15.383903364650346, 3324000.0, 21607000),
#  ('Kingstown', 'Saint Vincent and the Grenadines', 15.0, 17100.0, 114000),
#  ('Fakaofo', 'Tokelau', 15.0, 300.0, 2000),
#  ('Conakry', 'Guinea', 14.678465679676986, 1090610.0, 7430000),
#  ('Bangui', 'Central African Republic', 14.495159059474414, 524000.0, 3615000),
#  ('Lusaka', 'Zambia', 14.36361653397317, 1317000.0, 9169000),
#  ('Charlotte Amalie', 'Virgin Islands, U.S.', 13.978494623655912, 13000.0, 93000),
#  ('Maseru', 'Lesotho', 13.794705062703205, 297000.0, 2153000),
#  ('Sofija', 'Bulgaria', 13.701815429317902, 1122302.0, 8190900),
#  ('Ljubljana', 'Slovenia', 13.632457993761948, 270986.0, 1987800),
#  ('Gaborone', 'Botswana', 13.132983970406906, 213017.0, 1622000),
#  ('Dublin', 'Ireland', 12.764006251490025, 481854.0, 3775100),
#  ('Tegucigalpa', 'Honduras', 12.550501156515034, 813900.0, 6485000),
#  ('Bishkek', 'Kyrgyzstan', 12.543094275377738, 589400.0, 4699000),
#  ('Quito', 'Ecuador', 12.44233749802309, 1573458.0, 12646000),
#  ('London', 'United Kingdom', 12.218357222164453, 7285000.0, 59623400),
#  ('Ashgabat', 'Turkmenistan', 12.123794572774164, 540600.0, 4459000),
#  ('Harare', 'Zimbabwe', 12.083297626189047, 1410000.0, 11669000),
#  ('Port-Louis', 'Mauritius', 11.934369602763386, 138200.0, 1158000),
#  ('Taipei', 'Taiwan', 11.867864845434939, 2641312.0, 22256000),
#  ('Garapan', 'Northern Mariana Islands', 11.794871794871794, 9200.0, 78000),
#  ('Gaza', 'Palestine', 11.403805224121252, 353632.0, 3101000),
#  ('Oslo', 'Norway', 11.359294406609356, 508726.0, 4478500),
#  ('Beograd', 'Yugoslavia', 11.31578947368421, 1204000.0, 10640000),
#  ('Honiara', 'Solomon Islands', 11.283783783783784, 50100.0, 444000),
#  ('San Juan', 'Puerto Rico', 11.22703540966658, 434374.0, 3869000),
#  ('Asmara', 'Eritrea', 11.194805194805195, 431000.0, 3850000),
#  ('Papeete', 'French Polynesia', 10.873617021276596, 25553.0, 235000),
#  ('Port-au-Prince', 'Haiti', 10.757382631963026, 884472.0, 8222000),
#  ('Helsinki [Helsingfors]', 'Finland', 10.741476998046913, 555474.0, 5171300),
#  ('Pyongyang', 'North Korea', 10.33320853612879, 2484000.0, 24039000),
#  ('Bangkok', 'Thailand', 10.293610645124513, 6320174.0, 61399000),
#  ('Jerusalem', 'Israel', 10.193019141064823, 633700.0, 6217000),
#  ('Teheran', 'Iran', 9.98322796963162, 6758845.0, 67702000),
#  ('Cairo', 'Egypt', 9.91599094493939, 6789479.0, 68470000),
#  ('Mogadishu', 'Somalia', 9.87422006536595, 997000.0, 10097000),
#  ('Kinshasa', 'Congo, The Democratic Republic of the', 9.80369380880474, 5064000.0, 51654000),
#  ('Windhoek', 'Namibia', 9.791425260718425, 169000.0, 1726000),
#  ('Vientiane', 'Laos', 9.788330572427755, 531800.0, 5433000),
#  ('Suva', 'Fiji Islands', 9.469522643818848, 77366.0, 817000),
#  ('La Paz', 'Bolivia', 9.10242526113579, 758141.0, 8329000),
#  ('Sarajevo', 'Bosnia and Herzegovina', 9.06344410876133, 360000.0, 3972000),
#  ('Bucuresti', 'Romania', 8.97833938233395, 2016131.0, 22455500),
#  ('Malabo', 'Equatorial Guinea', 8.830022075055188, 40000.0, 453000),
#  ('Toskent', 'Uzbekistan', 8.707541738629821, 2117500.0, 24318000),
#  ('San Marino', 'San Marino', 8.496296296296297, 2294.0, 27000),
#  ('Dushanbe', 'Tajikistan', 8.468002585649645, 524000.0, 6188000),
#  ('Stockholm', 'Sweden', 8.467601056266503, 750348.0, 8861400),
#  ('Damascus', 'Syria', 8.353488372093024, 1347000.0, 16125000),
#  ('Bratislava', 'Slovakia', 8.303702743253005, 448292.0, 5398700),
#  ('Dakar', 'Senegal', 8.280466195548993, 785071.0, 9481000),
#  ('Caracas', 'Venezuela', 8.172503103020274, 1975294.0, 24170000),
#  ('Mamoutzou', 'Mayotte', 8.053691275167784, 12000.0, 149000),
#  ('Buenos Aires', 'Argentina', 8.052889392957443, 2982146.0, 37032000),
#  ('Tirana', 'Albania', 7.9383746912854285, 270000.0, 3401200),
#  ('Kabul', 'Afghanistan', 7.834507042253522, 1780000.0, 22720000),
#  ('Nairobi', 'Kenya', 7.613031914893617, 2290000.0, 30080000),
#  ('Mata-Utu', 'Wallis and Futuna', 7.580000000000001, 1137.0, 15000),
#  ('Rangoon (Yangon)', 'Myanmar', 7.370371182390214, 3361700.0, 45611000),
#  ('Athenai', 'Greece', 7.32120200650502, 772072.0, 10545700),
#  ('Madrid', 'Spain', 7.299512952027929, 2879052.0, 39441700),
#  ('Ciudad de Guatemala', 'Guatemala', 7.231453667105842, 823301.0, 11385000),
#  ('Palikir', 'Micronesia, Federated States of', 7.226890756302522, 8600.0, 119000),
#  ('Bamako', 'Mali', 7.20626669040413, 809552.0, 11234000),
#  ('Tunis', 'Tunisia', 7.204256206968496, 690600.0, 9586000),
#  ('Ouagadougou', 'Burkina Faso', 6.902906928038871, 824000.0, 11937000),
#  ('Alger', 'Algeria', 6.888881827714403, 2168000.0, 31471000),
#  ('San Salvador', 'El Salvador', 6.6180050987890375, 415346.0, 6276000),
#  ('Bandar Seri Begawan', 'Brunei', 6.550000000000001, 21484.0, 328000),
#  ('Tokyo', 'Japan', 6.2978281799958955, 7980230.0, 126714000),
#  ('Moroni', 'Comoros', 6.228373702422145, 36000.0, 578000),
#  ('Mbabane', 'Swaziland', 6.051587301587301, 61000.0, 1008000),
#  ('Kuala Lumpur', 'Malaysia', 5.833150512497752, 1297526.0, 22244000),
#  ('Moscow', 'Russian Federation', 5.709502225488995, 8389200.0, 146934000),
#  ('Lisboa', 'Portugal', 5.633452028486837, 563210.0, 9997600),
#  ('Dili', 'East Timor', 5.4124293785310735, 47900.0, 885000),
#  ('Accra', 'Ghana', 5.293884820898477, 1070000.0, 20212000),
#  ('Kyiv', 'Ukraine', 5.200570794355478, 2624000.0, 50456000),
#  ('Maputo', 'Mozambique', 5.177530487804878, 1018938.0, 19680000),
#  ('Port Moresby', 'Papua New Guinea', 5.138339920948617, 247000.0, 4807000),
#  ('Phnom Penh', 'Cambodia', 5.1052560888252145, 570155.0, 11168000),
#  ('Amsterdam', 'Netherlands', 4.609178013111447, 731200.0, 15864000),
#  ('Roma', 'Italy', 4.583184812760056, 2643581.0, 57680000),
#  ('Ankara', 'Turkey', 4.562416843116938, 3038159.0, 66591000),
#  ('Jakarta', 'Indonesia', 4.528327683669091, 9604900.0, 212107000),
#  ('Bujumbura', 'Burundi', 4.480955937266617, 300000.0, 6695000),
#  ('Wellington', 'New Zealand', 4.316416364577939, 166700.0, 3862000),
#  ('Antananarivo', 'Madagascar', 4.238295069627399, 675669.0, 15942000),
#  ('Warszawa', 'Poland', 4.179090692716849, 1615369.0, 38653600),
#  ('Berlin', 'Germany', 4.121802915363897, 3386667.0, 82164700),
#  ('Kampala', 'Uganda', 4.0903664248324, 890800.0, 21778000),
#  ('Kingston', 'Jamaica', 4.024854819976771, 103962.0, 2583000),
#  ('Lilongwe', 'Malawi', 3.9905171624713955, 435964.0, 10925000),
#  ('Addis Abeba', 'Ethiopia', 3.987852633261408, 2495000.0, 62565000),
#  ('Niamey', 'Niger', 3.91425908667288, 420000.0, 10730000),
#  ('Kigali', 'Rwanda', 3.698435277382646, 286000.0, 7733000),
#  ('Colombo', 'Sri Lanka', 3.4259308440006375, 645000.0, 18827000),
#  ('Fagatogo', 'American Samoa', 3.416176470588235, 2323.0, 68000),
#  ('Port-of-Spain', 'Trinidad and Tobago', 3.351042471042471, 43396.0, 1295000),
#  ('Banjul', 'Gambia', 3.243371647509578, 42326.0, 1305000),
#  ('Khartum', 'Sudan', 3.2128958969142083, 947483.0, 29490000),
#  ('Belmopan', 'Belize', 2.9481327800829877, 7105.0, 241000),
#  ('Dhaka', 'Bangladesh', 2.7972978204482986, 3612850.0, 129155000),
#  ('Sanaa', 'Yemen', 2.7804770318021204, 503600.0, 18112000),
#  ('Basse-Terre', 'Guadeloupe', 2.726535087719298, 12433.0, 456000),
#  ('Bairiki', 'Kiribati', 2.6819277108433734, 2226.0, 83000),
#  ('Kathmandu', 'Nepal', 2.473192645215211, 591835.0, 23930000),
#  ('Bridgetown', 'Barbados', 2.248148148148148, 6070.0, 270000),
#  ('Manila', 'Philippines', 2.0812747640422815, 1581082.0, 75967000),
#  ('Masqat', 'Oman', 2.04441384736428, 51969.0, 2542000),
#  ('Astana', 'Kazakstan', 1.9182641928126731, 311200.0, 16223000),
#  ('Valletta', 'Malta', 1.8603366649132036, 7073.0, 380200),
#  ('Hamilton', 'Bermuda', 1.8461538461538463, 1200.0, 65000),
#  ('Hanoi', 'Vietnam', 1.766209038981862, 1410000.0, 79832000),
#  ('Bern', 'Switzerland', 1.7135914194737725, 122700.0, 7160400),
#  ('Canberra', 'Australia', 1.708794874510219, 322723.0, 18886000),
#  ('Pretoria', 'South Africa', 1.6312009312232212, 658630.0, 40377000),
#  ('Castries', 'Saint Lucia', 1.4941558441558442, 2301.0, 154000),
#  ('Kuwait', 'Kuwait', 1.4634381338742393, 28859.0, 1972000),
#  ('Bruxelles [Brussel]', 'Belgium', 1.3073444672331282, 133859.0, 10239000),
#  ('Ottawa', 'Canada', 1.0764343275435837, 335277.0, 31147000),
#  ('Thimphu', 'Bhutan', 1.0357815442561207, 22000.0, 2124000),
#  ('Yamoussoukro', 'Côte d’Ivoire', 0.8792100635736507, 130000.0, 14786000),
#  ('Peking', 'China', 0.584865814311366, 7472000.0, 1277558000),
#  ('Dodoma', 'Tanzania', 0.5638929498463466, 189000.0, 33517000),
#  ('Islamabad', 'Pakistan', 0.3351801793166031, 524500.0, 156483000),
#  ('Abuja', 'Nigeria', 0.313974135920937, 350100.0, 111506000),
#  ('Washington', 'United States', 0.20551270490772644, 572059.0, 278357000),
#  ('New Delhi', 'India', 0.029723615958771266, 301297.0, 1013662000)]

# %% [markdown]
# ## Example: Joining `City` and `Country`
#
# Remove smallest cities. Make reader-friendly.

# %%
# %%sql
# SELECT
#   City.Name AS Name,
#   Country.Name AS Country,
#   ROUND((City.Population / Country.Population * 100),1) AS PopShare,
#   CAST((City.Population/1000) AS INT) AS 'City Pop (1000s)'
# FROM City
# JOIN Country
# ON  City.ID = Country.Capital
# WHERE City.Population > 50000
# ORDER BY PopShare DESC
# Out:
#  * mysql+pymysql://guest:***@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo
# 148 rows affected.
# [('Macao', 'Macao', 92.5, 438),
#  ('Djibouti', 'Djibouti', 60.0, 383),
#  ('Doha', 'Qatar', 59.3, 355),
#  ('Nassau', 'Bahamas', 56.0, 172),
#  ('Montevideo', 'Uruguay', 37.0, 1236),
#  ('Yerevan', 'Armenia', 35.5, 1249),
#  ('Libreville', 'Gabon', 34.2, 419),
#  ('Beirut', 'Lebanon', 33.5, 1100),
#  ('Brazzaville', 'Congo', 32.3, 950),
#  ('Riga', 'Latvia', 31.5, 764),
#  ('Santiago de Chile', 'Chile', 30.9, 4704),
#  ('Tripoli', 'Libyan Arab Jamahiriya', 30.0, 1682),
#  ('Georgetown', 'Guyana', 29.5, 254),
#  ('Ulan Bator', 'Mongolia', 29.1, 774),
#  ('Tallinn', 'Estonia', 28.1, 404),
#  ('Cayenne', 'French Guiana', 28.0, 51),
#  ('Monrovia', 'Liberia', 26.9, 850),
#  ('Paramaribo', 'Suriname', 26.9, 112),
#  ('Nicosia', 'Cyprus', 25.8, 195),
#  ('Lima', 'Peru', 25.2, 6465),
#  ('Nouakchott', 'Mauritania', 25.0, 667),
#  ('Tbilisi', 'Georgia', 24.9, 1235),
#  ('Male', 'Maldives', 24.8, 71),
#  ('al-Manama', 'Bahrain', 24.0, 148),
#  ('Fort-de-France', 'Martinique', 23.8, 94),
#  ('Baku', 'Azerbaijan', 23.1, 1788),
#  ('Skopje', 'Macedonia', 22.0, 444),
#  ('Seoul', 'South Korea', 21.3, 9982),
#  ('La Habana', 'Cuba', 20.1, 2256),
#  ('Bissau', 'Guinea-Bissau', 19.9, 241),
#  ('Wien', 'Austria', 19.9, 1608),
#  ('Amman', 'Jordan', 19.7, 1000),
#  ('Victoria', 'Hong Kong', 19.4, 1313),
#  ('Managua', 'Nicaragua', 18.9, 959),
#  ('Baghdad', 'Iraq', 18.8, 4336),
#  ('Saint-Denis', 'Réunion', 18.8, 131),
#  ('Budapest', 'Hungary', 18.0, 1812),
#  ('Freetown', 'Sierra Leone', 17.5, 850),
#  ('Chisinau', 'Moldova', 16.4, 720),
#  ('Minsk', 'Belarus', 16.4, 1674),
#  ('Abu Dhabi', 'United Arab Emirates', 16.3, 399),
#  ('Zagreb', 'Croatia', 15.8, 707),
#  ('Luanda', 'Angola', 15.7, 2022),
#  ('Vilnius', 'Lithuania', 15.6, 578),
#  ('Riyadh', 'Saudi Arabia', 15.4, 3324),
#  ('Conakry', 'Guinea', 14.7, 1091),
#  ('Bangui', 'Central African Republic', 14.5, 524),
#  ('Lusaka', 'Zambia', 14.4, 1317),
#  ('Maseru', 'Lesotho', 13.8, 297),
#  ('Sofija', 'Bulgaria', 13.7, 1122),
#  ('Ljubljana', 'Slovenia', 13.6, 271),
#  ('Gaborone', 'Botswana', 13.1, 213),
#  ('Dublin', 'Ireland', 12.8, 482),
#  ('Tegucigalpa', 'Honduras', 12.6, 814),
#  ('Bishkek', 'Kyrgyzstan', 12.5, 589),
#  ('Quito', 'Ecuador', 12.4, 1573),
#  ('London', 'United Kingdom', 12.2, 7285),
#  ('Ashgabat', 'Turkmenistan', 12.1, 541),
#  ('Harare', 'Zimbabwe', 12.1, 1410),
#  ('Port-Louis', 'Mauritius', 11.9, 138),
#  ('Taipei', 'Taiwan', 11.9, 2641),
#  ('Oslo', 'Norway', 11.4, 509),
#  ('Gaza', 'Palestine', 11.4, 354),
#  ('Beograd', 'Yugoslavia', 11.3, 1204),
#  ('Honiara', 'Solomon Islands', 11.3, 50),
#  ('Asmara', 'Eritrea', 11.2, 431),
#  ('San Juan', 'Puerto Rico', 11.2, 434),
#  ('Port-au-Prince', 'Haiti', 10.8, 884),
#  ('Helsinki [Helsingfors]', 'Finland', 10.7, 555),
#  ('Pyongyang', 'North Korea', 10.3, 2484),
#  ('Bangkok', 'Thailand', 10.3, 6320),
#  ('Jerusalem', 'Israel', 10.2, 634),
#  ('Teheran', 'Iran', 10.0, 6759),
#  ('Cairo', 'Egypt', 9.9, 6789),
#  ('Mogadishu', 'Somalia', 9.9, 997),
#  ('Kinshasa', 'Congo, The Democratic Republic of the', 9.8, 5064),
#  ('Vientiane', 'Laos', 9.8, 532),
#  ('Windhoek', 'Namibia', 9.8, 169),
#  ('Suva', 'Fiji Islands', 9.5, 77),
#  ('La Paz', 'Bolivia', 9.1, 758),
#  ('Sarajevo', 'Bosnia and Herzegovina', 9.1, 360),
#  ('Bucuresti', 'Romania', 9.0, 2016),
#  ('Toskent', 'Uzbekistan', 8.7, 2118),
#  ('Stockholm', 'Sweden', 8.5, 750),
#  ('Dushanbe', 'Tajikistan', 8.5, 524),
#  ('Damascus', 'Syria', 8.4, 1347),
#  ('Dakar', 'Senegal', 8.3, 785),
#  ('Bratislava', 'Slovakia', 8.3, 448),
#  ('Caracas', 'Venezuela', 8.2, 1975),
#  ('Buenos Aires', 'Argentina', 8.1, 2982),
#  ('Tirana', 'Albania', 7.9, 270),
#  ('Kabul', 'Afghanistan', 7.8, 1780),
#  ('Nairobi', 'Kenya', 7.6, 2290),
#  ('Rangoon (Yangon)', 'Myanmar', 7.4, 3362),
#  ('Madrid', 'Spain', 7.3, 2879),
#  ('Athenai', 'Greece', 7.3, 772),
#  ('Ciudad de Guatemala', 'Guatemala', 7.2, 823),
#  ('Bamako', 'Mali', 7.2, 810),
#  ('Tunis', 'Tunisia', 7.2, 691),
#  ('Alger', 'Algeria', 6.9, 2168),
#  ('Ouagadougou', 'Burkina Faso', 6.9, 824),
#  ('San Salvador', 'El Salvador', 6.6, 415),
#  ('Tokyo', 'Japan', 6.3, 7980),
#  ('Mbabane', 'Swaziland', 6.1, 61),
#  ('Kuala Lumpur', 'Malaysia', 5.8, 1298),
#  ('Moscow', 'Russian Federation', 5.7, 8389),
#  ('Lisboa', 'Portugal', 5.6, 563),
#  ('Accra', 'Ghana', 5.3, 1070),
#  ('Maputo', 'Mozambique', 5.2, 1019),
#  ('Kyiv', 'Ukraine', 5.2, 2624),
#  ('Phnom Penh', 'Cambodia', 5.1, 570),
#  ('Port Moresby', 'Papua New Guinea', 5.1, 247),
#  ('Amsterdam', 'Netherlands', 4.6, 731),
#  ('Roma', 'Italy', 4.6, 2644),
#  ('Ankara', 'Turkey', 4.6, 3038),
#  ('Bujumbura', 'Burundi', 4.5, 300),
#  ('Jakarta', 'Indonesia', 4.5, 9605),
#  ('Wellington', 'New Zealand', 4.3, 167),
#  ('Antananarivo', 'Madagascar', 4.2, 676),
#  ('Warszawa', 'Poland', 4.2, 1615),
#  ('Berlin', 'Germany', 4.1, 3387),
#  ('Kampala', 'Uganda', 4.1, 891),
#  ('Addis Abeba', 'Ethiopia', 4.0, 2495),
#  ('Kingston', 'Jamaica', 4.0, 104),
#  ('Lilongwe', 'Malawi', 4.0, 436),
#  ('Niamey', 'Niger', 3.9, 420),
#  ('Kigali', 'Rwanda', 3.7, 286),
#  ('Colombo', 'Sri Lanka', 3.4, 645),
#  ('Khartum', 'Sudan', 3.2, 947),
#  ('Dhaka', 'Bangladesh', 2.8, 3613),
#  ('Sanaa', 'Yemen', 2.8, 504),
#  ('Kathmandu', 'Nepal', 2.5, 592),
#  ('Manila', 'Philippines', 2.1, 1581),
#  ('Masqat', 'Oman', 2.0, 52),
#  ('Astana', 'Kazakstan', 1.9, 311),
#  ('Hanoi', 'Vietnam', 1.8, 1410),
#  ('Canberra', 'Australia', 1.7, 323),
#  ('Bern', 'Switzerland', 1.7, 123),
#  ('Pretoria', 'South Africa', 1.6, 659),
#  ('Bruxelles [Brussel]', 'Belgium', 1.3, 134),
#  ('Ottawa', 'Canada', 1.1, 335),
#  ('Yamoussoukro', 'Côte d’Ivoire', 0.9, 130),
#  ('Peking', 'China', 0.6, 7472),
#  ('Dodoma', 'Tanzania', 0.6, 189),
#  ('Abuja', 'Nigeria', 0.3, 350),
#  ('Islamabad', 'Pakistan', 0.3, 524),
#  ('Washington', 'United States', 0.2, 572),
#  ('New Delhi', 'India', 0.0, 301)]

# %% [markdown]
# ## SQL Tutorials
#
# There are lots of great SQL Tutorials to go further. Here are a few pointers:
#
# - [Codeacademy's SQL Tutorial](https://www.codecademy.com/learn/learn-sql)
# - [SQLzoo's SQL Tutorial](https://sqlzoo.net/)
# - [W3School.com SQL reference](https://www.w3schools.com/sql) (also interactive)
# - [Datacamp's SQL Intro to Databases in Python](https://learn.datacamp.com/courses/introduction-to-relational-databases-in-python) and [Introduction to Joins in PostgreSQL](https://learn.datacamp.com/courses/joining-data-in-postgresql)

# %% [markdown]
# ## Datagrip
#
# ![](images/datagrip.png)

# %% [markdown]
# # SQLAlchemy
#
# ![](images/sqlalchemy_banner.png)

# %% [markdown]
# ## What is SQLAlchemy?
#
# [SQLAlchemy](https://www.sqlalchemy.org/) is a powerful database access tool kit for Python.
#
# It allows to interact with databases in a pythonic way using its [object-relational mapper (ORM)](https://en.wikipedia.org/wiki/Object-relational_mapping).
#
# One of the fundamental elements to enable connecting SQLAlchemy to a database is creating a model. The model is a Python class defining the data mapping between the Python objects returned as a result of a database query and the underlying database tables.

# %% [markdown]
# ## Connecting to a Database
#
#     from sqlalchemy import create_engine
#     engine = create_engine('sqlite://database_name.sqlite')
#     connection = engine.connect()
#
# **engine**: common interface to databases with SQLAlchemy
# **connection string**: contains username and password (if required) as well as the location of the database and its name

# %%
from sqlalchemy import create_engine, MetaData, Table
from sqlalchemy import func, cast, Numeric, Integer, select


engine = create_engine('mysql+pymysql://guest:guest@shiny-demo.csa7qlmguqrf.us-east-1.rds.amazonaws.com/shinydemo')
connection = engine.connect()
metadata = MetaData()

City = Table('City', metadata, autoload=True, autoload_with=engine)
# Print the column names
print(City.columns.keys())
# Out:
# ['ID', 'Name', 'CountryCode', 'District', 'Population']

# %% [markdown]
# ## Writing a Query

# %%
query = select([City.columns.Name.label('city_name'),
                City.columns.CountryCode,
                  cast(City.columns.Population, Integer).label('city_population')]).where(
        City.columns.Population>5000)

connection.execute(query).fetchall()
# Out:
# [('Kabul', 'AFG', 1780000),
#  ('Qandahar', 'AFG', 237500),
#  ('Herat', 'AFG', 186800),
#  ('Mazar-e-Sharif', 'AFG', 127800),
#  ('Amsterdam', 'NLD', 731200),
#  ('Rotterdam', 'NLD', 593321),
#  ('Haag', 'NLD', 440900),
#  ('Utrecht', 'NLD', 234323),
#  ('Eindhoven', 'NLD', 201843),
#  ('Tilburg', 'NLD', 193238),
#  ('Groningen', 'NLD', 172701),
#  ('Breda', 'NLD', 160398),
#  ('Apeldoorn', 'NLD', 153491),
#  ('Nijmegen', 'NLD', 152463),
#  ('Enschede', 'NLD', 149544),
#  ('Haarlem', 'NLD', 148772),
#  ('Almere', 'NLD', 142465),
#  ('Arnhem', 'NLD', 138020),
#  ('Zaanstad', 'NLD', 135621),
#  ('Amersfoort', 'NLD', 126270),
#  ('Maastricht', 'NLD', 122087),
#  ('Dordrecht', 'NLD', 119811),
#  ('Leiden', 'NLD', 117196),
#  ('Haarlemmermeer', 'NLD', 110722),
#  ('Zoetermeer', 'NLD', 110214),
#  ('Emmen', 'NLD', 105853),
#  ('Zwolle', 'NLD', 105819),
#  ('Ede', 'NLD', 101574),
#  ('Delft', 'NLD', 95268),
#  ('Heerlen', 'NLD', 95052),
#  ('Alkmaar', 'NLD', 92713),
#  ('Tirana', 'ALB', 270000),
#  ('Alger', 'DZA', 2168000),
#  ('Oran', 'DZA', 609823),
#  ('Constantine', 'DZA', 443727),
#  ('Annaba', 'DZA', 222518),
#  ('Batna', 'DZA', 183377),
#  ('Skikda', 'DZA', 128747),
#  ('Biskra', 'DZA', 128281),
#  ('Blida (el-Boulaida)', 'DZA', 127284),
#  ('Mostaganem', 'DZA', 115212),
#  ('Tlemcen (Tilimsen)', 'DZA', 110242),
#  ('Tiaret', 'DZA', 100118),
#  ('Ech-Chleff (el-Asnam)', 'DZA', 96794),
#  ('Tafuna', 'ASM', 5200),
#  ('Andorra la Vella', 'AND', 21189),
#  ('Luanda', 'AGO', 2022000),
#  ('Huambo', 'AGO', 163100),
#  ('Lobito', 'AGO', 130000),
#  ('Benguela', 'AGO', 128300),
#  ('Namibe', 'AGO', 118200),
#  ('Dubai', 'ARE', 669181),
#  ('Abu Dhabi', 'ARE', 398695),
#  ('Sharja', 'ARE', 320095),
#  ('al-Ayn', 'ARE', 225970),
#  ('Ajman', 'ARE', 114395),
#  ('Buenos Aires', 'ARG', 2982146),
#  ('La Matanza', 'ARG', 1266461),
#  ('Lomas de Zamora', 'ARG', 622013),
#  ('Quilmes', 'ARG', 559249),
#  ('Almirante Brown', 'ARG', 538918),
#  ('La Plata', 'ARG', 521936),
#  ('Mar del Plata', 'ARG', 512880),
#  ('Merlo', 'ARG', 463846),
#  ('Salta', 'ARG', 367550),
#  ('Moreno', 'ARG', 356993),
#  ('Avellaneda', 'ARG', 353046),
#  ('Tres de Febrero', 'ARG', 352311),
#  ('Florencio Varela', 'ARG', 315432),
#  ('San Isidro', 'ARG', 306341),
#  ('Tigre', 'ARG', 296226),
#  ('Malvinas Argentinas', 'ARG', 290335),
#  ('Berazategui', 'ARG', 276916),
#  ('Corrientes', 'ARG', 258103),
#  ('San Miguel', 'ARG', 248700),
#  ('Resistencia', 'ARG', 229212),
#  ('Godoy Cruz', 'ARG', 206998),
#  ('Posadas', 'ARG', 201273),
#  ('Santiago del Estero', 'ARG', 189947),
#  ('San Salvador de Jujuy', 'ARG', 178748),
#  ('Hurlingham', 'ARG', 170028),
#  ('San Fernando', 'ARG', 153036),
#  ('Formosa', 'ARG', 147636),
#  ('Las Heras', 'ARG', 145823),
#  ('La Rioja', 'ARG', 138117),
#  ('San Fernando del Valle de Cata', 'ARG', 134935),
#  ('Comodoro Rivadavia', 'ARG', 124104),
#  ('Mendoza', 'ARG', 123027),
#  ('San Juan', 'ARG', 119152),
#  ('Escobar', 'ARG', 116675),
#  ('Concordia', 'ARG', 116485),
#  ('Pilar', 'ARG', 113428),
#  ('San Luis', 'ARG', 110136),
#  ('Ezeiza', 'ARG', 99578),
#  ('San Rafael', 'ARG', 94651),
#  ('Tandil', 'ARG', 91101),
#  ('Yerevan', 'ARM', 1248700),
#  ('Vanadzor', 'ARM', 172700),
#  ('Sydney', 'AUS', 3276207),
#  ('Melbourne', 'AUS', 2865329),
#  ('Brisbane', 'AUS', 1291117),
#  ('Perth', 'AUS', 1096829),
#  ('Adelaide', 'AUS', 978100),
#  ('Canberra', 'AUS', 322723),
#  ('Gold Coast', 'AUS', 311932),
#  ('Newcastle', 'AUS', 270324),
#  ('Central Coast', 'AUS', 227657),
#  ('Wollongong', 'AUS', 219761),
#  ('Hobart', 'AUS', 126118),
#  ('Geelong', 'AUS', 125382),
#  ('Townsville', 'AUS', 109914),
#  ('Cairns', 'AUS', 92273),
#  ('Baku', 'AZE', 1787800),
#  ('Sumqayit', 'AZE', 283000),
#  ('Nassau', 'BHS', 172000),
#  ('al-Manama', 'BHR', 148000),
#  ('Dhaka', 'BGD', 3612850),
#  ('Chittagong', 'BGD', 1392860),
#  ('Khulna', 'BGD', 663340),
#  ('Rajshahi', 'BGD', 294056),
#  ('Narayanganj', 'BGD', 202134),
#  ('Rangpur', 'BGD', 191398),
#  ('Mymensingh', 'BGD', 188713),
#  ('Barisal', 'BGD', 170232),
#  ('Tungi', 'BGD', 168702),
#  ('Jessore', 'BGD', 139710),
#  ('Comilla', 'BGD', 135313),
#  ('Nawabganj', 'BGD', 130577),
#  ('Dinajpur', 'BGD', 127815),
#  ('Bogra', 'BGD', 120170),
#  ('Sylhet', 'BGD', 117396),
#  ('Brahmanbaria', 'BGD', 109032),
#  ('Tangail', 'BGD', 106004),
#  ('Jamalpur', 'BGD', 103556),
#  ('Pabna', 'BGD', 103277),
#  ('Naogaon', 'BGD', 101266),
#  ('Sirajganj', 'BGD', 99669),
#  ('Narsinghdi', 'BGD', 98342),
#  ('Saidpur', 'BGD', 96777),
#  ('Gazipur', 'BGD', 96717),
#  ('Bridgetown', 'BRB', 6070),
#  ('Antwerpen', 'BEL', 446525),
#  ('Gent', 'BEL', 224180),
#  ('Charleroi', 'BEL', 200827),
#  ('Bruxelles [Brussel]', 'BEL', 133859),
#  ('Brugge', 'BEL', 116246),
#  ('Schaerbeek', 'BEL', 105692),
#  ('Namur', 'BEL', 105419),
#  ('Mons', 'BEL', 90935),
#  ('Belize City', 'BLZ', 55810),
#  ('Belmopan', 'BLZ', 7105),
#  ('Cotonou', 'BEN', 536827),
#  ('Djougou', 'BEN', 134099),
#  ('Parakou', 'BEN', 103577),
#  ('Thimphu', 'BTN', 22000),
#  ('Santa Cruz de la Sierra', 'BOL', 935361),
#  ('La Paz', 'BOL', 758141),
#  ('El Alto', 'BOL', 534466),
#  ('Cochabamba', 'BOL', 482800),
#  ('Oruro', 'BOL', 223553),
#  ('Sucre', 'BOL', 178426),
#  ('Tarija', 'BOL', 125255),
#  ('Sarajevo', 'BIH', 360000),
#  ('Banja Luka', 'BIH', 143079),
#  ('Zenica', 'BIH', 96027),
#  ('Gaborone', 'BWA', 213017),
#  ('Francistown', 'BWA', 101805),
#  ('Rio de Janeiro', 'BRA', 5598953),
#  ('Salvador', 'BRA', 2302832),
#  ('Belo Horizonte', 'BRA', 2139125),
#  ('Recife', 'BRA', 1378087),
#  ('Porto Alegre', 'BRA', 1314032),
#  ('Manaus', 'BRA', 1255049),
#  ('Duque de Caxias', 'BRA', 746758),
#  ('Natal', 'BRA', 688955),
#  ('Campo Grande', 'BRA', 649593),
#  ('Contagem', 'BRA', 520801),
#  ('Feira de Santana', 'BRA', 479992),
#  ('Juiz de Fora', 'BRA', 450288),
#  ('Aracaju', 'BRA', 445555),
#  ('Joinville', 'BRA', 428011),
#  ('Belford Roxo', 'BRA', 425194),
#  ('Campos dos Goytacazes', 'BRA', 398418),
#  ('Olinda', 'BRA', 354732),
#  ('Caxias do Sul', 'BRA', 349581),
#  ('Pelotas', 'BRA', 315415),
#  ('Betim', 'BRA', 302108),
#  ('Canoas', 'BRA', 294125),
#  ('Montes Claros', 'BRA', 286058),
#  ('Rio Branco', 'BRA', 259537),
#  ('Uberaba', 'BRA', 249225),
#  ('Paulista', 'BRA', 248473),
#  ('Blumenau', 'BRA', 244379),
#  ('Caruaru', 'BRA', 244247),
#  ('Volta Redonda', 'BRA', 240315),
#  ('Novo Hamburgo', 'BRA', 239940),
#  ('Santa Maria', 'BRA', 238473),
#  ('Governador Valadares', 'BRA', 231724),
#  ('Petrolina', 'BRA', 210540),
#  ('Ipatinga', 'BRA', 206338),
#  ('Juazeiro', 'BRA', 201073),
#  ('Sete Lagoas', 'BRA', 182984),
#  ('Rio Grande', 'BRA', 182222),
#  ('Itabuna', 'BRA', 182148),
#  ('Arapiraca', 'BRA', 178988),
#  ('Alvorada', 'BRA', 175574),
#  ('Nova Friburgo', 'BRA', 170697),
#  ('Barra Mansa', 'BRA', 168953),
#  ('Boa Vista', 'BRA', 167185),
#  ('Passo Fundo', 'BRA', 166343),
#  ('Dourados', 'BRA', 164716),
#  ('Santa Luzia', 'BRA', 164704),
#  ('Cabo de Santo Agostinho', 'BRA', 149964),
#  ('Lages', 'BRA', 139570),
#  ('Nossa Senhora do Socorro', 'BRA', 131351),
#  ('Barreiras', 'BRA', 127801),
#  ('Alagoinhas', 'BRA', 126820),
#  ('Uruguaiana', 'BRA', 126305),
#  ('Palmas', 'BRA', 121919),
#  ('Sapucaia do Sul', 'BRA', 120217),
#  ('Cabo Frio', 'BRA', 119503),
#  ('Patos de Minas', 'BRA', 119262),
#  ('Camaragibe', 'BRA', 118968),
#  ('Queimados', 'BRA', 115020),
#  ('Garanhuns', 'BRA', 114603),
#  ('Barbacena', 'BRA', 113079),
#  ('Lauro de Freitas', 'BRA', 109236),
#  ('Teixeira de Freitas', 'BRA', 108441),
#  ('Varginha', 'BRA', 108314),
#  ('Santa Cruz do Sul', 'BRA', 106734),
#  ('Cachoeirinha', 'BRA', 103240),
#  ('Itabira', 'BRA', 102217),
#  ('Resende', 'BRA', 100627),
#  ('Pouso Alegre', 'BRA', 100028),
#  ('Passos', 'BRA', 98570),
#  ('Araguari', 'BRA', 98399),
#  ('Conselheiro Lafaiete', 'BRA', 97507),
#  ('Paulo Afonso', 'BRA', 97291),
#  ('Angra dos Reis', 'BRA', 96864),
#  ('Parnamirim', 'BRA', 96210),
#  ('Jacobina', 'BRA', 96131),
#  ('Coronel Fabriciano', 'BRA', 95933),
#  ('Santana do Livramento', 'BRA', 91779),
#  ('Ituiutaba', 'BRA', 90507),
#  ('London', 'GBR', 7285000),
#  ('Birmingham', 'GBR', 1013000),
#  ('Glasgow', 'GBR', 619680),
#  ('Liverpool', 'GBR', 461000),
#  ('Edinburgh', 'GBR', 450180),
#  ('Sheffield', 'GBR', 431607),
#  ('Manchester', 'GBR', 430000),
#  ('Leeds', 'GBR', 424194),
#  ('Bristol', 'GBR', 402000),
#  ('Cardiff', 'GBR', 321000),
#  ('Coventry', 'GBR', 304000),
#  ('Leicester', 'GBR', 294000),
#  ('Bradford', 'GBR', 289376),
#  ('Belfast', 'GBR', 287500),
#  ('Nottingham', 'GBR', 287000),
#  ('Kingston upon Hull', 'GBR', 262000),
#  ('Plymouth', 'GBR', 253000),
#  ('Stoke-on-Trent', 'GBR', 252000),
#  ('Wolverhampton', 'GBR', 242000),
#  ('Derby', 'GBR', 236000),
#  ('Swansea', 'GBR', 230000),
#  ('Southampton', 'GBR', 216000),
#  ('Aberdeen', 'GBR', 213070),
#  ('Northampton', 'GBR', 196000),
#  ('Dudley', 'GBR', 192171),
#  ('Portsmouth', 'GBR', 190000),
#  ('Newcastle upon Tyne', 'GBR', 189150),
#  ('Sunderland', 'GBR', 183310),
#  ('Luton', 'GBR', 183000),
#  ('Swindon', 'GBR', 180000),
#  ('Southend-on-Sea', 'GBR', 176000),
#  ('Walsall', 'GBR', 174739),
#  ('Bournemouth', 'GBR', 162000),
#  ('Peterborough', 'GBR', 156000),
#  ('Brighton', 'GBR', 156124),
#  ('Blackpool', 'GBR', 151000),
#  ('Dundee', 'GBR', 146690),
#  ('West Bromwich', 'GBR', 146386),
#  ('Reading', 'GBR', 148000),
#  ('Oldbury/Smethwick (Warley)', 'GBR', 145542),
#  ('Middlesbrough', 'GBR', 145000),
#  ('Huddersfield', 'GBR', 143726),
#  ('Oxford', 'GBR', 144000),
#  ('Poole', 'GBR', 141000),
#  ('Bolton', 'GBR', 139020),
#  ('Blackburn', 'GBR', 140000),
#  ('Newport', 'GBR', 139000),
#  ('Preston', 'GBR', 135000),
#  ('Stockport', 'GBR', 132813),
#  ('Norwich', 'GBR', 124000),
#  ('Rotherham', 'GBR', 121380),
#  ('Cambridge', 'GBR', 121000),
#  ('Watford', 'GBR', 113080),
#  ('Ipswich', 'GBR', 114000),
#  ('Slough', 'GBR', 112000),
#  ('Exeter', 'GBR', 111000),
#  ('Cheltenham', 'GBR', 106000),
#  ('Gloucester', 'GBR', 107000),
#  ('Saint Helens', 'GBR', 106293),
#  ('Sutton Coldfield', 'GBR', 106001),
#  ('York', 'GBR', 104425),
#  ('Oldham', 'GBR', 103931),
#  ('Basildon', 'GBR', 100924),
#  ('Worthing', 'GBR', 100000),
#  ('Chelmsford', 'GBR', 97451),
#  ('Colchester', 'GBR', 96063),
#  ('Crawley', 'GBR', 97000),
#  ('Gillingham', 'GBR', 92000),
#  ('Solihull', 'GBR', 94531),
#  ('Rochdale', 'GBR', 94313),
#  ('Birkenhead', 'GBR', 93087),
#  ('Worcester', 'GBR', 95000),
#  ('Hartlepool', 'GBR', 92000),
#  ('Halifax', 'GBR', 91069),
#  ('Woking/Byfleet', 'GBR', 92000),
#  ('Southport', 'GBR', 90959),
#  ('Maidstone', 'GBR', 90878),
#  ('Eastbourne', 'GBR', 90000),
#  ('Grimsby', 'GBR', 89000),
#  ('Saint Helier', 'GBR', 27523),
#  ('Road Town', 'VGB', 8000),
#  ('Bandar Seri Begawan', 'BRN', 21484),
#  ('Sofija', 'BGR', 1122302),
#  ('Plovdiv', 'BGR', 342584),
#  ('Varna', 'BGR', 299801),
#  ('Burgas', 'BGR', 195255),
#  ('Ruse', 'BGR', 166467),
#  ('Stara Zagora', 'BGR', 147939),
#  ('Pleven', 'BGR', 121952),
#  ('Sliven', 'BGR', 105530),
#  ('Dobric', 'BGR', 100399),
#  ('Ouagadougou', 'BFA', 824000),
#  ('Bobo-Dioulasso', 'BFA', 300000),
#  ('Bujumbura', 'BDI', 300000),
#  ('George Town', 'CYM', 19600),
#  ('Santiago de Chile', 'CHL', 4703954),
#  ('Puente Alto', 'CHL', 386236),
#  ('Antofagasta', 'CHL', 251429),
#  ('San Bernardo', 'CHL', 241910),
#  ('Talca', 'CHL', 187557),
#  ('Puerto Montt', 'CHL', 152194),
#  ('Coquimbo', 'CHL', 143353),
#  ('Osorno', 'CHL', 141468),
#  ('La Serena', 'CHL', 137409),
#  ('Calama', 'CHL', 137265),
#  ('Valdivia', 'CHL', 133106),
#  ('Punta Arenas', 'CHL', 125631),
#  ('Ovalle', 'CHL', 94854),
#  ('Melipilla', 'CHL', 91056),
#  ('Avarua', 'COK', 11900),
#  ('Djibouti', 'DJI', 383000),
#  ('Roseau', 'DMA', 16243),
#  ('Santiago de los Caballeros', 'DOM', 365463),
#  ('La Romana', 'DOM', 140204),
#  ('San Felipe de Puerto Plata', 'DOM', 89423),
#  ('Guayaquil', 'ECU', 2070040),
#  ('Quito', 'ECU', 1573458),
#  ('Cuenca', 'ECU', 270353),
#  ('Machala', 'ECU', 210368),
#  ('Santo Domingo de los Colorados', 'ECU', 202111),
#  ('Ambato', 'ECU', 169612),
#  ('Duran [Eloy Alfaro]', 'ECU', 152514),
#  ('Ibarra', 'ECU', 130643),
#  ('Milagro', 'ECU', 124177),
#  ('Loja', 'ECU', 123875),
#  ('Esmeraldas', 'ECU', 123045),
#  ('Cairo', 'EGY', 6789479),
#  ('Alexandria', 'EGY', 3328196),
#  ('Giza', 'EGY', 2221868),
#  ('Shubra al-Khayma', 'EGY', 870716),
#  ('Port Said', 'EGY', 469533),
#  ('Suez', 'EGY', 417610),
#  ('al-Mahallat al-Kubra', 'EGY', 395402),
#  ('Tanta', 'EGY', 371010),
#  ('al-Mansura', 'EGY', 369621),
#  ('Luxor', 'EGY', 360503),
#  ('Asyut', 'EGY', 343498),
#  ('Bahtim', 'EGY', 275807),
#  ('Zagazig', 'EGY', 267351),
#  ('al-Faiyum', 'EGY', 260964),
#  ('Ismailia', 'EGY', 254477),
#  ('Kafr al-Dawwar', 'EGY', 231978),
#  ('Assuan', 'EGY', 219017),
#  ('Damanhur', 'EGY', 212203),
#  ('al-Minya', 'EGY', 201360),
#  ('Bani Suwayf', 'EGY', 172032),
#  ('Qina', 'EGY', 171275),
#  ('Sawhaj', 'EGY', 170125),
#  ('Shibin al-Kawm', 'EGY', 159909),
#  ('Bulaq al-Dakrur', 'EGY', 148787),
#  ('Banha', 'EGY', 145792),
#  ('Warraq al-Arab', 'EGY', 127108),
#  ('Kafr al-Shaykh', 'EGY', 124819),
#  ('Mallawi', 'EGY', 119283),
#  ('Bilbays', 'EGY', 113608),
#  ('Mit Ghamr', 'EGY', 101801),
#  ('al-Arish', 'EGY', 100447),
#  ('Talkha', 'EGY', 97700),
#  ('Qalyub', 'EGY', 97200),
#  ('Jirja', 'EGY', 95400),
#  ('Idfu', 'EGY', 94200),
#  ('al-Hawamidiya', 'EGY', 91700),
#  ('Disuq', 'EGY', 91300),
#  ('San Salvador', 'SLV', 415346),
#  ('Santa Ana', 'SLV', 139389),
#  ('Mejicanos', 'SLV', 138800),
#  ('Soyapango', 'SLV', 129800),
#  ('San Miguel', 'SLV', 127696),
#  ('Nueva San Salvador', 'SLV', 98400),
#  ('Apopa', 'SLV', 88800),
#  ('Asmara', 'ERI', 431000),
#  ('Madrid', 'ESP', 2879052),
#  ('Barcelona', 'ESP', 1503451),
#  ('Valencia', 'ESP', 739412),
#  ('Sevilla', 'ESP', 701927),
#  ('Zaragoza', 'ESP', 603367),
#  ('Bilbao', 'ESP', 357589),
#  ('Las Palmas de Gran Canaria', 'ESP', 354757),
#  ('Murcia', 'ESP', 353504),
#  ('Palma de Mallorca', 'ESP', 326993),
#  ('Vigo', 'ESP', 283670),
#  ('Alicante [Alacant]', 'ESP', 272432),
#  ('Granada', 'ESP', 244767),
#  ('Vitoria-Gasteiz', 'ESP', 217154),
#  ('Santa Cruz de Tenerife', 'ESP', 213050),
#  ('Badalona', 'ESP', 209635),
#  ('Oviedo', 'ESP', 200453),
#  ('Elche [Elx]', 'ESP', 193174),
#  ('Sabadell', 'ESP', 184859),
#  ('Santander', 'ESP', 184165),
#  ('Jerez de la Frontera', 'ESP', 182660),
#  ('Cartagena', 'ESP', 177709),
#  ('Fuenlabrada', 'ESP', 171173),
#  ('Terrassa', 'ESP', 168695),
#  ('Albacete', 'ESP', 147527),
#  ('Getafe', 'ESP', 145371),
#  ('Huelva', 'ESP', 140583),
#  ('Badajoz', 'ESP', 136613),
#  ('Santa Coloma de Gramenet', 'ESP', 120802),
#  ('Tarragona', 'ESP', 113016),
#  ('Ourense (Orense)', 'ESP', 109120),
#  ('Algeciras', 'ESP', 103106),
#  ('Marbella', 'ESP', 101144),
#  ('Barakaldo', 'ESP', 98212),
#  ('Dos Hermanas', 'ESP', 94591),
#  ('Santiago de Compostela', 'ESP', 93745),
#  ('Cape Town', 'ZAF', 2352121),
#  ('Soweto', 'ZAF', 904165),
#  ('Johannesburg', 'ZAF', 756653),
#  ('Port Elizabeth', 'ZAF', 752319),
#  ('Pretoria', 'ZAF', 658630),
#  ('Inanda', 'ZAF', 634065),
#  ('Durban', 'ZAF', 566120),
#  ('Vanderbijlpark', 'ZAF', 468931),
#  ('Kempton Park', 'ZAF', 442633),
#  ('Alberton', 'ZAF', 410102),
#  ('Pinetown', 'ZAF', 378810),
#  ('Pietermaritzburg', 'ZAF', 370190),
#  ('Benoni', 'ZAF', 365467),
#  ('Randburg', 'ZAF', 341288),
#  ('Umlazi', 'ZAF', 339233),
#  ('Bloemfontein', 'ZAF', 334341),
#  ('Vereeniging', 'ZAF', 328535),
#  ('Wonderboom', 'ZAF', 283289),
#  ('Roodepoort', 'ZAF', 279340),
#  ('Boksburg', 'ZAF', 262648),
#  ('Klerksdorp', 'ZAF', 261911),
#  ('Soshanguve', 'ZAF', 242727),
#  ('Newcastle', 'ZAF', 222993),
#  ('East London', 'ZAF', 221047),
#  ('Welkom', 'ZAF', 203296),
#  ('Kimberley', 'ZAF', 197254),
#  ('Uitenhage', 'ZAF', 192120),
#  ('Chatsworth', 'ZAF', 189885),
#  ('Mdantsane', 'ZAF', 182639),
#  ('Krugersdorp', 'ZAF', 181503),
#  ('Botshabelo', 'ZAF', 177971),
#  ('Brakpan', 'ZAF', 171363),
#  ('Witbank', 'ZAF', 167183),
#  ('Oberholzer', 'ZAF', 164367),
#  ('Germiston', 'ZAF', 164252),
#  ('Springs', 'ZAF', 162072),
#  ('Westonaria', 'ZAF', 159632),
#  ('Randfontein', 'ZAF', 120838),
#  ('Paarl', 'ZAF', 105768),
#  ('Potchefstroom', 'ZAF', 101817),
#  ('Rustenburg', 'ZAF', 97008),
#  ('Nigel', 'ZAF', 96734),
#  ('George', 'ZAF', 93818),
#  ('Ladysmith', 'ZAF', 89292),
#  ('Addis Abeba', 'ETH', 2495000),
#  ('Dire Dawa', 'ETH', 164851),
#  ('Nazret', 'ETH', 127842),
#  ('Gonder', 'ETH', 112249),
#  ('Dese', 'ETH', 97314),
#  ('Mekele', 'ETH', 96938),
#  ('Bahir Dar', 'ETH', 96140),
#  ('Suva', 'FJI', 77366),
#  ('Quezon', 'PHL', 2173831),
#  ('Manila', 'PHL', 1581082),
#  ('Kalookan', 'PHL', 1177604),
#  ('Davao', 'PHL', 1147116),
#  ('Cebu', 'PHL', 718821),
#  ('Zamboanga', 'PHL', 601794),
#  ('Pasig', 'PHL', 505058),
#  ('Valenzuela', 'PHL', 485433),
#  ('Antipolo', 'PHL', 470866),
#  ('Taguig', 'PHL', 467375),
#  ('Cagayan de Oro', 'PHL', 461877),
#  ('Makati', 'PHL', 444867),
#  ('Bacolod', 'PHL', 429076),
#  ('General Santos', 'PHL', 411822),
#  ('Marikina', 'PHL', 391170),
#  ('Muntinlupa', 'PHL', 379310),
#  ('Iloilo', 'PHL', 365820),
#  ('Pasay', 'PHL', 354908),
#  ('Malabon', 'PHL', 338855),
#  ('Bacoor', 'PHL', 305699),
#  ('Iligan', 'PHL', 285061),
#  ('Calamba', 'PHL', 281146),
#  ('Mandaluyong', 'PHL', 278474),
#  ('Butuan', 'PHL', 267279),
#  ('Angeles', 'PHL', 263971),
#  ('Tarlac', 'PHL', 262481),
#  ('Mandaue', 'PHL', 259728),
#  ('Baguio', 'PHL', 252386),
#  ('Batangas', 'PHL', 247588),
#  ('Cainta', 'PHL', 242511),
#  ('San Pedro', 'PHL', 231403),
#  ('Navotas', 'PHL', 230403),
#  ('Cabanatuan', 'PHL', 222859),
#  ('San Fernando', 'PHL', 221857),
#  ('Lipa', 'PHL', 218447),
#  ('Lapu-Lapu', 'PHL', 217019),
#  ('San Pablo', 'PHL', 207927),
#  ('Taytay', 'PHL', 198183),
#  ('Lucena', 'PHL', 196075),
#  ('Imus', 'PHL', 195482),
#  ('Olongapo', 'PHL', 194260),
#  ('Binangonan', 'PHL', 187691),
#  ('Santa Rosa', 'PHL', 185633),
#  ('Tagum', 'PHL', 179531),
#  ('Tacloban', 'PHL', 178639),
#  ('Malolos', 'PHL', 175291),
#  ('Mabalacat', 'PHL', 171045),
#  ('Cotabato', 'PHL', 163849),
#  ('Meycauayan', 'PHL', 163037),
#  ('Puerto Princesa', 'PHL', 161912),
#  ('Legazpi', 'PHL', 157010),
#  ('Silang', 'PHL', 156137),
#  ('Ormoc', 'PHL', 154297),
#  ('San Carlos', 'PHL', 154264),
#  ('Kabankalan', 'PHL', 149769),
#  ('Talisay', 'PHL', 148110),
#  ('Valencia', 'PHL', 147924),
#  ('Calbayog', 'PHL', 147187),
#  ('Santa Maria', 'PHL', 144282),
#  ('Pagadian', 'PHL', 142515),
#  ('Cadiz', 'PHL', 141954),
#  ('Bago', 'PHL', 141721),
#  ('Toledo', 'PHL', 141174),
#  ('Naga', 'PHL', 137810),
#  ('San Mateo', 'PHL', 135603),
#  ('Panabo', 'PHL', 133950),
#  ('Koronadal', 'PHL', 133786),
#  ('Marawi', 'PHL', 131090),
#  ('Dagupan', 'PHL', 130328),
#  ('Sagay', 'PHL', 129765),
#  ('Roxas', 'PHL', 126352),
#  ('Lubao', 'PHL', 125699),
#  ('Digos', 'PHL', 125171),
#  ('San Miguel', 'PHL', 123824),
#  ('Malaybalay', 'PHL', 123672),
#  ('Tuguegarao', 'PHL', 120645),
#  ('Ilagan', 'PHL', 119990),
#  ('Baliuag', 'PHL', 119675),
#  ('Surigao', 'PHL', 118534),
#  ('San Carlos', 'PHL', 118259),
#  ('San Juan del Monte', 'PHL', 117680),
#  ('Tanauan', 'PHL', 117539),
#  ('Concepcion', 'PHL', 115171),
#  ('Rodriguez (Montalban)', 'PHL', 115167),
#  ('Sariaya', 'PHL', 114568),
#  ('Malasiqui', 'PHL', 113190),
#  ('General Mariano Alvarez', 'PHL', 112446),
#  ('Urdaneta', 'PHL', 111582),
#  ('Hagonoy', 'PHL', 111425),
#  ('San Jose', 'PHL', 111009),
#  ('Polomolok', 'PHL', 110709),
#  ('Santiago', 'PHL', 110531),
#  ('Tanza', 'PHL', 110517),
#  ('Ozamis', 'PHL', 110420),
#  ('Mexico', 'PHL', 109481),
#  ('San Jose', 'PHL', 108254),
#  ('Silay', 'PHL', 107722),
#  ('General Trias', 'PHL', 107691),
#  ('Tabaco', 'PHL', 107166),
#  ('Cabuyao', 'PHL', 106630),
#  ('Calapan', 'PHL', 105910),
#  ('Mati', 'PHL', 105908),
#  ('Midsayap', 'PHL', 105760),
#  ('Cauayan', 'PHL', 103952),
#  ('Gingoog', 'PHL', 102379),
#  ('Dumaguete', 'PHL', 102265),
#  ('San Fernando', 'PHL', 102082),
#  ('Arayat', 'PHL', 101792),
#  ('Bayawan (Tulong)', 'PHL', 101391),
#  ('Kidapawan', 'PHL', 101205),
#  ('Daraga (Locsin)', 'PHL', 101031),
#  ('Marilao', 'PHL', 101017),
#  ('Malita', 'PHL', 100000),
#  ('Dipolog', 'PHL', 99862),
#  ('Cavite', 'PHL', 99367),
#  ('Danao', 'PHL', 98781),
#  ('Bislig', 'PHL', 97860),
#  ('Talavera', 'PHL', 97329),
#  ('Guagua', 'PHL', 96858),
#  ('Bayambang', 'PHL', 96609),
#  ('Nasugbu', 'PHL', 96113),
#  ('Baybay', 'PHL', 95630),
#  ('Capas', 'PHL', 95219),
#  ('Sultan Kudarat', 'PHL', 94861),
#  ('Laoag', 'PHL', 94466),
#  ('Bayugan', 'PHL', 93623),
#  ('Malungon', 'PHL', 93232),
#  ('Santa Cruz', 'PHL', 92694),
#  ('Sorsogon', 'PHL', 92512),
#  ('Candelaria', 'PHL', 92429),
#  ('Ligao', 'PHL', 90603),
#  ('Libreville', 'GAB', 419000),
#  ('Serekunda', 'GMB', 102600),
#  ('Banjul', 'GMB', 42326),
#  ('Tbilisi', 'GEO', 1235200),
#  ('Kutaisi', 'GEO', 240900),
#  ('Rustavi', 'GEO', 155400),
#  ('Sohumi', 'GEO', 111700),
#  ('Accra', 'GHA', 1070000),
#  ('Kumasi', 'GHA', 385192),
#  ('Tamale', 'GHA', 151069),
#  ('Tema', 'GHA', 109975),
#  ('Sekondi-Takoradi', 'GHA', 103653),
#  ('Nuuk', 'GRL', 13445),
#  ('Les Abymes', 'GLP', 62947),
#  ('Basse-Terre', 'GLP', 12433),
#  ('Ciudad de Guatemala', 'GTM', 823301),
#  ('Mixco', 'GTM', 209791),
#  ('Villa Nueva', 'GTM', 101295),
#  ('Quetzaltenango', 'GTM', 90801),
#  ('Conakry', 'GIN', 1090610),
#  ('Bissau', 'GNB', 241000),
#  ('Georgetown', 'GUY', 254000),
#  ('Port-au-Prince', 'HTI', 884472),
#  ('Carrefour', 'HTI', 290204),
#  ('Delmas', 'HTI', 240429),
#  ('Tegucigalpa', 'HND', 813900),
#  ('Kowloon and New Kowloon', 'HKG', 1987996),
#  ('Victoria', 'HKG', 1312637),
#  ('Jakarta', 'IDN', 9604900),
#  ('Surabaya', 'IDN', 2663820),
#  ('Bandung', 'IDN', 2429000),
#  ('Medan', 'IDN', 1843919),
#  ('Palembang', 'IDN', 1222764),
#  ('Tangerang', 'IDN', 1198300),
#  ('Semarang', 'IDN', 1104405),
#  ('Ujung Pandang', 'IDN', 1060257),
#  ('Malang', 'IDN', 716862),
#  ('Bandar Lampung', 'IDN', 680332),
#  ('Bekasi', 'IDN', 644300),
#  ('Padang', 'IDN', 534474),
#  ('Surakarta', 'IDN', 518600),
#  ('Banjarmasin', 'IDN', 482931),
#  ('Pekan Baru', 'IDN', 438638),
#  ('Denpasar', 'IDN', 435000),
#  ('Yogyakarta', 'IDN', 418944),
#  ('Pontianak', 'IDN', 409632),
#  ('Samarinda', 'IDN', 399175),
#  ('Jambi', 'IDN', 385201),
#  ('Depok', 'IDN', 365200),
#  ('Cimahi', 'IDN', 344600),
#  ('Balikpapan', 'IDN', 338752),
#  ('Manado', 'IDN', 332288),
#  ('Mataram', 'IDN', 306600),
#  ('Pekalongan', 'IDN', 301504),
#  ('Tegal', 'IDN', 289744),
#  ('Bogor', 'IDN', 285114),
#  ('Ciputat', 'IDN', 270800),
#  ('Pondokgede', 'IDN', 263200),
#  ('Cirebon', 'IDN', 254406),
#  ('Kediri', 'IDN', 253760),
#  ('Ambon', 'IDN', 249312),
#  ('Jember', 'IDN', 218500),
#  ('Cilacap', 'IDN', 206900),
#  ('Cimanggis', 'IDN', 205100),
#  ('Pematang Siantar', 'IDN', 203056),
#  ('Purwokerto', 'IDN', 202500),
#  ('Ciomas', 'IDN', 187400),
#  ('Tasikmalaya', 'IDN', 179800),
#  ('Madiun', 'IDN', 171532),
#  ('Bengkulu', 'IDN', 146439),
#  ('Karawang', 'IDN', 145000),
#  ('Banda Aceh', 'IDN', 143409),
#  ('Palu', 'IDN', 142800),
#  ('Pasuruan', 'IDN', 134019),
#  ('Kupang', 'IDN', 129300),
#  ('Tebing Tinggi', 'IDN', 129300),
#  ('Percut Sei Tuan', 'IDN', 129000),
#  ('Binjai', 'IDN', 127222),
#  ('Sukabumi', 'IDN', 125766),
#  ('Waru', 'IDN', 124300),
#  ('Pangkal Pinang', 'IDN', 124000),
#  ('Magelang', 'IDN', 123800),
#  ('Blitar', 'IDN', 122600),
#  ('Serang', 'IDN', 122400),
#  ('Probolinggo', 'IDN', 120770),
#  ('Cilegon', 'IDN', 117000),
#  ('Cianjur', 'IDN', 114300),
#  ('Ciparay', 'IDN', 111500),
#  ('Lhokseumawe', 'IDN', 109600),
#  ('Taman', 'IDN', 107000),
#  ('Depok', 'IDN', 106800),
#  ('Citeureup', 'IDN', 105100),
#  ('Pemalang', 'IDN', 103500),
#  ('Klaten', 'IDN', 103300),
#  ('Salatiga', 'IDN', 103000),
#  ('Cibinong', 'IDN', 101300),
#  ('Palangka Raya', 'IDN', 99693),
#  ('Mojokerto', 'IDN', 96626),
#  ('Purwakarta', 'IDN', 95900),
#  ('Garut', 'IDN', 95800),
#  ('Kudus', 'IDN', 95300),
#  ('Kendari', 'IDN', 94800),
#  ('Jaya Pura', 'IDN', 94700),
#  ('Gorontalo', 'IDN', 94058),
#  ('Majalaya', 'IDN', 93200),
#  ('Pondok Aren', 'IDN', 92700),
#  ('Jombang', 'IDN', 92600),
#  ('Sunggal', 'IDN', 92300),
#  ('Batam', 'IDN', 91871),
#  ('Padang Sidempuan', 'IDN', 91200),
#  ('Sawangan', 'IDN', 91100),
#  ('Banyuwangi', 'IDN', 89900),
#  ('Tanjung Pinang', 'IDN', 89900),
#  ('Mumbai (Bombay)', 'IND', 10500000),
#  ('Delhi', 'IND', 7206704),
#  ('Calcutta [Kolkata]', 'IND', 4399819),
#  ('Chennai (Madras)', 'IND', 3841396),
#  ('Hyderabad', 'IND', 2964638),
#  ('Ahmedabad', 'IND', 2876710),
#  ('Bangalore', 'IND', 2660088),
#  ('Kanpur', 'IND', 1874409),
#  ('Nagpur', 'IND', 1624752),
#  ('Lucknow', 'IND', 1619115),
#  ('Pune', 'IND', 1566651),
#  ('Surat', 'IND', 1498817),
#  ('Jaipur', 'IND', 1458483),
#  ('Indore', 'IND', 1091674),
#  ('Bhopal', 'IND', 1062771),
#  ('Ludhiana', 'IND', 1042740),
#  ('Vadodara (Baroda)', 'IND', 1031346),
#  ('Kalyan', 'IND', 1014557),
#  ('Madurai', 'IND', 977856),
#  ('Haora (Howrah)', 'IND', 950435),
#  ('Varanasi (Benares)', 'IND', 929270),
#  ('Patna', 'IND', 917243),
#  ('Srinagar', 'IND', 892506),
#  ('Agra', 'IND', 891790),
#  ('Coimbatore', 'IND', 816321),
#  ('Thane (Thana)', 'IND', 803389),
#  ('Allahabad', 'IND', 792858),
#  ('Meerut', 'IND', 753778),
#  ('Vishakhapatnam', 'IND', 752037),
#  ('Jabalpur', 'IND', 741927),
#  ('Amritsar', 'IND', 708835),
#  ('Faridabad', 'IND', 703592),
#  ('Vijayawada', 'IND', 701827),
#  ('Gwalior', 'IND', 690765),
#  ('Jodhpur', 'IND', 666279),
#  ('Nashik (Nasik)', 'IND', 656925),
#  ('Hubli-Dharwad', 'IND', 648298),
#  ('Solapur (Sholapur)', 'IND', 604215),
#  ('Ranchi', 'IND', 599306),
#  ('Bareilly', 'IND', 587211),
#  ('Guwahati (Gauhati)', 'IND', 584342),
#  ('Shambajinagar (Aurangabad)', 'IND', 573272),
#  ('Cochin (Kochi)', 'IND', 564589),
#  ('Rajkot', 'IND', 559407),
#  ('Kota', 'IND', 537371),
#  ('Thiruvananthapuram (Trivandrum', 'IND', 524006),
#  ('Pimpri-Chinchwad', 'IND', 517083),
#  ('Jalandhar (Jullundur)', 'IND', 509510),
#  ('Gorakhpur', 'IND', 505566),
#  ('Chandigarh', 'IND', 504094),
#  ('Mysore', 'IND', 480692),
#  ('Aligarh', 'IND', 480520),
#  ('Guntur', 'IND', 471051),
#  ('Jamshedpur', 'IND', 460577),
#  ('Ghaziabad', 'IND', 454156),
#  ('Warangal', 'IND', 447657),
#  ('Raipur', 'IND', 438639),
#  ('Moradabad', 'IND', 429214),
#  ('Durgapur', 'IND', 425836),
#  ('Amravati', 'IND', 421576),
#  ('Calicut (Kozhikode)', 'IND', 419831),
#  ('Bikaner', 'IND', 416289),
#  ('Bhubaneswar', 'IND', 411542),
#  ('Kolhapur', 'IND', 406370),
#  ('Kataka (Cuttack)', 'IND', 403418),
#  ('Ajmer', 'IND', 402700),
#  ('Bhavnagar', 'IND', 402338),
#  ('Tiruchirapalli', 'IND', 387223),
#  ('Bhilai', 'IND', 386159),
#  ('Bhiwandi', 'IND', 379070),
#  ('Saharanpur', 'IND', 374945),
#  ('Ulhasnagar', 'IND', 369077),
#  ('Salem', 'IND', 366712),
#  ('Ujjain', 'IND', 362266),
#  ('Malegaon', 'IND', 342595),
#  ('Jamnagar', 'IND', 341637),
#  ('Bokaro Steel City', 'IND', 333683),
#  ('Akola', 'IND', 328034),
#  ('Belgaum', 'IND', 326399),
#  ('Rajahmundry', 'IND', 324851),
#  ('Nellore', 'IND', 316606),
#  ('Udaipur', 'IND', 308571),
#  ('New Bombay', 'IND', 307297),
#  ('Bhatpara', 'IND', 304952),
#  ('Gulbarga', 'IND', 304099),
#  ('New Delhi', 'IND', 301297),
#  ('Jhansi', 'IND', 300850),
#  ('Gaya', 'IND', 291675),
#  ('Kakinada', 'IND', 279980),
#  ('Dhule (Dhulia)', 'IND', 278317),
#  ('Panihati', 'IND', 275990),
#  ('Nanded (Nander)', 'IND', 275083),
#  ('Mangalore', 'IND', 273304),
#  ('Dehra Dun', 'IND', 270159),
#  ('Kamarhati', 'IND', 266889),
#  ('Davangere', 'IND', 266082),
#  ('Asansol', 'IND', 262188),
#  ('Bhagalpur', 'IND', 253225),
#  ('Bellary', 'IND', 245391),
#  ('Barddhaman (Burdwan)', 'IND', 245079),
#  ('Rampur', 'IND', 243742),
#  ('Jalgaon', 'IND', 242193),
#  ('Muzaffarpur', 'IND', 241107),
#  ('Nizamabad', 'IND', 241034),
#  ('Muzaffarnagar', 'IND', 240609),
#  ('Patiala', 'IND', 238368),
#  ('Shahjahanpur', 'IND', 237713),
#  ('Kurnool', 'IND', 236800),
#  ('Tiruppur (Tirupper)', 'IND', 235661),
#  ('Rohtak', 'IND', 233400),
#  ('South Dum Dum', 'IND', 232811),
#  ('Mathura', 'IND', 226691),
#  ('Chandrapur', 'IND', 226105),
#  ('Barahanagar (Baranagar)', 'IND', 224821),
#  ('Darbhanga', 'IND', 218391),
#  ('Siliguri (Shiliguri)', 'IND', 216950),
#  ('Raurkela', 'IND', 215489),
#  ('Ambattur', 'IND', 215424),
#  ('Panipat', 'IND', 215218),
#  ('Firozabad', 'IND', 215128),
#  ('Ichalkaranji', 'IND', 214950),
#  ('Jammu', 'IND', 214737),
#  ('Ramagundam', 'IND', 214384),
#  ('Eluru', 'IND', 212866),
#  ('Brahmapur', 'IND', 210418),
#  ('Alwar', 'IND', 205086),
#  ('Pondicherry', 'IND', 203065),
#  ('Thanjavur', 'IND', 202013),
#  ('Bihar Sharif', 'IND', 201323),
#  ('Tuticorin', 'IND', 199854),
#  ('Imphal', 'IND', 198535),
#  ('Latur', 'IND', 197408),
#  ('Sagar', 'IND', 195346),
#  ('Farrukhabad-cum-Fatehgarh', 'IND', 194567),
#  ('Sangli', 'IND', 193197),
#  ('Parbhani', 'IND', 190255),
#  ('Nagar Coil', 'IND', 190084),
#  ('Bijapur', 'IND', 186939),
#  ('Kukatpalle', 'IND', 185378),
#  ('Bally', 'IND', 184474),
#  ('Bhilwara', 'IND', 183965),
#  ('Ratlam', 'IND', 183375),
#  ('Avadi', 'IND', 183215),
#  ('Dindigul', 'IND', 182477),
#  ('Ahmadnagar', 'IND', 181339),
#  ('Bilaspur', 'IND', 179833),
#  ('Shimoga', 'IND', 179258),
#  ('Kharagpur', 'IND', 177989),
#  ('Mira Bhayandar', 'IND', 175372),
#  ('Vellore', 'IND', 175061),
#  ('Jalna', 'IND', 174985),
#  ('Burnpur', 'IND', 174933),
#  ('Anantapur', 'IND', 174924),
#  ('Allappuzha (Alleppey)', 'IND', 174666),
#  ('Tirupati', 'IND', 174369),
#  ('Karnal', 'IND', 173751),
#  ('Burhanpur', 'IND', 172710),
#  ('Hisar (Hissar)', 'IND', 172677),
#  ('Tiruvottiyur', 'IND', 172562),
#  ('Mirzapur-cum-Vindhyachal', 'IND', 169336),
#  ('Secunderabad', 'IND', 167461),
#  ('Nadiad', 'IND', 167051),
#  ('Dewas', 'IND', 164364),
#  ('Murwara (Katni)', 'IND', 163431),
#  ('Ganganagar', 'IND', 161482),
#  ('Vizianagaram', 'IND', 160359),
#  ('Erode', 'IND', 159232),
#  ('Machilipatnam (Masulipatam)', 'IND', 159110),
#  ('Bhatinda (Bathinda)', 'IND', 159042),
#  ('Raichur', 'IND', 157551),
#  ('Agartala', 'IND', 157358),
#  ('Arrah (Ara)', 'IND', 157082),
#  ('Satna', 'IND', 156630),
#  ('Lalbahadur Nagar', 'IND', 155500),
#  ('Aizawl', 'IND', 155240),
#  ('Uluberia', 'IND', 155172),
#  ('Katihar', 'IND', 154367),
#  ('Cuddalore', 'IND', 153086),
#  ('Hugli-Chinsurah', 'IND', 151806),
#  ('Dhanbad', 'IND', 151789),
#  ('Raiganj', 'IND', 151045),
#  ('Sambhal', 'IND', 150869),
#  ('Durg', 'IND', 150645),
#  ('Munger (Monghyr)', 'IND', 150112),
#  ('Kanchipuram', 'IND', 150100),
#  ('North Dum Dum', 'IND', 149965),
#  ('Karimnagar', 'IND', 148583),
#  ('Bharatpur', 'IND', 148519),
#  ('Sikar', 'IND', 148272),
#  ('Hardwar (Haridwar)', 'IND', 147305),
#  ('Dabgram', 'IND', 147217),
#  ('Morena', 'IND', 147124),
#  ('Noida', 'IND', 146514),
#  ('Hapur', 'IND', 146262),
#  ('Bhusawal', 'IND', 145143),
#  ('Khandwa', 'IND', 145133),
#  ('Yamuna Nagar', 'IND', 144346),
#  ('Sonipat (Sonepat)', 'IND', 143922),
#  ('Tenali', 'IND', 143726),
#  ('Raurkela Civil Township', 'IND', 140408),
#  ('Kollam (Quilon)', 'IND', 139852),
#  ('Kumbakonam', 'IND', 139483),
#  ('Ingraj Bazar (English Bazar)', 'IND', 139204),
#  ('Timkur', 'IND', 138903),
#  ('Amroha', 'IND', 137061),
#  ('Serampore', 'IND', 137028),
#  ('Chapra', 'IND', 136877),
#  ('Pali', 'IND', 136842),
#  ('Maunath Bhanjan', 'IND', 136697),
#  ('Adoni', 'IND', 136182),
#  ('Jaunpur', 'IND', 136062),
#  ('Tirunelveli', 'IND', 135825),
#  ('Bahraich', 'IND', 135400),
#  ('Gadag Betigeri', 'IND', 134051),
#  ('Proddatur', 'IND', 133914),
#  ('Chittoor', 'IND', 133462),
#  ('Barrackpur', 'IND', 133265),
#  ('Bharuch (Broach)', 'IND', 133102),
#  ('Naihati', 'IND', 132701),
#  ('Shillong', 'IND', 131719),
#  ('Sambalpur', 'IND', 131138),
#  ('Junagadh', 'IND', 130484),
#  ('Rae Bareli', 'IND', 129904),
#  ('Rewa', 'IND', 128981),
#  ('Gurgaon', 'IND', 128608),
#  ('Khammam', 'IND', 127992),
#  ('Bulandshahr', 'IND', 127201),
#  ('Navsari', 'IND', 126089),
#  ('Malkajgiri', 'IND', 126066),
#  ('Midnapore (Medinipur)', 'IND', 125498),
#  ('Miraj', 'IND', 125407),
#  ('Raj Nandgaon', 'IND', 125371),
#  ('Alandur', 'IND', 125244),
#  ('Puri', 'IND', 125199),
#  ('Navadwip', 'IND', 125037),
#  ('Sirsa', 'IND', 125000),
#  ('Korba', 'IND', 124501),
#  ('Faizabad', 'IND', 124437),
#  ('Etawah', 'IND', 124072),
#  ('Pathankot', 'IND', 123930),
#  ('Gandhinagar', 'IND', 123359),
#  ('Palghat (Palakkad)', 'IND', 123289),
#  ('Veraval', 'IND', 123000),
#  ('Hoshiarpur', 'IND', 122705),
#  ('Ambala', 'IND', 122596),
#  ('Sitapur', 'IND', 121842),
#  ('Bhiwani', 'IND', 121629),
#  ('Cuddapah', 'IND', 121463),
#  ('Bhimavaram', 'IND', 121314),
#  ('Krishnanagar', 'IND', 121110),
#  ('Chandannagar', 'IND', 120378),
#  ('Mandya', 'IND', 120265),
#  ('Dibrugarh', 'IND', 120127),
#  ('Nandyal', 'IND', 119813),
#  ...]

# %% [markdown]
# ## Query to Pandas

# %%
# Get results into a pandas data frame
df = pd.read_sql_query(query, engine)
df.head()
# Out:
#         city_name CountryCode  city_population
# 0           Kabul         AFG          1780000
# 1        Qandahar         AFG           237500
# 2           Herat         AFG           186800
# 3  Mazar-e-Sharif         AFG           127800
# 4       Amsterdam         NLD           731200

# %% [markdown]
# ## Query in SQL

# %%
print(query)
# Out:
# SELECT "City"."Name" AS city_name, "City"."CountryCode", CAST("City"."Population" AS INTEGER) AS city_population
# FROM "City"
# WHERE "City"."Population" > :Population_1

# %%
print(query.compile(compile_kwargs={"literal_binds": True}))
# Out:
# SELECT "City"."Name" AS city_name, "City"."CountryCode", CAST("City"."Population" AS INTEGER) AS city_population
# FROM "City"
# WHERE "City"."Population" > 5000

# %% [markdown]
# ## Expanding the Query

# %%
query2 = query.filter(City.columns.CountryCode == 'USA')

# %%
print(query2.compile(compile_kwargs={"literal_binds": True}))
# Out:
# SELECT "City"."Name" AS city_name, "City"."CountryCode", CAST("City"."Population" AS INTEGER) AS city_population
# FROM "City"
# WHERE "City"."Population" > 5000 AND "City"."CountryCode" = 'USA'

# %%
pd.read_sql_query(query2, engine)
# Out:
#         city_name CountryCode  city_population
# 0        New York         USA          8008278
# 1     Los Angeles         USA          3694820
# 2         Chicago         USA          2896016
# 3         Houston         USA          1953631
# 4    Philadelphia         USA          1517550
# ..            ...         ...              ...
# 269       Kenosha         USA            89447
# 270         Elgin         USA            89408
# 271        Odessa         USA            89293
# 272        Carson         USA            89089
# 273    Charleston         USA            89063
#
# [274 rows x 3 columns]
